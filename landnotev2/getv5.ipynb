# %%
import os
import time
import random
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib.parse
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
from pathlib import Path
import logging
from tqdm import tqdm
import hashlib
import re
import urllib3
from typing import Optional, Dict, Any, List

class ArticleScraper:
    def __init__(self, scan_mode="all", data_file="articles.xlsx"):
        """初始化爬蟲設定"""
        # 基本設定
        self.base_url = "https://real-estate.get.com.tw/Columns/"
        self.detail_url = f"{self.base_url}detail.aspx"
        self.journal_url = f"{self.base_url}journal.aspx"
        self.target_authors = ["曾榮耀", "許文昌", "蘇偉強"]
        self.scan_mode = scan_mode
        self.data_file = Path(data_file)

        # 期刊參數設定
        self.journal_params = {
            "no": "1282",
            "pno": "51121"
        }

        # 時間範圍設定
        self.end_date = datetime.now()
        self.start_date = self.end_date - timedelta(days=9*365)

        # 效能設定
        self.batch_size = 50  # 降低批次大小以減少伺服器負擔
        self.max_workers = 4  # 降低線程數以避免過度請求
        self.max_retries = 5
        self.retry_delay = 3
        self.request_interval = 1.5  # 請求間隔(秒)

        # 文章編號範圍
        self.start_no = 900000
        self.max_no = 915000
        
   
        
        

        # 初始化
        self.setup_directories()
        self.setup_session()
        self.setup_logger()
        self.processed_articles = set()
        self.load_processed_articles()
        self.last_request_time = 0

    def setup_directories(self):
        """建立必要的目錄結構"""
        self.base_dir = Path("real_estate_articles")
        self.articles_dir = self.base_dir / "articles"
        self.images_dir = self.articles_dir / "images"
        self.logs_dir = self.base_dir / "logs"

        for directory in [self.base_dir, self.articles_dir, self.images_dir, self.logs_dir]:
            directory.mkdir(parents=True, exist_ok=True)

        # 創建預設的失敗圖片
        self.failed_image_path = self.images_dir / "image_download_failed.png"
        if not self.failed_image_path.exists():
            try:
                from PIL import Image, ImageDraw
                img = Image.new('RGB', (400, 100), color='white')
                d = ImageDraw.Draw(img)
                d.text((10, 40), "Image Download Failed", fill='black')
                img.save(self.failed_image_path)
            except Exception:
                self.failed_image_path.touch()

    def setup_session(self):
        """設定請求session"""
        urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
            'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
            'Accept-Encoding': 'gzip, deflate',
            'Connection': 'keep-alive',
            'Upgrade-Insecure-Requests': '1'
        })

    def setup_logger(self):
        """設定日誌系統"""
        self.logger = logging.getLogger('ArticleScraper')
        self.logger.setLevel(logging.INFO)

        log_file = self.logs_dir / f"scraper_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
        handlers = [
            logging.FileHandler(log_file, encoding='utf-8'),
            logging.StreamHandler()
        ]

        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        for handler in handlers:
            handler.setFormatter(formatter)
            self.logger.addHandler(handler)

    def load_processed_articles(self):
        """載入已處理的文章"""
        if self.data_file.exists():
            df = pd.read_excel(self.data_file)
            if '文章編號' in df.columns:
                self.processed_articles = set(df['文章編號'].astype(str))

    def wait_between_requests(self):
        """控制請求間隔"""
        current_time = time.time()
        elapsed = current_time - self.last_request_time
        if elapsed < self.request_interval:
            time.sleep(self.request_interval - elapsed)
        self.last_request_time = current_time

    def get_max_page_number(self) -> int:
        """獲取期刊最大頁數"""
        try:
            self.wait_between_requests()
            response = self.session.get(
                self.journal_url,
                params=self.journal_params,
                timeout=30,
                verify=False
            )
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 找到分頁元素
            pagination = soup.select('.pagination a')
            if pagination:
                page_numbers = []
                for a in pagination:
                    try:
                        page_numbers.append(int(a.text.strip()))
                    except ValueError:
                        continue
                return max(page_numbers) if page_numbers else 1
            return 1
            
        except Exception as e:
            self.logger.error(f"獲取最大頁數失敗: {str(e)}")
            return 30  # 預設較大的頁數以確保不遺漏

    def get_article_urls_from_journal(self, page_no: int) -> List[int]:
        """從期刊頁面獲取文章編號列表"""
        try:
            params = self.journal_params.copy()
            params['page_no'] = page_no
            
            self.wait_between_requests()
            response = self.session.get(
                self.journal_url,
                params=params,
                timeout=30,
                verify=False
            )
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            articles = []
            for link in soup.select('a[href*="detail.aspx?no="]'):
                href = link.get('href', '')
                if 'no=' in href:
                    article_no = href.split('no=')[-1]
                    try:
                        article_no = int(article_no)
                        if str(article_no) not in self.processed_articles:
                            articles.append(article_no)
                    except ValueError:
                        continue
                        
            return articles
            
        except Exception as e:
            self.logger.error(f"獲取第 {page_no} 頁文章列表失敗: {str(e)}")
            return []

    def fetch_article(self, article_no: int) -> Optional[Dict]:
        """抓取單篇文章"""
        if str(article_no) in self.processed_articles:
            return None

        for retry in range(self.max_retries):
            try:
                params = {'no': article_no}
                self.wait_between_requests()

                self.logger.info(f"正在抓取文章 {article_no}")
                response = self.session.get(
                    self.detail_url,
                    params=params,
                    timeout=30,
                    verify=False
                )

                self.logger.info(f"文章 {article_no} 回應狀態碼: {
                                 response.status_code}")

                if response.status_code == 404:
                    self.logger.info(f"文章 {article_no} 不存在")
                    return None

                response.raise_for_status()
                response.encoding = 'utf-8'

                soup = BeautifulSoup(response.text, 'html.parser')
                article_data = self.parse_article(soup, article_no)

                if article_data and self.validate_article(article_data):
                    self.logger.info(f"成功解析文章 {article_no}")
                    return article_data
                else:
                    self.logger.info(f"文章 {article_no} 不符合條件或解析失敗")
                    return None

            except requests.exceptions.RequestException as e:
                self.logger.error(f"抓取文章 {article_no} 失敗 (嘗試 {
                                  retry + 1}/{self.max_retries}): {str(e)}")
                if hasattr(e, 'response') and hasattr(e.response, 'text'):
                    self.logger.error(f"錯誤回應內容: {e.response.text[:200]}")
                if retry < self.max_retries - 1:
                    time.sleep(self.retry_delay * (retry + 1))
                    continue
            except Exception as e:
                self.logger.error(f"處理文章 {article_no} 時發生未預期錯誤: {str(e)}")
                break

        return None

    def parse_article(self, soup: BeautifulSoup, article_no: int) -> Optional[Dict]:
        """解析文章內容"""
        try:
            # 先只解析作者欄位,如果不符合就直接返回
            author = None
            article_info = {}

            for row in soup.select('.columnsDetail_tableRow'):
                th = row.select_one('.columnsDetail_tableth')
                td = row.select_one('.columnsDetail_tabletd')
                if th and td:
                    key = th.text.strip()
                    value = td.text.strip()
                    article_info[key] = value

                    if key == '內文':
                        article_info['內文HTML'] = str(td)
                    elif key == '作者':
                        author = value

            # 如果不是目標作者就直接返回
            if not author or not any(target in author for target in self.target_authors):
                return None

            # 處理文章內容和圖片
            content = self.process_content(
                article_info.get('內文HTML', ''), article_no)

            return {
                '文章編號': article_no,
                '標題': article_info.get('篇名', ''),
                '作者': author,
                '日期': article_info.get('日期', ''),
                '內文': content,
                'URL': f"{self.detail_url}?no={article_no}",
                '爬取時間': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            }

        except Exception as e:
            self.logger.error(f"解析文章 {article_no} 失敗: {str(e)}")
            return None
        
    def download_image(self, img_url: str, article_no: int) -> Optional[str]:
        """下載圖片並返回本地檔名"""
        try:
            if not img_url.startswith(('http://', 'https://')):
                img_url = urllib.parse.urljoin(self.base_url, img_url)
            
            # 生成唯一的檔名
            url_hash = hashlib.md5(img_url.encode()).hexdigest()[:8]
            file_ext = os.path.splitext(img_url)[1] or '.jpg'
            local_filename = f"{article_no}_{url_hash}{file_ext}"
            local_path = self.images_dir / local_filename
            
            # 如果圖片已存在就直接返回
            if local_path.exists():
                return local_filename
                
            # 下載圖片
            self.wait_between_requests()
            response = self.session.get(img_url, timeout=30, verify=False)
            response.raise_for_status()
            
            # 保存圖片
            with open(local_path, 'wb') as f:
                f.write(response.content)
                
            return local_filename
            
        except Exception as e:
            self.logger.error(f"下載圖片失敗 ({img_url}): {str(e)}")
            return None

    def process_content(self, content_html: str, article_no: int) -> str:
        """處理文章內容"""
        if not content_html:
            return ""

        content = []
        soup = BeautifulSoup(content_html, 'html.parser')

        try:
            for element in soup.descendants:
                if isinstance(element, str):
                    text = element.strip()
                    if text:
                        content.append(text)
                elif element.name == 'img':
                    try:
                        img_src = element.get('src')
                        if img_src:
                            local_img = self.download_image(
                                img_src, article_no)
                            if local_img:
                                content.append(
                                    f"\n![圖片](./images/{local_img})\n")
                    except Exception as e:
                        self.logger.error(f"處理圖片元素失敗: {str(e)}")
                        continue

            return '\n'.join(filter(None, content))
        except Exception as e:
            self.logger.error(f"處理文章 {article_no} 內容失敗: {str(e)}")
            return ""


    def validate_article(self, article_data: Dict) -> bool:
        """驗證文章資料完整性"""
        required_fields = ['標題', '作者', '日期', '內文']
        return all(field in article_data and article_data[field] for field in required_fields)

    def save_article(self, article_data: Dict) -> None:
        """儲存文章"""
        try:
            # 更新 Excel 資料
            new_df = pd.DataFrame([article_data])
            if self.data_file.exists():
                df = pd.read_excel(self.data_file)
                df = pd.concat([df, new_df]).drop_duplicates(subset=['文章編號'])
            else:
                df = new_df
            df.to_excel(self.data_file, index=False)

            # 建立 Markdown 文件
            article_no = article_data['文章編號']
            title = re.sub(r'[<>:"/\\|?*]', '', article_data['標題'])[:100]

            markdown_content = f"""# {article_data['標題']}

## 文章資訊
- 文章編號：{article_no}
- 作者：{article_data['作者']}
- 發布日期：{article_data['日期']}
- 爬取時間：{article_data['爬取時間']}
- 原文連結：[閱讀原文]({article_data['URL']})

## 內文
{article_data['內文']}

---
*注：本文圖片存放於 ./images/ 目錄下*
"""

            # 儲存 Markdown 文件
            file_path = self.articles_dir / f"{article_no}_{title}.md"
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(markdown_content)

            # 更新已處理集合
            self.processed_articles.add(str(article_no))

        except Exception as e:
            self.logger.error(f"儲存文章失敗: {str(e)}")
            
            
    def create_index(self):
        """創建文章索引，整合原有目錄內容"""
        try:
            # 讀取 Excel 檔案獲取所有文章資訊
            if not self.data_file.exists():
                return
                
            df = pd.read_excel(self.data_file)
            
            # 讀取現有的目錄文件（如果存在）
            index_path = self.base_dir / "README.md"
            existing_content = []
            existing_articles = set()
            
            if index_path.exists():
                with open(index_path, 'r', encoding='utf-8') as f:
                    existing_content = f.read().splitlines()
                    # 提取現有目錄中的文章編號
                    for line in existing_content:
                        if match := re.search(r'/(\d+)_[^/]+\.md', line):
                            existing_articles.add(match.group(1))
            
            # 只處理新文章
            df['文章編號'] = df['文章編號'].astype(str)
            new_articles = df[~df['文章編號'].isin(existing_articles)]
            
            if new_articles.empty and existing_content:
                self.logger.info("沒有新文章需要添加到目錄")
                return
                
            # 如果有現有內容，保留開頭的通用部分（如標題）
            index_content = []
            for line in existing_content:
                if line.startswith('## '):
                    break
                index_content.append(line)
            
            if not index_content:  # 如果是全新的目錄
                index_content = ["# 文章目錄", ""]
            
            # 合併現有文章和新文章
            all_articles = pd.concat([
                df[df['文章編號'].isin(existing_articles)],
                new_articles
            ]).drop_duplicates(subset=['文章編號'])
            
            # 按作者和日期排序
            all_articles['日期'] = pd.to_datetime(all_articles['日期'])
            all_articles = all_articles.sort_values(['作者', '日期'], ascending=[True, False])
            
            # 按作者分組
            for author in sorted(all_articles['作者'].unique()):
                index_content.append(f"## {author}")
                author_articles = all_articles[all_articles['作者'] == author]
                
                # 按年份分組
                for year in sorted(author_articles['日期'].dt.year.unique(), reverse=True):
                    index_content.append(f"\n### {year}年")
                    year_articles = author_articles[author_articles['日期'].dt.year == year]
                    
                    # 生成文章列表
                    for _, article in year_articles.iterrows():
                        title = re.sub(r'[<>:"/\\|?*]', '', article['標題'])[:100]
                        file_name = f"{article['文章編號']}_{title}.md"
                        date_str = article['日期'].strftime('%Y-%m-%d')
                        index_content.append(
                            f"- {date_str} [{article['標題']}](./articles/{file_name})"
                        )
                
                index_content.append("")  # 作者之間加入空行
            
            # 保存更新後的目錄文件
            with open(index_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(index_content))
                
            self.logger.info(f"已成功更新文章目錄，新增 {len(new_articles)} 篇文章")
            
        except Exception as e:
            self.logger.error(f"更新目錄失敗: {str(e)}")


    def run(self):
        """執行爬蟲"""
        self.logger.info(f"開始執行爬蟲 (模式: {self.scan_mode})")

        success_count = 0
        fail_count = 0

        try:
            with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                futures = []

                # 從期刊頁面獲取文章
                max_page = self.get_max_page_number()
                self.logger.info(f"檢測到期刊總頁數: {max_page}")

                article_numbers = set()

                # 收集所有文章編號
                for page_no in range(1, max_page + 1):
                    self.logger.info(f"正在獲取第 {page_no} 頁的文章列表")
                    page_articles = self.get_article_urls_from_journal(page_no)
                    article_numbers.update(page_articles)

                    if not page_articles:
                        self.logger.warning(f"第 {page_no} 頁沒有找到新文章，可能已到達最後一頁")
                        break

                self.logger.info(f"從期刊頁面共找到 {len(article_numbers)} 篇新文章")

                # 處理找到的文章
                for article_no in article_numbers:
                    if str(article_no) not in self.processed_articles:
                        futures.append(executor.submit(
                            self.fetch_article, article_no))

                # 如果是全量模式，還要掃描編號範圍
                if self.scan_mode == "all":
                    for article_no in range(self.start_no, self.max_no + 1, self.batch_size):
                        batch = range(article_no, min(
                            article_no + self.batch_size, self.max_no + 1))
                        futures.extend([
                            executor.submit(self.fetch_article, no)
                            for no in batch
                            if str(no) not in self.processed_articles
                        ])

                # 處理結果
                with tqdm(total=len(futures), desc="處理文章") as pbar:
                    for future in futures:
                        try:
                            result = future.result()
                            if result:
                                self.save_article(result)
                                success_count += 1
                            else:
                                fail_count += 1
                            pbar.update(1)
                        except Exception as e:
                            self.logger.error(f"處理文章結果失敗: {str(e)}")
                            fail_count += 1
                            pbar.update(1)

        finally:
            self.logger.info(f"成功處理文章數: {success_count}")
            self.logger.info(f"失敗處理文章數: {fail_count}")
            self.create_index()
            self.logger.info("程式結束執行")


if __name__ == "__main__":
    # 建立爬蟲實例並執行
    scraper = ArticleScraper(scan_mode="all")
    scraper.run()
# Out:
# 2025-02-02 16:47:57,487 - INFO - 開始執行爬蟲 (模式: all)
# 2025-02-02 16:47:58,051 - INFO - 檢測到期刊總頁數: 1
# 2025-02-02 16:47:58,051 - INFO - 正在獲取第 1 頁的文章列表
# 2025-02-02 16:47:59,136 - INFO - 從期刊頁面共找到 20 篇新文章
# 處理文章:   0%|          | 0/15021 [00:00<?, ?it/s]2025-02-02 16:47:59,558 - INFO - 正在抓取文章 913286
# 2025-02-02 16:47:59,558 - INFO - 正在抓取文章 913158
# 2025-02-02 16:47:59,559 - INFO - 正在抓取文章 912910
# 2025-02-02 16:47:59,559 - INFO - 正在抓取文章 912784
# 2025-02-02 16:47:59,653 - INFO - 文章 913158 回應狀態碼: 200
# 2025-02-02 16:47:59,689 - INFO - 成功解析文章 913158
# 2025-02-02 16:48:00,122 - INFO - 文章 912910 回應狀態碼: 200
# 2025-02-02 16:48:00,156 - INFO - 成功解析文章 912910
# 2025-02-02 16:48:00,203 - INFO - 文章 913286 回應狀態碼: 200
# 2025-02-02 16:48:00,228 - INFO - 文章 912784 回應狀態碼: 200
# 2025-02-02 16:48:00,252 - INFO - 成功解析文章 912784
# 2025-02-02 16:48:00,636 - INFO - 正在抓取文章 913331
# 2025-02-02 16:48:00,640 - INFO - 正在抓取文章 913054
# 2025-02-02 16:48:00,642 - INFO - 正在抓取文章 912425
# 2025-02-02 16:48:00,672 - INFO - 文章 913331 回應狀態碼: 200
# 2025-02-02 16:48:00,699 - INFO - 成功解析文章 913331
# 2025-02-02 16:48:00,704 - INFO - 文章 912425 回應狀態碼: 200
# 2025-02-02 16:48:00,705 - INFO - 成功解析文章 913286
# 2025-02-02 16:48:00,723 - INFO - 文章 913054 回應狀態碼: 200
# 2025-02-02 16:48:00,755 - INFO - 成功解析文章 913054
# 處理文章:   0%|          | 3/15021 [00:01<1:53:32,  2.20it/s]2025-02-02 16:48:01,658 - INFO - 正在抓取文章 912956
# 2025-02-02 16:48:01,662 - INFO - 正在抓取文章 912452
# 2025-02-02 16:48:01,665 - INFO - 正在抓取文章 912836
# 2025-02-02 16:48:01,690 - INFO - 文章 912956 回應狀態碼: 200
# 2025-02-02 16:48:01,716 - INFO - 成功解析文章 912956
# 2025-02-02 16:48:01,718 - INFO - 文章 912836 回應狀態碼: 200
# 2025-02-02 16:48:01,718 - INFO - 文章 912452 回應狀態碼: 200
# 2025-02-02 16:48:01,741 - INFO - 成功解析文章 912836
# 2025-02-02 16:48:01,741 - INFO - 成功解析文章 912425
# 2025-02-02 16:48:01,756 - INFO - 成功解析文章 912452
# 處理文章:   0%|          | 9/15021 [00:02<45:17,  5.52it/s]  2025-02-02 16:48:02,224 - INFO - 正在抓取文章 912355
# 2025-02-02 16:48:02,224 - INFO - 正在抓取文章 913225
# 2025-02-02 16:48:02,224 - INFO - 正在抓取文章 912485
# 2025-02-02 16:48:02,237 - INFO - 正在抓取文章 913112
# 2025-02-02 16:48:02,257 - INFO - 文章 912355 回應狀態碼: 200
# 2025-02-02 16:48:02,274 - INFO - 成功解析文章 912355
# 2025-02-02 16:48:02,274 - INFO - 文章 913112 回應狀態碼: 200
# 2025-02-02 16:48:02,274 - INFO - 文章 913225 回應狀態碼: 200
# 2025-02-02 16:48:02,309 - INFO - 成功解析文章 913112
# 2025-02-02 16:48:02,309 - INFO - 文章 912485 回應狀態碼: 200
# 2025-02-02 16:48:03,257 - INFO - 正在抓取文章 913011
# 2025-02-02 16:48:03,267 - INFO - 正在抓取文章 912242
# 2025-02-02 16:48:03,292 - INFO - 文章 913011 回應狀態碼: 200
# 2025-02-02 16:48:03,336 - INFO - 成功解析文章 913011
# 2025-02-02 16:48:03,336 - INFO - 文章 912242 回應狀態碼: 200
# 2025-02-02 16:48:03,370 - INFO - 成功解析文章 912242
# 2025-02-02 16:48:03,370 - INFO - 成功解析文章 912485
# 2025-02-02 16:48:03,375 - INFO - 成功解析文章 913225
# 處理文章:   0%|          | 14/15021 [00:04<57:56,  4.32it/s]  2025-02-02 16:48:03,823 - INFO - 正在抓取文章 912632
# 2025-02-02 16:48:03,823 - INFO - 正在抓取文章 912631
# 2025-02-02 16:48:03,824 - INFO - 正在抓取文章 913274
# 2025-02-02 16:48:03,824 - INFO - 正在抓取文章 912885
# 2025-02-02 16:48:03,860 - INFO - 文章 912632 回應狀態碼: 200
# 2025-02-02 16:48:03,889 - INFO - 成功解析文章 912632
# 2025-02-02 16:48:03,890 - INFO - 文章 912631 回應狀態碼: 200
# 2025-02-02 16:48:03,891 - INFO - 文章 913274 回應狀態碼: 200
# 2025-02-02 16:48:03,891 - INFO - 文章 912885 回應狀態碼: 200
# 2025-02-02 16:48:03,912 - INFO - 成功解析文章 912631
# 2025-02-02 16:48:03,956 - INFO - 成功解析文章 913274
# 2025-02-02 16:48:03,974 - INFO - 成功解析文章 912885
# 處理文章:   0%|          | 20/15021 [00:04<39:55,  6.26it/s]2025-02-02 16:48:04,839 - INFO - 正在抓取文章 900000
# 2025-02-02 16:48:04,849 - INFO - 正在抓取文章 900001
# 2025-02-02 16:48:04,849 - INFO - 正在抓取文章 900002
# 2025-02-02 16:48:04,850 - INFO - 正在抓取文章 900003
# 2025-02-02 16:48:04,853 - INFO - 文章 900000 回應狀態碼: 200
# 2025-02-02 16:48:04,859 - INFO - 文章 900000 不符合條件或解析失敗
# 2025-02-02 16:48:04,859 - INFO - 文章 900001 回應狀態碼: 200
# 2025-02-02 16:48:04,859 - INFO - 文章 900001 不符合條件或解析失敗
# 2025-02-02 16:48:04,859 - INFO - 文章 900002 回應狀態碼: 200
# 處理文章:   0%|          | 22/15021 [00:05<48:37,  5.14it/s]2025-02-02 16:48:04,859 - INFO - 文章 900003 回應狀態碼: 200
# 2025-02-02 16:48:04,859 - INFO - 文章 900002 不符合條件或解析失敗
# 2025-02-02 16:48:04,859 - INFO - 文章 900003 不符合條件或解析失敗
# 2025-02-02 16:48:05,478 - INFO - 正在抓取文章 900007
# 2025-02-02 16:48:05,479 - INFO - 正在抓取文章 900004
# 2025-02-02 16:48:05,485 - INFO - 正在抓取文章 900005
# 2025-02-02 16:48:05,487 - INFO - 正在抓取文章 900006
# 2025-02-02 16:48:05,493 - INFO - 文章 900007 回應狀態碼: 200
# 2025-02-02 16:48:05,495 - INFO - 文章 900004 回應狀態碼: 200
# 2025-02-02 16:48:05,496 - INFO - 文章 900007 不符合條件或解析失敗
# 2025-02-02 16:48:05,497 - INFO - 文章 900004 不符合條件或解析失敗
# 2025-02-02 16:48:05,501 - INFO - 文章 900005 回應狀態碼: 200
# 2025-02-02 16:48:05,504 - INFO - 文章 900006 回應狀態碼: 200
# 2025-02-02 16:48:05,505 - INFO - 文章 900005 不符合條件或解析失敗
# 2025-02-02 16:48:05,506 - INFO - 文章 900006 不符合條件或解析失敗
# 處理文章:   0%|          | 25/15021 [00:06<50:35,  4.94it/s]2025-02-02 16:48:06,360 - INFO - 正在抓取文章 900011
# 2025-02-02 16:48:06,360 - INFO - 正在抓取文章 900009
# 2025-02-02 16:48:06,360 - INFO - 正在抓取文章 900008
# 2025-02-02 16:48:06,360 - INFO - 正在抓取文章 900010
# 2025-02-02 16:48:06,374 - INFO - 文章 900011 回應狀態碼: 200
# 2025-02-02 16:48:06,376 - INFO - 文章 900011 不符合條件或解析失敗
# 2025-02-02 16:48:06,378 - INFO - 文章 900009 回應狀態碼: 200
# 2025-02-02 16:48:06,380 - INFO - 文章 900008 回應狀態碼: 200
# 2025-02-02 16:48:06,380 - INFO - 文章 900009 不符合條件或解析失敗
# 2025-02-02 16:48:06,382 - INFO - 文章 900010 回應狀態碼: 200
# 2025-02-02 16:48:06,385 - INFO - 文章 900008 不符合條件或解析失敗
# 2025-02-02 16:48:06,387 - INFO - 文章 900010 不符合條件或解析失敗
# 處理文章:   0%|          | 29/15021 [00:06<52:16,  4.78it/s]2025-02-02 16:48:07,008 - INFO - 正在抓取文章 900012
# 2025-02-02 16:48:07,008 - INFO - 正在抓取文章 900013
# 2025-02-02 16:48:07,008 - INFO - 正在抓取文章 900015
# 2025-02-02 16:48:07,008 - INFO - 正在抓取文章 900014
# 2025-02-02 16:48:07,021 - INFO - 文章 900012 回應狀態碼: 200
# 2025-02-02 16:48:07,023 - INFO - 文章 900012 不符合條件或解析失敗
# 2025-02-02 16:48:07,025 - INFO - 文章 900013 回應狀態碼: 200
# 處理文章:   0%|          | 33/15021 [00:07<47:44,  5.23it/s]2025-02-02 16:48:07,028 - INFO - 文章 900015 回應狀態碼: 200
# 2025-02-02 16:48:07,030 - INFO - 文章 900014 回應狀態碼: 200
# 2025-02-02 16:48:07,031 - INFO - 文章 900013 不符合條件或解析失敗
# 2025-02-02 16:48:07,033 - INFO - 文章 900015 不符合條件或解析失敗
# 2025-02-02 16:48:07,034 - INFO - 文章 900014 不符合條件或解析失敗
# 2025-02-02 16:48:07,890 - INFO - 正在抓取文章 900018
# 2025-02-02 16:48:07,890 - INFO - 正在抓取文章 900016
# 2025-02-02 16:48:07,890 - INFO - 正在抓取文章 900017
# 2025-02-02 16:48:07,890 - INFO - 正在抓取文章 900019
# 2025-02-02 16:48:07,905 - INFO - 文章 900018 回應狀態碼: 200
# 2025-02-02 16:48:07,907 - INFO - 文章 900018 不符合條件或解析失敗
# 2025-02-02 16:48:07,908 - INFO - 文章 900016 回應狀態碼: 200
# 2025-02-02 16:48:07,910 - INFO - 文章 900017 回應狀態碼: 200
# 2025-02-02 16:48:07,912 - INFO - 文章 900019 回應狀態碼: 200
# 2025-02-02 16:48:07,913 - INFO - 文章 900016 不符合條件或解析失敗
# 2025-02-02 16:48:07,914 - INFO - 文章 900017 不符合條件或解析失敗
# 處理文章:   0%|          | 37/15021 [00:08<50:23,  4.96it/s]2025-02-02 16:48:07,915 - INFO - 文章 900019 不符合條件或解析失敗
# 2025-02-02 16:48:08,537 - INFO - 正在抓取文章 900022
# 2025-02-02 16:48:08,537 - INFO - 正在抓取文章 900023
# 2025-02-02 16:48:08,537 - INFO - 正在抓取文章 900020
# 2025-02-02 16:48:08,538 - INFO - 正在抓取文章 900021
# 2025-02-02 16:48:08,549 - INFO - 文章 900022 回應狀態碼: 200
# 2025-02-02 16:48:08,550 - INFO - 文章 900022 不符合條件或解析失敗
# 2025-02-02 16:48:08,552 - INFO - 文章 900023 回應狀態碼: 200
# 2025-02-02 16:48:08,553 - INFO - 文章 900023 不符合條件或解析失敗
# 2025-02-02 16:48:08,554 - INFO - 文章 900020 回應狀態碼: 200
# 2025-02-02 16:48:08,555 - INFO - 文章 900020 不符合條件或解析失敗
# 處理文章:   0%|          | 41/15021 [00:09<46:57,  5.32it/s]2025-02-02 16:48:08,556 - INFO - 文章 900021 回應狀態碼: 200
# 2025-02-02 16:48:08,557 - INFO - 文章 900021 不符合條件或解析失敗
# 2025-02-02 16:48:09,416 - INFO - 正在抓取文章 900024
# 2025-02-02 16:48:09,416 - INFO - 正在抓取文章 900025
# 2025-02-02 16:48:09,417 - INFO - 正在抓取文章 900027
# 2025-02-02 16:48:09,419 - INFO - 正在抓取文章 900026
# 2025-02-02 16:48:09,429 - INFO - 文章 900024 回應狀態碼: 200
# 2025-02-02 16:48:09,430 - INFO - 文章 900025 回應狀態碼: 200
# 2025-02-02 16:48:09,431 - INFO - 文章 900024 不符合條件或解析失敗
# 處理文章:   0%|          | 45/15021 [00:09<49:26,  5.05it/s]2025-02-02 16:48:09,432 - INFO - 文章 900026 回應狀態碼: 200
# 2025-02-02 16:48:09,432 - INFO - 文章 900025 不符合條件或解析失敗
# 2025-02-02 16:48:09,433 - INFO - 文章 900027 回應狀態碼: 200
# 2025-02-02 16:48:09,435 - INFO - 文章 900026 不符合條件或解析失敗
# 2025-02-02 16:48:09,436 - INFO - 文章 900027 不符合條件或解析失敗
# 2025-02-02 16:48:10,056 - INFO - 正在抓取文章 900031
# 2025-02-02 16:48:10,056 - INFO - 正在抓取文章 900028
# 2025-02-02 16:48:10,057 - INFO - 正在抓取文章 900030
# 2025-02-02 16:48:10,057 - INFO - 正在抓取文章 900029
# 2025-02-02 16:48:10,060 - INFO - 文章 900031 回應狀態碼: 200
# 2025-02-02 16:48:10,060 - INFO - 文章 900028 回應狀態碼: 200
# 2025-02-02 16:48:10,060 - INFO - 文章 900031 不符合條件或解析失敗
# 2025-02-02 16:48:10,060 - INFO - 文章 900028 不符合條件或解析失敗
# 處理文章:   0%|          | 49/15021 [00:10<46:29,  5.37it/s]2025-02-02 16:48:10,060 - INFO - 文章 900030 回應狀態碼: 200
# 2025-02-02 16:48:10,075 - INFO - 文章 900029 回應狀態碼: 200
# 2025-02-02 16:48:10,078 - INFO - 文章 900030 不符合條件或解析失敗
# 2025-02-02 16:48:10,079 - INFO - 文章 900029 不符合條件或解析失敗
# 2025-02-02 16:48:10,936 - INFO - 正在抓取文章 900032
# 2025-02-02 16:48:10,937 - INFO - 正在抓取文章 900034
# 2025-02-02 16:48:10,937 - INFO - 正在抓取文章 900033
# 2025-02-02 16:48:10,937 - INFO - 正在抓取文章 900035
# 2025-02-02 16:48:10,950 - INFO - 文章 900032 回應狀態碼: 200
# 2025-02-02 16:48:10,951 - INFO - 文章 900034 回應狀態碼: 200
# 2025-02-02 16:48:10,951 - INFO - 文章 900032 不符合條件或解析失敗
# 2025-02-02 16:48:10,952 - INFO - 文章 900035 回應狀態碼: 200
# 處理文章:   0%|          | 53/15021 [00:11<49:04,  5.08it/s]2025-02-02 16:48:10,952 - INFO - 文章 900033 回應狀態碼: 200
# 2025-02-02 16:48:10,953 - INFO - 文章 900034 不符合條件或解析失敗
# 2025-02-02 16:48:10,956 - INFO - 文章 900035 不符合條件或解析失敗
# 2025-02-02 16:48:10,957 - INFO - 文章 900033 不符合條件或解析失敗
# 2025-02-02 16:48:11,581 - INFO - 正在抓取文章 900039
# 2025-02-02 16:48:11,581 - INFO - 正在抓取文章 900038
# 2025-02-02 16:48:11,581 - INFO - 正在抓取文章 900037
# 2025-02-02 16:48:11,582 - INFO - 正在抓取文章 900036
# 2025-02-02 16:48:11,593 - INFO - 文章 900039 回應狀態碼: 200
# 2025-02-02 16:48:11,594 - INFO - 文章 900038 回應狀態碼: 200
# 2025-02-02 16:48:11,595 - INFO - 文章 900039 不符合條件或解析失敗
# 2025-02-02 16:48:11,597 - INFO - 文章 900038 不符合條件或解析失敗
# 2025-02-02 16:48:11,598 - INFO - 文章 900037 回應狀態碼: 200
# 2025-02-02 16:48:11,599 - INFO - 文章 900036 回應狀態碼: 200
# 2025-02-02 16:48:11,602 - INFO - 文章 900037 不符合條件或解析失敗
# 2025-02-02 16:48:11,603 - INFO - 文章 900036 不符合條件或解析失敗
# 處理文章:   0%|          | 57/15021 [00:12<46:26,  5.37it/s]2025-02-02 16:48:12,455 - INFO - 正在抓取文章 900040
# 2025-02-02 16:48:12,455 - INFO - 正在抓取文章 900043
# 2025-02-02 16:48:12,455 - INFO - 正在抓取文章 900041
# 2025-02-02 16:48:12,455 - INFO - 正在抓取文章 900042
# 2025-02-02 16:48:12,463 - INFO - 文章 900040 回應狀態碼: 200
# 2025-02-02 16:48:12,463 - INFO - 文章 900040 不符合條件或解析失敗
# 處理文章:   0%|          | 61/15021 [00:12<48:33,  5.13it/s]2025-02-02 16:48:12,463 - INFO - 文章 900041 回應狀態碼: 200
# 2025-02-02 16:48:12,472 - INFO - 文章 900043 回應狀態碼: 200
# 2025-02-02 16:48:12,472 - INFO - 文章 900042 回應狀態碼: 200
# 2025-02-02 16:48:12,473 - INFO - 文章 900041 不符合條件或解析失敗
# 2025-02-02 16:48:12,474 - INFO - 文章 900043 不符合條件或解析失敗
# 2025-02-02 16:48:12,475 - INFO - 文章 900042 不符合條件或解析失敗
# 2025-02-02 16:48:13,105 - INFO - 正在抓取文章 900046
# 2025-02-02 16:48:13,105 - INFO - 正在抓取文章 900045
# 2025-02-02 16:48:13,105 - INFO - 正在抓取文章 900047
# 2025-02-02 16:48:13,111 - INFO - 正在抓取文章 900044
# 2025-02-02 16:48:13,120 - INFO - 文章 900046 回應狀態碼: 200
# 2025-02-02 16:48:13,120 - INFO - 文章 900047 回應狀態碼: 200
# 2025-02-02 16:48:13,121 - INFO - 文章 900045 回應狀態碼: 200
# 2025-02-02 16:48:13,122 - INFO - 文章 900046 不符合條件或解析失敗
# 2025-02-02 16:48:13,123 - INFO - 文章 900047 不符合條件或解析失敗
# 2025-02-02 16:48:13,124 - INFO - 文章 900045 不符合條件或解析失敗
# 2025-02-02 16:48:13,127 - INFO - 文章 900044 回應狀態碼: 200
# 2025-02-02 16:48:13,128 - INFO - 文章 900044 不符合條件或解析失敗
# 處理文章:   0%|          | 65/15021 [00:13<46:25,  5.37it/s]2025-02-02 16:48:13,963 - INFO - 正在抓取文章 900049
# 2025-02-02 16:48:13,963 - INFO - 正在抓取文章 900048
# 2025-02-02 16:48:13,964 - INFO - 正在抓取文章 900051
# 2025-02-02 16:48:13,964 - INFO - 正在抓取文章 900050
# 2025-02-02 16:48:13,966 - INFO - 文章 900049 回應狀態碼: 200
# 2025-02-02 16:48:13,981 - INFO - 文章 900049 不符合條件或解析失敗
# 2025-02-02 16:48:13,989 - INFO - 文章 900048 回應狀態碼: 200
# 2025-02-02 16:48:13,989 - INFO - 文章 900051 回應狀態碼: 200
# 2025-02-02 16:48:13,990 - INFO - 文章 900050 回應狀態碼: 200
# 2025-02-02 16:48:13,991 - INFO - 文章 900048 不符合條件或解析失敗
# 處理文章:   0%|          | 69/15021 [00:14<48:40,  5.12it/s]2025-02-02 16:48:13,992 - INFO - 文章 900051 不符合條件或解析失敗
# 2025-02-02 16:48:13,993 - INFO - 文章 900050 不符合條件或解析失敗
# 2025-02-02 16:48:14,628 - INFO - 正在抓取文章 900052
# 2025-02-02 16:48:14,628 - INFO - 正在抓取文章 900054
# 2025-02-02 16:48:14,628 - INFO - 正在抓取文章 900055
# 2025-02-02 16:48:14,628 - INFO - 正在抓取文章 900053
# 2025-02-02 16:48:14,631 - INFO - 文章 900052 回應狀態碼: 200
# 2025-02-02 16:48:14,631 - INFO - 文章 900052 不符合條件或解析失敗
# 2025-02-02 16:48:14,631 - INFO - 文章 900054 回應狀態碼: 200
# 處理文章:   0%|          | 73/15021 [00:15<45:57,  5.42it/s]2025-02-02 16:48:14,645 - INFO - 文章 900054 不符合條件或解析失敗
# 2025-02-02 16:48:14,647 - INFO - 文章 900053 回應狀態碼: 200
# 2025-02-02 16:48:14,647 - INFO - 文章 900053 不符合條件或解析失敗
# 2025-02-02 16:48:14,665 - INFO - 文章 900055 回應狀態碼: 200
# 2025-02-02 16:48:14,689 - INFO - 成功解析文章 900055
# 處理文章:   1%|          | 76/15021 [00:15<36:57,  6.74it/s]2025-02-02 16:48:15,494 - INFO - 正在抓取文章 900058
# 2025-02-02 16:48:15,494 - INFO - 正在抓取文章 900059
# 2025-02-02 16:48:15,495 - INFO - 正在抓取文章 900057
# 2025-02-02 16:48:15,507 - INFO - 正在抓取文章 900056
# 2025-02-02 16:48:15,527 - INFO - 文章 900057 回應狀態碼: 200
# 2025-02-02 16:48:15,548 - INFO - 文章 900056 回應狀態碼: 200
# 2025-02-02 16:48:15,550 - INFO - 文章 900057 不符合條件或解析失敗
# 2025-02-02 16:48:15,551 - INFO - 文章 900059 回應狀態碼: 200
# 2025-02-02 16:48:15,573 - INFO - 文章 900056 不符合條件或解析失敗
# 2025-02-02 16:48:15,574 - INFO - 文章 900058 回應狀態碼: 200
# 處理文章:   1%|          | 78/15021 [00:16<50:47,  4.90it/s]2025-02-02 16:48:15,597 - INFO - 文章 900059 不符合條件或解析失敗
# 2025-02-02 16:48:15,627 - INFO - 成功解析文章 900058
# 2025-02-02 16:48:16,131 - INFO - 正在抓取文章 900061
# 2025-02-02 16:48:16,133 - INFO - 正在抓取文章 900062
# 2025-02-02 16:48:16,133 - INFO - 正在抓取文章 900063
# 2025-02-02 16:48:16,133 - INFO - 正在抓取文章 900060
# 2025-02-02 16:48:16,166 - INFO - 文章 900061 回應狀態碼: 200
# 2025-02-02 16:48:16,186 - INFO - 文章 900061 不符合條件或解析失敗
# 2025-02-02 16:48:16,187 - INFO - 文章 900060 回應狀態碼: 200
# 2025-02-02 16:48:16,188 - INFO - 文章 900063 回應狀態碼: 200
# 2025-02-02 16:48:16,203 - INFO - 文章 900062 回應狀態碼: 200
# 2025-02-02 16:48:16,211 - INFO - 文章 900060 不符合條件或解析失敗
# 處理文章:   1%|          | 81/15021 [00:16<51:12,  4.86it/s]2025-02-02 16:48:16,232 - INFO - 文章 900063 不符合條件或解析失敗
# 2025-02-02 16:48:16,256 - INFO - 文章 900062 不符合條件或解析失敗
# 2025-02-02 16:48:17,075 - INFO - 正在抓取文章 900065
# 2025-02-02 16:48:17,075 - INFO - 正在抓取文章 900067
# 2025-02-02 16:48:17,075 - INFO - 正在抓取文章 900066
# 2025-02-02 16:48:17,075 - INFO - 正在抓取文章 900064
# 2025-02-02 16:48:17,113 - INFO - 文章 900065 回應狀態碼: 200
# 2025-02-02 16:48:17,136 - INFO - 文章 900065 不符合條件或解析失敗
# 2025-02-02 16:48:17,138 - INFO - 文章 900064 回應狀態碼: 200
# 2025-02-02 16:48:17,139 - INFO - 文章 900066 回應狀態碼: 200
# 2025-02-02 16:48:17,139 - INFO - 文章 900067 回應狀態碼: 200
# 2025-02-02 16:48:17,161 - INFO - 文章 900064 不符合條件或解析失敗
# 處理文章:   1%|          | 85/15021 [00:17<55:18,  4.50it/s]2025-02-02 16:48:17,265 - INFO - 文章 900066 不符合條件或解析失敗
# 2025-02-02 16:48:17,283 - INFO - 文章 900067 不符合條件或解析失敗
# 2025-02-02 16:48:17,689 - INFO - 正在抓取文章 900069
# 2025-02-02 16:48:17,689 - INFO - 正在抓取文章 900068
# 2025-02-02 16:48:17,690 - INFO - 正在抓取文章 900070
# 2025-02-02 16:48:17,691 - INFO - 正在抓取文章 900071
# 2025-02-02 16:48:17,703 - INFO - 文章 900069 回應狀態碼: 200
# 2025-02-02 16:48:17,704 - INFO - 文章 900069 不符合條件或解析失敗
# 2025-02-02 16:48:17,704 - INFO - 文章 900071 回應狀態碼: 200
# 2025-02-02 16:48:17,706 - INFO - 文章 900070 回應狀態碼: 200
# 2025-02-02 16:48:17,706 - INFO - 文章 900071 不符合條件或解析失敗
# 2025-02-02 16:48:17,707 - INFO - 文章 900070 不符合條件或解析失敗
# 2025-02-02 16:48:17,727 - INFO - 文章 900068 回應狀態碼: 200
# 2025-02-02 16:48:17,751 - INFO - 文章 900068 不符合條件或解析失敗
# 處理文章:   1%|          | 89/15021 [00:18<46:52,  5.31it/s]2025-02-02 16:48:18,784 - INFO - 正在抓取文章 900075
# 2025-02-02 16:48:18,784 - INFO - 正在抓取文章 900073
# 2025-02-02 16:48:18,784 - INFO - 正在抓取文章 900074
# 2025-02-02 16:48:18,784 - INFO - 正在抓取文章 900072
# 2025-02-02 16:48:18,796 - INFO - 文章 900075 回應狀態碼: 200
# 2025-02-02 16:48:18,797 - INFO - 文章 900075 不符合條件或解析失敗
# 2025-02-02 16:48:18,798 - INFO - 文章 900073 回應狀態碼: 200
# 2025-02-02 16:48:18,800 - INFO - 文章 900074 回應狀態碼: 200
# 2025-02-02 16:48:18,801 - INFO - 文章 900073 不符合條件或解析失敗
# 2025-02-02 16:48:18,802 - INFO - 文章 900072 回應狀態碼: 200
# 2025-02-02 16:48:18,803 - INFO - 文章 900074 不符合條件或解析失敗
# 2025-02-02 16:48:18,805 - INFO - 文章 900072 不符合條件或解析失敗
# 處理文章:   1%|          | 93/15021 [00:19<52:56,  4.70it/s]2025-02-02 16:48:19,205 - INFO - 正在抓取文章 900079
# 2025-02-02 16:48:19,205 - INFO - 正在抓取文章 900076
# 2025-02-02 16:48:19,205 - INFO - 正在抓取文章 900078
# 2025-02-02 16:48:19,205 - INFO - 正在抓取文章 900077
# 2025-02-02 16:48:19,218 - INFO - 文章 900079 回應狀態碼: 200
# 2025-02-02 16:48:19,220 - INFO - 文章 900079 不符合條件或解析失敗
# 2025-02-02 16:48:19,221 - INFO - 文章 900078 回應狀態碼: 200
# 2025-02-02 16:48:19,222 - INFO - 文章 900077 回應狀態碼: 200
# 2025-02-02 16:48:19,222 - INFO - 文章 900076 回應狀態碼: 200
# 2025-02-02 16:48:19,224 - INFO - 文章 900078 不符合條件或解析失敗
# 2025-02-02 16:48:19,226 - INFO - 文章 900077 不符合條件或解析失敗
# 2025-02-02 16:48:19,227 - INFO - 文章 900076 不符合條件或解析失敗
# 處理文章:   1%|          | 97/15021 [00:19<44:29,  5.59it/s]2025-02-02 16:48:20,305 - INFO - 正在抓取文章 900083
# 2025-02-02 16:48:20,305 - INFO - 正在抓取文章 900082
# 2025-02-02 16:48:20,305 - INFO - 正在抓取文章 900080
# 2025-02-02 16:48:20,305 - INFO - 正在抓取文章 900081
# 2025-02-02 16:48:20,305 - INFO - 文章 900083 回應狀態碼: 200
# 2025-02-02 16:48:20,305 - INFO - 文章 900083 不符合條件或解析失敗
# 2025-02-02 16:48:20,320 - INFO - 文章 900080 回應狀態碼: 200
# 2025-02-02 16:48:20,320 - INFO - 文章 900080 不符合條件或解析失敗
# 處理文章:   1%|          | 101/15021 [00:20<51:45,  4.80it/s]2025-02-02 16:48:20,342 - INFO - 文章 900082 回應狀態碼: 200
# 2025-02-02 16:48:20,366 - INFO - 成功解析文章 900082
# 2025-02-02 16:48:20,367 - INFO - 文章 900081 回應狀態碼: 200
# 2025-02-02 16:48:20,396 - INFO - 成功解析文章 900081
# 處理文章:   1%|          | 102/15021 [00:20<49:30,  5.02it/s]2025-02-02 16:48:20,729 - INFO - 正在抓取文章 900086
# 2025-02-02 16:48:20,729 - INFO - 正在抓取文章 900085
# 2025-02-02 16:48:20,729 - INFO - 正在抓取文章 900087
# 2025-02-02 16:48:20,736 - INFO - 文章 900086 回應狀態碼: 200
# 2025-02-02 16:48:20,736 - INFO - 文章 900086 不符合條件或解析失敗
# 2025-02-02 16:48:20,742 - INFO - 正在抓取文章 900084
# 2025-02-02 16:48:20,742 - INFO - 文章 900085 回應狀態碼: 200
# 2025-02-02 16:48:20,745 - INFO - 文章 900087 回應狀態碼: 200
# 2025-02-02 16:48:20,746 - INFO - 文章 900085 不符合條件或解析失敗
# 2025-02-02 16:48:20,747 - INFO - 文章 900087 不符合條件或解析失敗
# 2025-02-02 16:48:20,754 - INFO - 文章 900084 回應狀態碼: 200
# 2025-02-02 16:48:20,755 - INFO - 文章 900084 不符合條件或解析失敗
# 處理文章:   1%|          | 105/15021 [00:21<42:31,  5.85it/s]2025-02-02 16:48:21,806 - INFO - 正在抓取文章 900090
# 2025-02-02 16:48:21,806 - INFO - 正在抓取文章 900089
# 2025-02-02 16:48:21,806 - INFO - 正在抓取文章 900091
# 2025-02-02 16:48:21,807 - INFO - 正在抓取文章 900088
# 2025-02-02 16:48:21,821 - INFO - 文章 900090 回應狀態碼: 200
# 2025-02-02 16:48:21,821 - INFO - 文章 900091 回應狀態碼: 200
# 2025-02-02 16:48:21,821 - INFO - 文章 900089 回應狀態碼: 200
# 2025-02-02 16:48:21,821 - INFO - 文章 900090 不符合條件或解析失敗
# 2025-02-02 16:48:21,824 - INFO - 文章 900088 回應狀態碼: 200
# 2025-02-02 16:48:21,825 - INFO - 文章 900091 不符合條件或解析失敗
# 2025-02-02 16:48:21,827 - INFO - 文章 900089 不符合條件或解析失敗
# 2025-02-02 16:48:21,828 - INFO - 文章 900088 不符合條件或解析失敗
# 處理文章:   1%|          | 109/15021 [00:22<51:20,  4.84it/s]2025-02-02 16:48:22,242 - INFO - 正在抓取文章 900092
# 2025-02-02 16:48:22,243 - INFO - 正在抓取文章 900095
# 2025-02-02 16:48:22,243 - INFO - 正在抓取文章 900093
# 2025-02-02 16:48:22,243 - INFO - 正在抓取文章 900094
# 2025-02-02 16:48:22,254 - INFO - 文章 900092 回應狀態碼: 200
# 2025-02-02 16:48:22,254 - INFO - 文章 900092 不符合條件或解析失敗
# 處理文章:   1%|          | 113/15021 [00:22<42:46,  5.81it/s]2025-02-02 16:48:22,254 - INFO - 文章 900093 回應狀態碼: 200
# 2025-02-02 16:48:22,261 - INFO - 文章 900094 回應狀態碼: 200
# 2025-02-02 16:48:22,261 - INFO - 文章 900093 不符合條件或解析失敗
# 2025-02-02 16:48:22,263 - INFO - 文章 900094 不符合條件或解析失敗
# 2025-02-02 16:48:22,277 - INFO - 文章 900095 回應狀態碼: 200
# 2025-02-02 16:48:22,303 - INFO - 文章 900095 不符合條件或解析失敗
# 2025-02-02 16:48:23,330 - INFO - 正在抓取文章 900099
# 2025-02-02 16:48:23,331 - INFO - 正在抓取文章 900097
# 2025-02-02 16:48:23,332 - INFO - 正在抓取文章 900098
# 2025-02-02 16:48:23,334 - INFO - 正在抓取文章 900096
# 2025-02-02 16:48:23,344 - INFO - 文章 900097 回應狀態碼: 200
# 2025-02-02 16:48:23,345 - INFO - 文章 900097 不符合條件或解析失敗
# 2025-02-02 16:48:23,346 - INFO - 文章 900099 回應狀態碼: 200
# 2025-02-02 16:48:23,348 - INFO - 文章 900099 不符合條件或解析失敗
# 2025-02-02 16:48:23,349 - INFO - 文章 900098 回應狀態碼: 200
# 2025-02-02 16:48:23,350 - INFO - 文章 900098 不符合條件或解析失敗
# 2025-02-02 16:48:23,368 - INFO - 文章 900096 回應狀態碼: 200
# 2025-02-02 16:48:23,392 - INFO - 文章 900096 不符合條件或解析失敗
# 處理文章:   1%|          | 117/15021 [00:23<51:55,  4.78it/s]2025-02-02 16:48:23,755 - INFO - 正在抓取文章 900100
# 2025-02-02 16:48:23,755 - INFO - 正在抓取文章 900102
# 2025-02-02 16:48:23,755 - INFO - 正在抓取文章 900103
# 2025-02-02 16:48:23,756 - INFO - 正在抓取文章 900101
# 2025-02-02 16:48:23,756 - INFO - 文章 900100 回應狀態碼: 200
# 2025-02-02 16:48:23,756 - INFO - 文章 900102 回應狀態碼: 200
# 2025-02-02 16:48:23,756 - INFO - 文章 900100 不符合條件或解析失敗
# 處理文章:   1%|          | 121/15021 [00:24<42:32,  5.84it/s]2025-02-02 16:48:23,756 - INFO - 文章 900102 不符合條件或解析失敗
# 2025-02-02 16:48:23,756 - INFO - 文章 900101 回應狀態碼: 200
# 2025-02-02 16:48:23,775 - INFO - 文章 900101 不符合條件或解析失敗
# 2025-02-02 16:48:23,788 - INFO - 文章 900103 回應狀態碼: 200
# 2025-02-02 16:48:23,813 - INFO - 文章 900103 不符合條件或解析失敗
# 2025-02-02 16:48:24,849 - INFO - 正在抓取文章 900106
# 2025-02-02 16:48:24,849 - INFO - 正在抓取文章 900107
# 2025-02-02 16:48:24,851 - INFO - 正在抓取文章 900105
# 2025-02-02 16:48:24,863 - INFO - 文章 900106 回應狀態碼: 200
# 2025-02-02 16:48:24,863 - INFO - 正在抓取文章 900104
# 2025-02-02 16:48:24,864 - INFO - 文章 900107 回應狀態碼: 200
# 2025-02-02 16:48:24,864 - INFO - 文章 900106 不符合條件或解析失敗
# 2025-02-02 16:48:24,867 - INFO - 文章 900105 回應狀態碼: 200
# 2025-02-02 16:48:24,868 - INFO - 文章 900107 不符合條件或解析失敗
# 2025-02-02 16:48:24,869 - INFO - 文章 900105 不符合條件或解析失敗
# 2025-02-02 16:48:24,877 - INFO - 文章 900104 回應狀態碼: 200
# 2025-02-02 16:48:24,878 - INFO - 文章 900104 不符合條件或解析失敗
# 處理文章:   1%|          | 125/15021 [00:25<51:02,  4.86it/s]2025-02-02 16:48:25,257 - INFO - 正在抓取文章 900110
# 2025-02-02 16:48:25,257 - INFO - 正在抓取文章 900109
# 2025-02-02 16:48:25,257 - INFO - 正在抓取文章 900111
# 2025-02-02 16:48:25,257 - INFO - 正在抓取文章 900108
# 2025-02-02 16:48:25,257 - INFO - 文章 900110 回應狀態碼: 200
# 2025-02-02 16:48:25,257 - INFO - 文章 900110 不符合條件或解析失敗
# 2025-02-02 16:48:25,273 - INFO - 文章 900111 回應狀態碼: 200
# 2025-02-02 16:48:25,274 - INFO - 文章 900109 回應狀態碼: 200
# 2025-02-02 16:48:25,274 - INFO - 文章 900108 回應狀態碼: 200
# 2025-02-02 16:48:25,276 - INFO - 文章 900111 不符合條件或解析失敗
# 2025-02-02 16:48:25,277 - INFO - 文章 900109 不符合條件或解析失敗
# 2025-02-02 16:48:25,278 - INFO - 文章 900108 不符合條件或解析失敗
# 處理文章:   1%|          | 129/15021 [00:25<42:57,  5.78it/s]2025-02-02 16:48:26,369 - INFO - 正在抓取文章 900114
# 2025-02-02 16:48:26,369 - INFO - 正在抓取文章 900112
# 2025-02-02 16:48:26,369 - INFO - 正在抓取文章 900115
# 2025-02-02 16:48:26,371 - INFO - 正在抓取文章 900113
# 2025-02-02 16:48:26,381 - INFO - 文章 900114 回應狀態碼: 200
# 2025-02-02 16:48:26,382 - INFO - 文章 900114 不符合條件或解析失敗
# 2025-02-02 16:48:26,382 - INFO - 文章 900112 回應狀態碼: 200
# 2025-02-02 16:48:26,384 - INFO - 文章 900112 不符合條件或解析失敗
# 2025-02-02 16:48:26,384 - INFO - 文章 900115 回應狀態碼: 200
# 處理文章:   1%|          | 133/15021 [00:26<50:46,  4.89it/s]2025-02-02 16:48:26,386 - INFO - 文章 900113 回應狀態碼: 200
# 2025-02-02 16:48:26,387 - INFO - 文章 900115 不符合條件或解析失敗
# 2025-02-02 16:48:26,388 - INFO - 文章 900113 不符合條件或解析失敗
# 2025-02-02 16:48:26,780 - INFO - 正在抓取文章 900119
# 2025-02-02 16:48:26,780 - INFO - 正在抓取文章 900116
# 2025-02-02 16:48:26,780 - INFO - 正在抓取文章 900117
# 2025-02-02 16:48:26,780 - INFO - 正在抓取文章 900118
# 2025-02-02 16:48:26,794 - INFO - 文章 900119 回應狀態碼: 200
# 2025-02-02 16:48:26,795 - INFO - 文章 900116 回應狀態碼: 200
# 2025-02-02 16:48:26,796 - INFO - 文章 900119 不符合條件或解析失敗
# 2025-02-02 16:48:26,797 - INFO - 文章 900117 回應狀態碼: 200
# 2025-02-02 16:48:26,798 - INFO - 文章 900116 不符合條件或解析失敗
# 處理文章:   1%|          | 137/15021 [00:27<43:09,  5.75it/s]2025-02-02 16:48:26,798 - INFO - 文章 900118 回應狀態碼: 200
# 2025-02-02 16:48:26,800 - INFO - 文章 900117 不符合條件或解析失敗
# 2025-02-02 16:48:26,802 - INFO - 文章 900118 不符合條件或解析失敗
# 2025-02-02 16:48:27,890 - INFO - 正在抓取文章 900121
# 2025-02-02 16:48:27,890 - INFO - 正在抓取文章 900123
# 2025-02-02 16:48:27,890 - INFO - 正在抓取文章 900122
# 2025-02-02 16:48:27,890 - INFO - 正在抓取文章 900120
# 2025-02-02 16:48:27,893 - INFO - 文章 900121 回應狀態碼: 200
# 2025-02-02 16:48:27,893 - INFO - 文章 900123 回應狀態碼: 200
# 2025-02-02 16:48:27,893 - INFO - 文章 900121 不符合條件或解析失敗
# 2025-02-02 16:48:27,893 - INFO - 文章 900122 回應狀態碼: 200
# 2025-02-02 16:48:27,893 - INFO - 文章 900120 回應狀態碼: 200
# 2025-02-02 16:48:27,893 - INFO - 文章 900123 不符合條件或解析失敗
# 2025-02-02 16:48:27,908 - INFO - 文章 900122 不符合條件或解析失敗
# 2025-02-02 16:48:27,911 - INFO - 文章 900120 不符合條件或解析失敗
# 處理文章:   1%|          | 141/15021 [00:28<50:58,  4.87it/s]2025-02-02 16:48:28,299 - INFO - 正在抓取文章 900124
# 2025-02-02 16:48:28,299 - INFO - 正在抓取文章 900127
# 2025-02-02 16:48:28,300 - INFO - 正在抓取文章 900125
# 2025-02-02 16:48:28,300 - INFO - 正在抓取文章 900126
# 2025-02-02 16:48:28,311 - INFO - 文章 900124 回應狀態碼: 200
# 2025-02-02 16:48:28,312 - INFO - 文章 900124 不符合條件或解析失敗
# 處理文章:   1%|          | 145/15021 [00:28<43:04,  5.76it/s]2025-02-02 16:48:28,315 - INFO - 文章 900127 回應狀態碼: 200
# 2025-02-02 16:48:28,316 - INFO - 文章 900125 回應狀態碼: 200
# 2025-02-02 16:48:28,317 - INFO - 文章 900127 不符合條件或解析失敗
# 2025-02-02 16:48:28,317 - INFO - 文章 900126 回應狀態碼: 200
# 2025-02-02 16:48:28,318 - INFO - 文章 900125 不符合條件或解析失敗
# 2025-02-02 16:48:28,322 - INFO - 文章 900126 不符合條件或解析失敗
# 2025-02-02 16:48:29,413 - INFO - 正在抓取文章 900130
# 2025-02-02 16:48:29,413 - INFO - 正在抓取文章 900129
# 2025-02-02 16:48:29,413 - INFO - 正在抓取文章 900131
# 2025-02-02 16:48:29,414 - INFO - 正在抓取文章 900128
# 2025-02-02 16:48:29,427 - INFO - 文章 900130 回應狀態碼: 200
# 2025-02-02 16:48:29,428 - INFO - 文章 900130 不符合條件或解析失敗
# 2025-02-02 16:48:29,430 - INFO - 文章 900129 回應狀態碼: 200
# 2025-02-02 16:48:29,430 - INFO - 文章 900129 不符合條件或解析失敗
# 2025-02-02 16:48:29,430 - INFO - 文章 900131 回應狀態碼: 200
# 2025-02-02 16:48:29,430 - INFO - 文章 900128 回應狀態碼: 200
# 2025-02-02 16:48:29,430 - INFO - 文章 900131 不符合條件或解析失敗
# 2025-02-02 16:48:29,436 - INFO - 文章 900128 不符合條件或解析失敗
# 處理文章:   1%|          | 149/15021 [00:29<51:04,  4.85it/s]2025-02-02 16:48:29,815 - INFO - 正在抓取文章 900135
# 2025-02-02 16:48:29,815 - INFO - 正在抓取文章 900134
# 2025-02-02 16:48:29,815 - INFO - 正在抓取文章 900132
# 2025-02-02 16:48:29,818 - INFO - 正在抓取文章 900133
# 2025-02-02 16:48:29,827 - INFO - 文章 900135 回應狀態碼: 200
# 2025-02-02 16:48:29,828 - INFO - 文章 900135 不符合條件或解析失敗
# 2025-02-02 16:48:29,831 - INFO - 文章 900134 回應狀態碼: 200
# 2025-02-02 16:48:29,832 - INFO - 文章 900132 回應狀態碼: 200
# 2025-02-02 16:48:29,833 - INFO - 文章 900134 不符合條件或解析失敗
# 2025-02-02 16:48:29,834 - INFO - 文章 900133 回應狀態碼: 200
# 2025-02-02 16:48:29,835 - INFO - 文章 900132 不符合條件或解析失敗
# 處理文章:   1%|          | 153/15021 [00:30<43:08,  5.74it/s]2025-02-02 16:48:29,837 - INFO - 文章 900133 不符合條件或解析失敗
# 2025-02-02 16:48:30,930 - INFO - 正在抓取文章 900137
# 2025-02-02 16:48:30,930 - INFO - 正在抓取文章 900136
# 2025-02-02 16:48:30,930 - INFO - 正在抓取文章 900139
# 2025-02-02 16:48:30,930 - INFO - 正在抓取文章 900138
# 2025-02-02 16:48:30,932 - INFO - 文章 900136 回應狀態碼: 200
# 2025-02-02 16:48:30,932 - INFO - 文章 900137 回應狀態碼: 200
# 2025-02-02 16:48:30,946 - INFO - 文章 900136 不符合條件或解析失敗
# 2025-02-02 16:48:30,948 - INFO - 文章 900138 回應狀態碼: 200
# 處理文章:   1%|          | 157/15021 [00:31<50:54,  4.87it/s]2025-02-02 16:48:30,948 - INFO - 文章 900139 回應狀態碼: 200
# 2025-02-02 16:48:30,948 - INFO - 文章 900137 不符合條件或解析失敗
# 2025-02-02 16:48:30,953 - INFO - 文章 900138 不符合條件或解析失敗
# 2025-02-02 16:48:30,954 - INFO - 文章 900139 不符合條件或解析失敗
# 2025-02-02 16:48:31,338 - INFO - 正在抓取文章 900142
# 2025-02-02 16:48:31,339 - INFO - 正在抓取文章 900143
# 2025-02-02 16:48:31,339 - INFO - 正在抓取文章 900141
# 2025-02-02 16:48:31,342 - INFO - 正在抓取文章 900140
# 2025-02-02 16:48:31,348 - INFO - 文章 900143 回應狀態碼: 200
# 2025-02-02 16:48:31,348 - INFO - 文章 900143 不符合條件或解析失敗
# 2025-02-02 16:48:31,371 - INFO - 文章 900140 回應狀態碼: 200
# 2025-02-02 16:48:31,392 - INFO - 文章 900140 不符合條件或解析失敗
# 處理文章:   1%|          | 161/15021 [00:31<43:49,  5.65it/s]2025-02-02 16:48:31,409 - INFO - 文章 900142 回應狀態碼: 200
# 2025-02-02 16:48:31,436 - INFO - 成功解析文章 900142
# 2025-02-02 16:48:31,437 - INFO - 文章 900141 回應狀態碼: 200
# 2025-02-02 16:48:31,461 - INFO - 文章 900141 不符合條件或解析失敗
# 處理文章:   1%|          | 163/15021 [00:32<38:36,  6.41it/s]2025-02-02 16:48:32,448 - INFO - 正在抓取文章 900145
# 2025-02-02 16:48:32,448 - INFO - 正在抓取文章 900147
# 2025-02-02 16:48:32,448 - INFO - 正在抓取文章 900146
# 2025-02-02 16:48:32,455 - INFO - 正在抓取文章 900144
# 2025-02-02 16:48:32,484 - INFO - 文章 900145 回應狀態碼: 200
# 2025-02-02 16:48:32,509 - INFO - 文章 900147 回應狀態碼: 200
# 2025-02-02 16:48:32,519 - INFO - 文章 900145 不符合條件或解析失敗
# 2025-02-02 16:48:32,530 - INFO - 文章 900147 不符合條件或解析失敗
# 2025-02-02 16:48:32,530 - INFO - 文章 900146 回應狀態碼: 200
# 2025-02-02 16:48:32,530 - INFO - 文章 900144 回應狀態碼: 200
# 2025-02-02 16:48:32,567 - INFO - 文章 900146 不符合條件或解析失敗
# 2025-02-02 16:48:32,590 - INFO - 成功解析文章 900144
# 處理文章:   1%|          | 165/15021 [00:33<59:15,  4.18it/s]2025-02-02 16:48:32,849 - INFO - 正在抓取文章 900151
# 2025-02-02 16:48:32,849 - INFO - 正在抓取文章 900150
# 2025-02-02 16:48:32,860 - INFO - 正在抓取文章 900148
# 2025-02-02 16:48:32,860 - INFO - 文章 900151 回應狀態碼: 200
# 2025-02-02 16:48:32,862 - INFO - 文章 900151 不符合條件或解析失敗
# 2025-02-02 16:48:32,862 - INFO - 正在抓取文章 900149
# 2025-02-02 16:48:32,867 - INFO - 文章 900150 回應狀態碼: 200
# 2025-02-02 16:48:32,874 - INFO - 文章 900150 不符合條件或解析失敗
# 2025-02-02 16:48:32,954 - INFO - 文章 900149 回應狀態碼: 200
# 2025-02-02 16:48:32,975 - INFO - 文章 900149 不符合條件或解析失敗
# 2025-02-02 16:48:32,975 - INFO - 文章 900148 回應狀態碼: 200
# 2025-02-02 16:48:33,005 - INFO - 文章 900148 不符合條件或解析失敗
# 處理文章:   1%|          | 169/15021 [00:33<45:40,  5.42it/s]2025-02-02 16:48:34,030 - INFO - 正在抓取文章 900155
# 2025-02-02 16:48:34,031 - INFO - 正在抓取文章 900154
# 2025-02-02 16:48:34,031 - INFO - 正在抓取文章 900152
# 2025-02-02 16:48:34,031 - INFO - 正在抓取文章 900153
# 2025-02-02 16:48:34,034 - INFO - 文章 900155 回應狀態碼: 200
# 2025-02-02 16:48:34,034 - INFO - 文章 900155 不符合條件或解析失敗
# 2025-02-02 16:48:34,047 - INFO - 文章 900154 回應狀態碼: 200
# 2025-02-02 16:48:34,049 - INFO - 文章 900152 回應狀態碼: 200
# 2025-02-02 16:48:34,050 - INFO - 文章 900154 不符合條件或解析失敗
# 2025-02-02 16:48:34,051 - INFO - 文章 900153 回應狀態碼: 200
# 2025-02-02 16:48:34,051 - INFO - 文章 900152 不符合條件或解析失敗
# 處理文章:   1%|          | 173/15021 [00:34<52:14,  4.74it/s]2025-02-02 16:48:34,053 - INFO - 文章 900153 不符合條件或解析失敗
# 2025-02-02 16:48:34,375 - INFO - 正在抓取文章 900159
# 2025-02-02 16:48:34,377 - INFO - 正在抓取文章 900156
# 2025-02-02 16:48:34,377 - INFO - 正在抓取文章 900158
# 2025-02-02 16:48:34,377 - INFO - 正在抓取文章 900157
# 2025-02-02 16:48:34,388 - INFO - 文章 900159 回應狀態碼: 200
# 2025-02-02 16:48:34,389 - INFO - 文章 900159 不符合條件或解析失敗
# 2025-02-02 16:48:34,390 - INFO - 文章 900156 回應狀態碼: 200
# 2025-02-02 16:48:34,391 - INFO - 文章 900156 不符合條件或解析失敗
# 2025-02-02 16:48:34,392 - INFO - 文章 900158 回應狀態碼: 200
# 處理文章:   1%|          | 177/15021 [00:34<41:57,  5.90it/s]2025-02-02 16:48:34,395 - INFO - 文章 900157 回應狀態碼: 200
# 2025-02-02 16:48:34,395 - INFO - 文章 900158 不符合條件或解析失敗
# 2025-02-02 16:48:34,397 - INFO - 文章 900157 不符合條件或解析失敗
# 2025-02-02 16:48:35,552 - INFO - 正在抓取文章 900162
# 2025-02-02 16:48:35,552 - INFO - 正在抓取文章 900161
# 2025-02-02 16:48:35,553 - INFO - 正在抓取文章 900163
# 2025-02-02 16:48:35,553 - INFO - 正在抓取文章 900160
# 2025-02-02 16:48:35,566 - INFO - 文章 900162 回應狀態碼: 200
# 2025-02-02 16:48:35,566 - INFO - 文章 900161 回應狀態碼: 200
# 2025-02-02 16:48:35,566 - INFO - 文章 900163 回應狀態碼: 200
# 2025-02-02 16:48:35,566 - INFO - 文章 900162 不符合條件或解析失敗
# 2025-02-02 16:48:35,566 - INFO - 文章 900160 回應狀態碼: 200
# 2025-02-02 16:48:35,570 - INFO - 文章 900161 不符合條件或解析失敗
# 2025-02-02 16:48:35,571 - INFO - 文章 900163 不符合條件或解析失敗
# 2025-02-02 16:48:35,573 - INFO - 文章 900160 不符合條件或解析失敗
# 處理文章:   1%|          | 181/15021 [00:36<51:53,  4.77it/s]2025-02-02 16:48:35,889 - INFO - 正在抓取文章 900167
# 2025-02-02 16:48:35,890 - INFO - 正在抓取文章 900164
# 2025-02-02 16:48:35,890 - INFO - 正在抓取文章 900166
# 2025-02-02 16:48:35,890 - INFO - 正在抓取文章 900165
# 2025-02-02 16:48:35,901 - INFO - 文章 900167 回應狀態碼: 200
# 2025-02-02 16:48:35,902 - INFO - 文章 900164 回應狀態碼: 200
# 2025-02-02 16:48:35,904 - INFO - 文章 900166 回應狀態碼: 200
# 2025-02-02 16:48:35,905 - INFO - 文章 900167 不符合條件或解析失敗
# 2025-02-02 16:48:35,905 - INFO - 文章 900165 回應狀態碼: 200
# 2025-02-02 16:48:35,908 - INFO - 文章 900164 不符合條件或解析失敗
# 處理文章:   1%|          | 185/15021 [00:36<42:11,  5.86it/s]2025-02-02 16:48:35,910 - INFO - 文章 900166 不符合條件或解析失敗
# 2025-02-02 16:48:35,913 - INFO - 文章 900165 不符合條件或解析失敗
# 2025-02-02 16:48:37,075 - INFO - 正在抓取文章 900169
# 2025-02-02 16:48:37,075 - INFO - 正在抓取文章 900171
# 2025-02-02 16:48:37,075 - INFO - 正在抓取文章 900168
# 2025-02-02 16:48:37,075 - INFO - 正在抓取文章 900170
# 2025-02-02 16:48:37,098 - INFO - 文章 900171 回應狀態碼: 200
# 2025-02-02 16:48:37,099 - INFO - 文章 900171 不符合條件或解析失敗
# 2025-02-02 16:48:37,100 - INFO - 文章 900170 回應狀態碼: 200
# 2025-02-02 16:48:37,100 - INFO - 文章 900168 回應狀態碼: 200
# 2025-02-02 16:48:37,102 - INFO - 文章 900170 不符合條件或解析失敗
# 2025-02-02 16:48:37,103 - INFO - 文章 900168 不符合條件或解析失敗
# 處理文章:   1%|▏         | 189/15021 [00:37<51:52,  4.77it/s]2025-02-02 16:48:37,213 - INFO - 文章 900169 回應狀態碼: 200
# 2025-02-02 16:48:37,214 - INFO - 文章 900169 不符合條件或解析失敗
# 處理文章:   1%|▏         | 190/15021 [00:37<49:25,  5.00it/s]2025-02-02 16:48:37,416 - INFO - 正在抓取文章 900175
# 2025-02-02 16:48:37,416 - INFO - 正在抓取文章 900172
# 2025-02-02 16:48:37,416 - INFO - 正在抓取文章 900173
# 2025-02-02 16:48:37,417 - INFO - 正在抓取文章 900174
# 2025-02-02 16:48:37,428 - INFO - 文章 900175 回應狀態碼: 200
# 2025-02-02 16:48:37,429 - INFO - 文章 900175 不符合條件或解析失敗
# 2025-02-02 16:48:37,430 - INFO - 文章 900172 回應狀態碼: 200
# 2025-02-02 16:48:37,431 - INFO - 文章 900173 回應狀態碼: 200
# 2025-02-02 16:48:37,432 - INFO - 文章 900172 不符合條件或解析失敗
# 處理文章:   1%|▏         | 193/15021 [00:37<40:04,  6.17it/s]2025-02-02 16:48:37,433 - INFO - 文章 900174 回應狀態碼: 200
# 2025-02-02 16:48:37,434 - INFO - 文章 900173 不符合條件或解析失敗
# 2025-02-02 16:48:37,436 - INFO - 文章 900174 不符合條件或解析失敗
# 2025-02-02 16:48:38,604 - INFO - 正在抓取文章 900178
# 2025-02-02 16:48:38,604 - INFO - 正在抓取文章 900176
# 2025-02-02 16:48:38,604 - INFO - 正在抓取文章 900177
# 2025-02-02 16:48:38,604 - INFO - 正在抓取文章 900179
# 2025-02-02 16:48:38,604 - INFO - 文章 900178 回應狀態碼: 200
# 2025-02-02 16:48:38,604 - INFO - 文章 900178 不符合條件或解析失敗
# 2025-02-02 16:48:38,624 - INFO - 文章 900179 回應狀態碼: 200
# 2025-02-02 16:48:38,625 - INFO - 文章 900179 不符合條件或解析失敗
# 2025-02-02 16:48:38,626 - INFO - 文章 900176 回應狀態碼: 200
# 2025-02-02 16:48:38,627 - INFO - 文章 900176 不符合條件或解析失敗
# 處理文章:   1%|▏         | 197/15021 [00:39<52:15,  4.73it/s]2025-02-02 16:48:38,635 - INFO - 文章 900177 回應狀態碼: 200
# 2025-02-02 16:48:38,657 - INFO - 文章 900177 不符合條件或解析失敗
# 2025-02-02 16:48:38,938 - INFO - 正在抓取文章 900182
# 2025-02-02 16:48:38,939 - INFO - 正在抓取文章 900180
# 2025-02-02 16:48:38,939 - INFO - 正在抓取文章 900183
# 2025-02-02 16:48:38,939 - INFO - 正在抓取文章 900181
# 2025-02-02 16:48:38,951 - INFO - 文章 900182 回應狀態碼: 200
# 2025-02-02 16:48:38,951 - INFO - 文章 900180 回應狀態碼: 200
# 2025-02-02 16:48:38,952 - INFO - 文章 900182 不符合條件或解析失敗
# 2025-02-02 16:48:38,954 - INFO - 文章 900183 回應狀態碼: 200
# 2025-02-02 16:48:38,955 - INFO - 文章 900180 不符合條件或解析失敗
# 2025-02-02 16:48:38,955 - INFO - 文章 900181 回應狀態碼: 200
# 2025-02-02 16:48:38,957 - INFO - 文章 900183 不符合條件或解析失敗
# 處理文章:   1%|▏         | 201/15021 [00:39<41:24,  5.96it/s]2025-02-02 16:48:38,959 - INFO - 文章 900181 不符合條件或解析失敗
# 2025-02-02 16:48:40,126 - INFO - 正在抓取文章 900185
# 2025-02-02 16:48:40,126 - INFO - 正在抓取文章 900187
# 2025-02-02 16:48:40,126 - INFO - 正在抓取文章 900184
# 2025-02-02 16:48:40,126 - INFO - 正在抓取文章 900186
# 2025-02-02 16:48:40,138 - INFO - 文章 900185 回應狀態碼: 200
# 2025-02-02 16:48:40,139 - INFO - 文章 900185 不符合條件或解析失敗
# 2025-02-02 16:48:40,140 - INFO - 文章 900187 回應狀態碼: 200
# 2025-02-02 16:48:40,141 - INFO - 文章 900186 回應狀態碼: 200
# 2025-02-02 16:48:40,142 - INFO - 文章 900187 不符合條件或解析失敗
# 2025-02-02 16:48:40,143 - INFO - 文章 900186 不符合條件或解析失敗
# 2025-02-02 16:48:40,144 - INFO - 文章 900184 回應狀態碼: 200
# 2025-02-02 16:48:40,146 - INFO - 文章 900184 不符合條件或解析失敗
# 處理文章:   1%|▏         | 205/15021 [00:40<51:50,  4.76it/s]2025-02-02 16:48:40,461 - INFO - 正在抓取文章 900189
# 2025-02-02 16:48:40,461 - INFO - 正在抓取文章 900191
# 2025-02-02 16:48:40,462 - INFO - 正在抓取文章 900190
# 2025-02-02 16:48:40,463 - INFO - 正在抓取文章 900188
# 2025-02-02 16:48:40,472 - INFO - 文章 900189 回應狀態碼: 200
# 2025-02-02 16:48:40,473 - INFO - 文章 900189 不符合條件或解析失敗
# 2025-02-02 16:48:40,474 - INFO - 文章 900191 回應狀態碼: 200
# 2025-02-02 16:48:40,476 - INFO - 文章 900191 不符合條件或解析失敗
# 2025-02-02 16:48:40,477 - INFO - 文章 900190 回應狀態碼: 200
# 2025-02-02 16:48:40,478 - INFO - 文章 900188 回應狀態碼: 200
# 2025-02-02 16:48:40,479 - INFO - 文章 900190 不符合條件或解析失敗
# 2025-02-02 16:48:40,481 - INFO - 文章 900188 不符合條件或解析失敗
# 處理文章:   1%|▏         | 209/15021 [00:40<41:55,  5.89it/s]2025-02-02 16:48:41,640 - INFO - 正在抓取文章 900192
# 2025-02-02 16:48:41,641 - INFO - 正在抓取文章 900194
# 2025-02-02 16:48:41,641 - INFO - 正在抓取文章 900195
# 2025-02-02 16:48:41,641 - INFO - 正在抓取文章 900193
# 2025-02-02 16:48:41,641 - INFO - 文章 900192 回應狀態碼: 200
# 2025-02-02 16:48:41,641 - INFO - 文章 900192 不符合條件或解析失敗
# 處理文章:   1%|▏         | 213/15021 [00:42<51:23,  4.80it/s]2025-02-02 16:48:41,656 - INFO - 文章 900194 回應狀態碼: 200
# 2025-02-02 16:48:41,658 - INFO - 文章 900193 回應狀態碼: 200
# 2025-02-02 16:48:41,659 - INFO - 文章 900194 不符合條件或解析失敗
# 2025-02-02 16:48:41,660 - INFO - 文章 900195 回應狀態碼: 200
# 2025-02-02 16:48:41,661 - INFO - 文章 900193 不符合條件或解析失敗
# 2025-02-02 16:48:41,664 - INFO - 文章 900195 不符合條件或解析失敗
# 2025-02-02 16:48:41,979 - INFO - 正在抓取文章 900196
# 2025-02-02 16:48:41,979 - INFO - 正在抓取文章 900197
# 2025-02-02 16:48:41,979 - INFO - 正在抓取文章 900199
# 2025-02-02 16:48:41,979 - INFO - 正在抓取文章 900198
# 2025-02-02 16:48:41,993 - INFO - 文章 900196 回應狀態碼: 200
# 2025-02-02 16:48:41,994 - INFO - 文章 900197 回應狀態碼: 200
# 2025-02-02 16:48:41,995 - INFO - 文章 900196 不符合條件或解析失敗
# 處理文章:   1%|▏         | 217/15021 [00:42<42:04,  5.86it/s]2025-02-02 16:48:41,995 - INFO - 文章 900198 回應狀態碼: 200
# 2025-02-02 16:48:41,996 - INFO - 文章 900199 回應狀態碼: 200
# 2025-02-02 16:48:41,997 - INFO - 文章 900197 不符合條件或解析失敗
# 2025-02-02 16:48:41,999 - INFO - 文章 900198 不符合條件或解析失敗
# 2025-02-02 16:48:42,000 - INFO - 文章 900199 不符合條件或解析失敗
# 2025-02-02 16:48:43,166 - INFO - 正在抓取文章 900202
# 2025-02-02 16:48:43,166 - INFO - 正在抓取文章 900200
# 2025-02-02 16:48:43,166 - INFO - 正在抓取文章 900201
# 2025-02-02 16:48:43,167 - INFO - 正在抓取文章 900203
# 2025-02-02 16:48:43,178 - INFO - 文章 900202 回應狀態碼: 200
# 2025-02-02 16:48:43,179 - INFO - 文章 900202 不符合條件或解析失敗
# 2025-02-02 16:48:43,180 - INFO - 文章 900201 回應狀態碼: 200
# 2025-02-02 16:48:43,181 - INFO - 文章 900201 不符合條件或解析失敗
# 2025-02-02 16:48:43,182 - INFO - 文章 900200 回應狀態碼: 200
# 2025-02-02 16:48:43,184 - INFO - 文章 900200 不符合條件或解析失敗
# 2025-02-02 16:48:43,185 - INFO - 文章 900203 回應狀態碼: 200
# 處理文章:   1%|▏         | 221/15021 [00:43<51:36,  4.78it/s]2025-02-02 16:48:43,187 - INFO - 文章 900203 不符合條件或解析失敗
# 2025-02-02 16:48:43,503 - INFO - 正在抓取文章 900205
# 2025-02-02 16:48:43,503 - INFO - 正在抓取文章 900204
# 2025-02-02 16:48:43,503 - INFO - 正在抓取文章 900206
# 2025-02-02 16:48:43,503 - INFO - 正在抓取文章 900207
# 2025-02-02 16:48:43,518 - INFO - 文章 900206 回應狀態碼: 200
# 2025-02-02 16:48:43,519 - INFO - 文章 900204 回應狀態碼: 200
# 2025-02-02 16:48:43,520 - INFO - 文章 900206 不符合條件或解析失敗
# 2025-02-02 16:48:43,521 - INFO - 文章 900204 不符合條件或解析失敗
# 處理文章:   1%|▏         | 225/15021 [00:44<42:12,  5.84it/s]2025-02-02 16:48:43,524 - INFO - 文章 900207 回應狀態碼: 200
# 2025-02-02 16:48:43,525 - INFO - 文章 900207 不符合條件或解析失敗
# 2025-02-02 16:48:43,538 - INFO - 文章 900205 回應狀態碼: 200
# 2025-02-02 16:48:43,603 - INFO - 文章 900205 不符合條件或解析失敗
# 2025-02-02 16:48:44,688 - INFO - 正在抓取文章 900209
# 2025-02-02 16:48:44,688 - INFO - 正在抓取文章 900208
# 2025-02-02 16:48:44,689 - INFO - 正在抓取文章 900210
# 2025-02-02 16:48:44,689 - INFO - 正在抓取文章 900211
# 2025-02-02 16:48:44,702 - INFO - 文章 900209 回應狀態碼: 200
# 2025-02-02 16:48:44,702 - INFO - 文章 900208 回應狀態碼: 200
# 2025-02-02 16:48:44,703 - INFO - 文章 900209 不符合條件或解析失敗
# 2025-02-02 16:48:44,704 - INFO - 文章 900208 不符合條件或解析失敗
# 2025-02-02 16:48:44,706 - INFO - 文章 900210 回應狀態碼: 200
# 處理文章:   2%|▏         | 229/15021 [00:45<51:35,  4.78it/s]2025-02-02 16:48:44,707 - INFO - 文章 900211 回應狀態碼: 200
# 2025-02-02 16:48:44,711 - INFO - 文章 900210 不符合條件或解析失敗
# 2025-02-02 16:48:44,712 - INFO - 文章 900211 不符合條件或解析失敗
# 2025-02-02 16:48:45,104 - INFO - 正在抓取文章 900215
# 2025-02-02 16:48:45,105 - INFO - 正在抓取文章 900213
# 2025-02-02 16:48:45,105 - INFO - 正在抓取文章 900212
# 2025-02-02 16:48:45,105 - INFO - 正在抓取文章 900214
# 2025-02-02 16:48:45,120 - INFO - 文章 900213 回應狀態碼: 200
# 2025-02-02 16:48:45,121 - INFO - 文章 900213 不符合條件或解析失敗
# 2025-02-02 16:48:45,122 - INFO - 文章 900212 回應狀態碼: 200
# 2025-02-02 16:48:45,123 - INFO - 文章 900212 不符合條件或解析失敗
# 處理文章:   2%|▏         | 233/15021 [00:45<43:41,  5.64it/s]2025-02-02 16:48:45,140 - INFO - 文章 900215 回應狀態碼: 200
# 2025-02-02 16:48:45,161 - INFO - 文章 900215 不符合條件或解析失敗
# 2025-02-02 16:48:45,162 - INFO - 文章 900214 回應狀態碼: 200
# 2025-02-02 16:48:45,186 - INFO - 文章 900214 不符合條件或解析失敗
# 2025-02-02 16:48:46,214 - INFO - 正在抓取文章 900216
# 2025-02-02 16:48:46,214 - INFO - 正在抓取文章 900217
# 2025-02-02 16:48:46,214 - INFO - 正在抓取文章 900218
# 2025-02-02 16:48:46,214 - INFO - 正在抓取文章 900219
# 2025-02-02 16:48:46,233 - INFO - 文章 900218 回應狀態碼: 200
# 2025-02-02 16:48:46,234 - INFO - 文章 900218 不符合條件或解析失敗
# 2025-02-02 16:48:46,235 - INFO - 文章 900219 回應狀態碼: 200
# 2025-02-02 16:48:46,238 - INFO - 文章 900219 不符合條件或解析失敗
# 2025-02-02 16:48:46,246 - INFO - 文章 900216 回應狀態碼: 200
# 2025-02-02 16:48:46,279 - INFO - 文章 900216 不符合條件或解析失敗
# 處理文章:   2%|▏         | 237/15021 [00:46<51:59,  4.74it/s]2025-02-02 16:48:46,280 - INFO - 文章 900217 回應狀態碼: 200
# 2025-02-02 16:48:46,305 - INFO - 文章 900217 不符合條件或解析失敗
# 2025-02-02 16:48:46,686 - INFO - 正在抓取文章 900220
# 2025-02-02 16:48:46,687 - INFO - 正在抓取文章 900221
# 2025-02-02 16:48:46,687 - INFO - 正在抓取文章 900222
# 2025-02-02 16:48:46,687 - INFO - 正在抓取文章 900223
# 2025-02-02 16:48:46,700 - INFO - 文章 900220 回應狀態碼: 200
# 2025-02-02 16:48:46,700 - INFO - 文章 900221 回應狀態碼: 200
# 2025-02-02 16:48:46,701 - INFO - 文章 900220 不符合條件或解析失敗
# 2025-02-02 16:48:46,702 - INFO - 文章 900221 不符合條件或解析失敗
# 處理文章:   2%|▏         | 241/15021 [00:47<44:11,  5.57it/s]2025-02-02 16:48:46,725 - INFO - 文章 900223 回應狀態碼: 200
# 2025-02-02 16:48:46,751 - INFO - 成功解析文章 900223
# 2025-02-02 16:48:46,753 - INFO - 文章 900222 回應狀態碼: 200
# 2025-02-02 16:48:46,781 - INFO - 成功解析文章 900222
# 處理文章:   2%|▏         | 243/15021 [00:47<39:09,  6.29it/s]2025-02-02 16:48:47,807 - INFO - 正在抓取文章 900225
# 2025-02-02 16:48:47,807 - INFO - 正在抓取文章 900227
# 2025-02-02 16:48:47,807 - INFO - 正在抓取文章 900224
# 2025-02-02 16:48:47,807 - INFO - 正在抓取文章 900226
# 2025-02-02 16:48:47,820 - INFO - 文章 900225 回應狀態碼: 200
# 2025-02-02 16:48:47,821 - INFO - 文章 900225 不符合條件或解析失敗
# 2025-02-02 16:48:47,823 - INFO - 文章 900227 回應狀態碼: 200
# 2025-02-02 16:48:47,823 - INFO - 文章 900224 回應狀態碼: 200
# 2025-02-02 16:48:47,824 - INFO - 文章 900227 不符合條件或解析失敗
# 2025-02-02 16:48:47,826 - INFO - 文章 900224 不符合條件或解析失敗
# 處理文章:   2%|▏         | 245/15021 [00:48<55:59,  4.40it/s]2025-02-02 16:48:47,844 - INFO - 文章 900226 回應狀態碼: 200
# 2025-02-02 16:48:47,875 - INFO - 文章 900226 不符合條件或解析失敗
# 2025-02-02 16:48:48,251 - INFO - 正在抓取文章 900228
# 2025-02-02 16:48:48,251 - INFO - 正在抓取文章 900230
# 2025-02-02 16:48:48,251 - INFO - 正在抓取文章 900229
# 2025-02-02 16:48:48,251 - INFO - 正在抓取文章 900231
# 2025-02-02 16:48:48,261 - INFO - 文章 900230 回應狀態碼: 200
# 2025-02-02 16:48:48,261 - INFO - 文章 900228 回應狀態碼: 200
# 2025-02-02 16:48:48,261 - INFO - 文章 900230 不符合條件或解析失敗
# 2025-02-02 16:48:48,261 - INFO - 文章 900228 不符合條件或解析失敗
# 處理文章:   2%|▏         | 249/15021 [00:48<45:27,  5.42it/s]2025-02-02 16:48:48,261 - INFO - 文章 900229 回應狀態碼: 200
# 2025-02-02 16:48:48,269 - INFO - 文章 900231 回應狀態碼: 200
# 2025-02-02 16:48:48,271 - INFO - 文章 900229 不符合條件或解析失敗
# 2025-02-02 16:48:48,272 - INFO - 文章 900231 不符合條件或解析失敗
# 2025-02-02 16:48:49,376 - INFO - 正在抓取文章 900234
# 2025-02-02 16:48:49,376 - INFO - 正在抓取文章 900233
# 2025-02-02 16:48:49,376 - INFO - 正在抓取文章 900235
# 2025-02-02 16:48:49,383 - INFO - 正在抓取文章 900232
# 2025-02-02 16:48:49,388 - INFO - 文章 900234 回應狀態碼: 200
# 2025-02-02 16:48:49,389 - INFO - 文章 900234 不符合條件或解析失敗
# 2025-02-02 16:48:49,390 - INFO - 文章 900233 回應狀態碼: 200
# 2025-02-02 16:48:49,391 - INFO - 文章 900235 回應狀態碼: 200
# 2025-02-02 16:48:49,392 - INFO - 文章 900233 不符合條件或解析失敗
# 2025-02-02 16:48:49,393 - INFO - 文章 900235 不符合條件或解析失敗
# 2025-02-02 16:48:49,394 - INFO - 文章 900232 回應狀態碼: 200
# 2025-02-02 16:48:49,397 - INFO - 文章 900232 不符合條件或解析失敗
# 處理文章:   2%|▏         | 253/15021 [00:49<53:40,  4.59it/s]2025-02-02 16:48:49,761 - INFO - 正在抓取文章 900236
# 2025-02-02 16:48:49,761 - INFO - 正在抓取文章 900239
# 2025-02-02 16:48:49,762 - INFO - 正在抓取文章 900237
# 2025-02-02 16:48:49,762 - INFO - 正在抓取文章 900238
# 2025-02-02 16:48:49,776 - INFO - 文章 900239 回應狀態碼: 200
# 2025-02-02 16:48:49,777 - INFO - 文章 900239 不符合條件或解析失敗
# 2025-02-02 16:48:49,778 - INFO - 文章 900237 回應狀態碼: 200
# 2025-02-02 16:48:49,779 - INFO - 文章 900237 不符合條件或解析失敗
# 2025-02-02 16:48:49,780 - INFO - 文章 900238 回應狀態碼: 200
# 2025-02-02 16:48:49,782 - INFO - 文章 900238 不符合條件或解析失敗
# 2025-02-02 16:48:49,793 - INFO - 文章 900236 回應狀態碼: 200
# 2025-02-02 16:48:49,818 - INFO - 文章 900236 不符合條件或解析失敗
# 處理文章:   2%|▏         | 257/15021 [00:50<44:31,  5.53it/s]2025-02-02 16:48:50,897 - INFO - 正在抓取文章 900241
# 2025-02-02 16:48:50,897 - INFO - 正在抓取文章 900243
# 2025-02-02 16:48:50,897 - INFO - 正在抓取文章 900242
# 2025-02-02 16:48:50,897 - INFO - 正在抓取文章 900240
# 2025-02-02 16:48:50,914 - INFO - 文章 900243 回應狀態碼: 200
# 2025-02-02 16:48:50,915 - INFO - 文章 900242 回應狀態碼: 200
# 2025-02-02 16:48:50,915 - INFO - 文章 900240 回應狀態碼: 200
# 2025-02-02 16:48:50,916 - INFO - 文章 900243 不符合條件或解析失敗
# 2025-02-02 16:48:50,917 - INFO - 文章 900242 不符合條件或解析失敗
# 2025-02-02 16:48:50,919 - INFO - 文章 900240 不符合條件或解析失敗
# 處理文章:   2%|▏         | 261/15021 [00:51<51:58,  4.73it/s]2025-02-02 16:48:50,935 - INFO - 文章 900241 回應狀態碼: 200
# 2025-02-02 16:48:50,958 - INFO - 文章 900241 不符合條件或解析失敗
# 2025-02-02 16:48:51,279 - INFO - 正在抓取文章 900246
# 2025-02-02 16:48:51,279 - INFO - 正在抓取文章 900247
# 2025-02-02 16:48:51,279 - INFO - 正在抓取文章 900245
# 2025-02-02 16:48:51,279 - INFO - 正在抓取文章 900244
# 2025-02-02 16:48:51,280 - INFO - 文章 900246 回應狀態碼: 200
# 2025-02-02 16:48:51,280 - INFO - 文章 900246 不符合條件或解析失敗
# 2025-02-02 16:48:51,280 - INFO - 文章 900247 回應狀態碼: 200
# 2025-02-02 16:48:51,295 - INFO - 文章 900247 不符合條件或解析失敗
# 2025-02-02 16:48:51,297 - INFO - 文章 900245 回應狀態碼: 200
# 2025-02-02 16:48:51,298 - INFO - 文章 900244 回應狀態碼: 200
# 2025-02-02 16:48:51,299 - INFO - 文章 900245 不符合條件或解析失敗
# 2025-02-02 16:48:51,300 - INFO - 文章 900244 不符合條件或解析失敗
# 處理文章:   2%|▏         | 265/15021 [00:51<42:59,  5.72it/s]2025-02-02 16:48:52,421 - INFO - 正在抓取文章 900251
# 2025-02-02 16:48:52,421 - INFO - 正在抓取文章 900250
# 2025-02-02 16:48:52,421 - INFO - 正在抓取文章 900249
# 2025-02-02 16:48:52,434 - INFO - 正在抓取文章 900248
# 2025-02-02 16:48:52,436 - INFO - 文章 900250 回應狀態碼: 200
# 2025-02-02 16:48:52,437 - INFO - 文章 900251 回應狀態碼: 200
# 2025-02-02 16:48:52,443 - INFO - 文章 900249 回應狀態碼: 200
# 2025-02-02 16:48:52,448 - INFO - 文章 900250 不符合條件或解析失敗
# 2025-02-02 16:48:52,451 - INFO - 文章 900251 不符合條件或解析失敗
# 2025-02-02 16:48:52,455 - INFO - 文章 900249 不符合條件或解析失敗
# 2025-02-02 16:48:52,456 - INFO - 文章 900248 回應狀態碼: 200
# 2025-02-02 16:48:52,461 - INFO - 文章 900248 不符合條件或解析失敗
# 處理文章:   2%|▏         | 269/15021 [00:52<51:44,  4.75it/s]2025-02-02 16:48:52,781 - INFO - 正在抓取文章 900252
# 2025-02-02 16:48:52,781 - INFO - 正在抓取文章 900253
# 2025-02-02 16:48:52,781 - INFO - 正在抓取文章 900255
# 2025-02-02 16:48:52,782 - INFO - 正在抓取文章 900254
# 2025-02-02 16:48:52,795 - INFO - 文章 900252 回應狀態碼: 200
# 2025-02-02 16:48:52,796 - INFO - 文章 900252 不符合條件或解析失敗
# 處理文章:   2%|▏         | 273/15021 [00:53<42:10,  5.83it/s]2025-02-02 16:48:52,798 - INFO - 文章 900253 回應狀態碼: 200
# 2025-02-02 16:48:52,799 - INFO - 文章 900255 回應狀態碼: 200
# 2025-02-02 16:48:52,801 - INFO - 文章 900254 回應狀態碼: 200
# 2025-02-02 16:48:52,801 - INFO - 文章 900253 不符合條件或解析失敗
# 2025-02-02 16:48:52,802 - INFO - 文章 900255 不符合條件或解析失敗
# 2025-02-02 16:48:52,804 - INFO - 文章 900254 不符合條件或解析失敗
# 2025-02-02 16:48:53,960 - INFO - 正在抓取文章 900257
# 2025-02-02 16:48:53,960 - INFO - 正在抓取文章 900259
# 2025-02-02 16:48:53,960 - INFO - 正在抓取文章 900256
# 2025-02-02 16:48:53,960 - INFO - 正在抓取文章 900258
# 2025-02-02 16:48:53,975 - INFO - 文章 900257 回應狀態碼: 200
# 2025-02-02 16:48:53,976 - INFO - 文章 900259 回應狀態碼: 200
# 2025-02-02 16:48:53,977 - INFO - 文章 900257 不符合條件或解析失敗
# 2025-02-02 16:48:53,978 - INFO - 文章 900256 回應狀態碼: 200
# 2025-02-02 16:48:53,979 - INFO - 文章 900258 回應狀態碼: 200
# 2025-02-02 16:48:53,981 - INFO - 文章 900259 不符合條件或解析失敗
# 2025-02-02 16:48:53,984 - INFO - 文章 900256 不符合條件或解析失敗
# 2025-02-02 16:48:53,986 - INFO - 文章 900258 不符合條件或解析失敗
# 處理文章:   2%|▏         | 277/15021 [00:54<51:37,  4.76it/s]2025-02-02 16:48:54,305 - INFO - 正在抓取文章 900263
# 2025-02-02 16:48:54,305 - INFO - 正在抓取文章 900262
# 2025-02-02 16:48:54,305 - INFO - 正在抓取文章 900261
# 2025-02-02 16:48:54,306 - INFO - 正在抓取文章 900260
# 2025-02-02 16:48:54,318 - INFO - 文章 900263 回應狀態碼: 200
# 2025-02-02 16:48:54,320 - INFO - 文章 900263 不符合條件或解析失敗
# 2025-02-02 16:48:54,321 - INFO - 文章 900261 回應狀態碼: 200
# ...
# 2025-02-02 17:07:55,333 - INFO - 文章 905959 不符合條件或解析失敗
# 2025-02-02 17:07:55,334 - INFO - 文章 905960 不符合條件或解析失敗
# 2025-02-02 17:07:55,339 - INFO - 文章 905961 回應狀態碼: 200
# 2025-02-02 17:07:55,340 - INFO - 文章 905961 不符合條件或解析失敗
# 2025-02-02 17:07:55,347 - INFO - 文章 905958 回應狀態碼: 200
# 2025-02-02 17:07:55,348 - INFO - 文章 905958 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5979/15021 [19:55<30:19,  4.97it/s]2025-02-02 17:07:55,850 - INFO - 正在抓取文章 905965
# 2025-02-02 17:07:55,851 - INFO - 正在抓取文章 905964
# 2025-02-02 17:07:55,853 - INFO - 正在抓取文章 905963
# 2025-02-02 17:07:55,853 - INFO - 正在抓取文章 905962
# 2025-02-02 17:07:55,853 - INFO - 文章 905965 回應狀態碼: 200
# 2025-02-02 17:07:55,853 - INFO - 文章 905965 不符合條件或解析失敗
# 2025-02-02 17:07:55,853 - INFO - 文章 905964 回應狀態碼: 200
# 2025-02-02 17:07:55,853 - INFO - 文章 905964 不符合條件或解析失敗
# 2025-02-02 17:07:55,868 - INFO - 文章 905963 回應狀態碼: 200
# 2025-02-02 17:07:55,868 - INFO - 文章 905963 不符合條件或解析失敗
# 2025-02-02 17:07:55,868 - INFO - 文章 905962 回應狀態碼: 200
# 2025-02-02 17:07:55,868 - INFO - 文章 905962 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5983/15021 [19:56<27:05,  5.56it/s]2025-02-02 17:07:56,838 - INFO - 正在抓取文章 905968
# 2025-02-02 17:07:56,840 - INFO - 正在抓取文章 905969
# 2025-02-02 17:07:56,848 - INFO - 正在抓取文章 905966
# 2025-02-02 17:07:56,850 - INFO - 正在抓取文章 905967
# 2025-02-02 17:07:56,864 - INFO - 文章 905968 回應狀態碼: 200
# 2025-02-02 17:07:56,865 - INFO - 文章 905967 回應狀態碼: 200
# 2025-02-02 17:07:56,866 - INFO - 文章 905966 回應狀態碼: 200
# 2025-02-02 17:07:56,868 - INFO - 文章 905968 不符合條件或解析失敗
# 2025-02-02 17:07:56,869 - INFO - 文章 905967 不符合條件或解析失敗
# 2025-02-02 17:07:56,870 - INFO - 文章 905966 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5987/15021 [19:57<30:17,  4.97it/s]2025-02-02 17:07:57,022 - INFO - 文章 905969 回應狀態碼: 200
# 2025-02-02 17:07:57,043 - INFO - 文章 905969 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5990/15021 [19:57<24:59,  6.02it/s]2025-02-02 17:07:57,353 - INFO - 正在抓取文章 905972
# 2025-02-02 17:07:57,353 - INFO - 正在抓取文章 905971
# 2025-02-02 17:07:57,354 - INFO - 正在抓取文章 905973
# 2025-02-02 17:07:57,354 - INFO - 正在抓取文章 905970
# 2025-02-02 17:07:57,396 - INFO - 文章 905971 回應狀態碼: 200
# 2025-02-02 17:07:57,426 - INFO - 文章 905971 不符合條件或解析失敗
# 2025-02-02 17:07:57,429 - INFO - 文章 905972 回應狀態碼: 200
# 2025-02-02 17:07:57,430 - INFO - 文章 905973 回應狀態碼: 200
# 2025-02-02 17:07:57,430 - INFO - 文章 905970 回應狀態碼: 200
# 2025-02-02 17:07:57,464 - INFO - 文章 905972 不符合條件或解析失敗
# 2025-02-02 17:07:57,502 - INFO - 成功解析文章 905973
# 2025-02-02 17:07:57,531 - INFO - 文章 905970 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5994/15021 [19:58<23:46,  6.33it/s]2025-02-02 17:07:58,372 - INFO - 正在抓取文章 905977
# 2025-02-02 17:07:58,372 - INFO - 正在抓取文章 905974
# 2025-02-02 17:07:58,373 - INFO - 正在抓取文章 905975
# 2025-02-02 17:07:58,374 - INFO - 正在抓取文章 905976
# 2025-02-02 17:07:58,397 - INFO - 文章 905977 回應狀態碼: 200
# 2025-02-02 17:07:58,397 - INFO - 文章 905975 回應狀態碼: 200
# 2025-02-02 17:07:58,399 - INFO - 文章 905974 回應狀態碼: 200
# 2025-02-02 17:07:58,399 - INFO - 文章 905977 不符合條件或解析失敗
# 2025-02-02 17:07:58,401 - INFO - 文章 905975 不符合條件或解析失敗
# 2025-02-02 17:07:58,402 - INFO - 文章 905976 回應狀態碼: 200
# 2025-02-02 17:07:58,403 - INFO - 文章 905974 不符合條件或解析失敗
# 2025-02-02 17:07:58,406 - INFO - 文章 905976 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5995/15021 [19:58<33:51,  4.44it/s]2025-02-02 17:07:59,032 - INFO - 正在抓取文章 905981
# 2025-02-02 17:07:59,032 - INFO - 正在抓取文章 905979
# 2025-02-02 17:07:59,032 - INFO - 正在抓取文章 905978
# 2025-02-02 17:07:59,032 - INFO - 正在抓取文章 905980
# 2025-02-02 17:07:59,046 - INFO - 文章 905981 回應狀態碼: 200
# 2025-02-02 17:07:59,048 - INFO - 文章 905981 不符合條件或解析失敗
# 2025-02-02 17:07:59,055 - INFO - 文章 905978 回應狀態碼: 200
# 2025-02-02 17:07:59,055 - INFO - 文章 905980 回應狀態碼: 200
# 2025-02-02 17:07:59,056 - INFO - 文章 905978 不符合條件或解析失敗
# 2025-02-02 17:07:59,058 - INFO - 文章 905980 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 5999/15021 [19:59<29:52,  5.03it/s]2025-02-02 17:07:59,077 - INFO - 文章 905979 回應狀態碼: 200
# 2025-02-02 17:07:59,118 - INFO - 成功解析文章 905979
# 處理文章:  40%|███▉      | 6000/15021 [19:59<32:07,  4.68it/s]2025-02-02 17:07:59,909 - INFO - 正在抓取文章 905982
# 2025-02-02 17:07:59,909 - INFO - 正在抓取文章 905985
# 2025-02-02 17:07:59,909 - INFO - 正在抓取文章 905983
# 2025-02-02 17:07:59,909 - INFO - 正在抓取文章 905984
# 2025-02-02 17:07:59,921 - INFO - 文章 905982 回應狀態碼: 200
# 2025-02-02 17:07:59,921 - INFO - 文章 905985 回應狀態碼: 200
# 2025-02-02 17:07:59,921 - INFO - 文章 905982 不符合條件或解析失敗
# 2025-02-02 17:07:59,921 - INFO - 文章 905985 不符合條件或解析失敗
# 處理文章:  40%|███▉      | 6003/15021 [20:00<30:26,  4.94it/s]2025-02-02 17:07:59,939 - INFO - 文章 905983 回應狀態碼: 200
# 2025-02-02 17:07:59,940 - INFO - 文章 905983 不符合條件或解析失敗
# 2025-02-02 17:07:59,945 - INFO - 文章 905984 回應狀態碼: 200
# 2025-02-02 17:07:59,946 - INFO - 文章 905984 不符合條件或解析失敗
# 2025-02-02 17:08:00,562 - INFO - 正在抓取文章 905988
# 2025-02-02 17:08:00,562 - INFO - 正在抓取文章 905989
# 2025-02-02 17:08:00,566 - INFO - 正在抓取文章 905986
# 2025-02-02 17:08:00,567 - INFO - 正在抓取文章 905987
# 2025-02-02 17:08:00,586 - INFO - 文章 905986 回應狀態碼: 200
# 2025-02-02 17:08:00,587 - INFO - 文章 905988 回應狀態碼: 200
# 2025-02-02 17:08:00,588 - INFO - 文章 905986 不符合條件或解析失敗
# 2025-02-02 17:08:00,588 - INFO - 文章 905989 回應狀態碼: 200
# 處理文章:  40%|███▉      | 6007/15021 [20:01<28:18,  5.31it/s]2025-02-02 17:08:00,588 - INFO - 文章 905987 回應狀態碼: 200
# 2025-02-02 17:08:00,588 - INFO - 文章 905988 不符合條件或解析失敗
# 2025-02-02 17:08:00,592 - INFO - 文章 905989 不符合條件或解析失敗
# 2025-02-02 17:08:00,592 - INFO - 文章 905987 不符合條件或解析失敗
# 2025-02-02 17:08:01,422 - INFO - 正在抓取文章 905990
# 2025-02-02 17:08:01,426 - INFO - 正在抓取文章 905991
# 2025-02-02 17:08:01,427 - INFO - 正在抓取文章 905993
# 2025-02-02 17:08:01,427 - INFO - 正在抓取文章 905992
# 2025-02-02 17:08:01,427 - INFO - 文章 905990 回應狀態碼: 200
# 2025-02-02 17:08:01,427 - INFO - 文章 905990 不符合條件或解析失敗
# 處理文章:  40%|████      | 6011/15021 [20:01<29:34,  5.08it/s]2025-02-02 17:08:01,444 - INFO - 文章 905991 回應狀態碼: 200
# 2025-02-02 17:08:01,445 - INFO - 文章 905993 回應狀態碼: 200
# 2025-02-02 17:08:01,445 - INFO - 文章 905992 回應狀態碼: 200
# 2025-02-02 17:08:01,446 - INFO - 文章 905991 不符合條件或解析失敗
# 2025-02-02 17:08:01,448 - INFO - 文章 905993 不符合條件或解析失敗
# 2025-02-02 17:08:01,449 - INFO - 文章 905992 不符合條件或解析失敗
# 2025-02-02 17:08:02,092 - INFO - 正在抓取文章 905994
# 2025-02-02 17:08:02,093 - INFO - 正在抓取文章 905996
# 2025-02-02 17:08:02,093 - INFO - 正在抓取文章 905995
# 2025-02-02 17:08:02,093 - INFO - 正在抓取文章 905997
# 2025-02-02 17:08:02,121 - INFO - 文章 905994 回應狀態碼: 200
# 2025-02-02 17:08:02,129 - INFO - 文章 905994 不符合條件或解析失敗
# 處理文章:  40%|████      | 6015/15021 [20:02<28:19,  5.30it/s]2025-02-02 17:08:02,132 - INFO - 文章 905995 回應狀態碼: 200
# 2025-02-02 17:08:02,135 - INFO - 文章 905995 不符合條件或解析失敗
# 2025-02-02 17:08:02,137 - INFO - 文章 905997 回應狀態碼: 200
# 2025-02-02 17:08:02,143 - INFO - 文章 905997 不符合條件或解析失敗
# 2025-02-02 17:08:02,303 - INFO - 文章 905996 回應狀態碼: 200
# 2025-02-02 17:08:02,342 - INFO - 文章 905996 不符合條件或解析失敗
# 處理文章:  40%|████      | 6017/15021 [20:02<25:53,  5.80it/s]2025-02-02 17:08:02,952 - INFO - 正在抓取文章 906001
# 2025-02-02 17:08:02,952 - INFO - 正在抓取文章 905998
# 2025-02-02 17:08:02,952 - INFO - 正在抓取文章 906000
# 2025-02-02 17:08:02,952 - INFO - 正在抓取文章 905999
# 2025-02-02 17:08:02,959 - INFO - 文章 906001 回應狀態碼: 200
# 2025-02-02 17:08:02,959 - INFO - 文章 906000 回應狀態碼: 200
# 2025-02-02 17:08:02,959 - INFO - 文章 905998 回應狀態碼: 200
# 2025-02-02 17:08:02,959 - INFO - 文章 906001 不符合條件或解析失敗
# 2025-02-02 17:08:02,959 - INFO - 文章 906000 不符合條件或解析失敗
# 2025-02-02 17:08:02,959 - INFO - 文章 905999 回應狀態碼: 200
# 2025-02-02 17:08:02,975 - INFO - 文章 905998 不符合條件或解析失敗
# 2025-02-02 17:08:02,983 - INFO - 文章 905999 不符合條件或解析失敗
# 處理文章:  40%|████      | 6018/15021 [20:03<30:00,  5.00it/s]
# 2025-02-02 17:08:03,641 - INFO - 正在抓取文章 906002
# 2025-02-02 17:08:03,643 - INFO - 正在抓取文章 906003
# 2025-02-02 17:08:03,643 - INFO - 正在抓取文章 906004
# 2025-02-02 17:08:03,645 - INFO - 正在抓取文章 906005
# 2025-02-02 17:08:03,660 - INFO - 文章 906002 回應狀態碼: 200
# 2025-02-02 17:08:03,661 - INFO - 文章 906002 不符合條件或解析失敗
# 2025-02-02 17:08:03,662 - INFO - 文章 906003 回應狀態碼: 200
# 2025-02-02 17:08:03,663 - INFO - 文章 906003 不符合條件或解析失敗
# 2025-02-02 17:08:03,668 - INFO - 文章 906005 回應狀態碼: 200
# 2025-02-02 17:08:03,669 - INFO - 文章 906004 回應狀態碼: 200
# 2025-02-02 17:08:03,669 - INFO - 文章 906005 不符合條件或解析失敗
# 2025-02-02 17:08:03,671 - INFO - 文章 906004 不符合條件或解析失敗
# 2025-02-02 17:08:04,483 - INFO - 正在抓取文章 906006
# 2025-02-02 17:08:04,483 - INFO - 正在抓取文章 906009
# 2025-02-02 17:08:04,484 - INFO - 正在抓取文章 906008
# 2025-02-02 17:08:04,484 - INFO - 正在抓取文章 906007
# 2025-02-02 17:08:04,492 - INFO - 文章 906009 回應狀態碼: 200
# 2025-02-02 17:08:04,492 - INFO - 文章 906009 不符合條件或解析失敗
# 2025-02-02 17:08:04,492 - INFO - 文章 906006 回應狀態碼: 200
# 2025-02-02 17:08:04,492 - INFO - 文章 906006 不符合條件或解析失敗
# 2025-02-02 17:08:04,492 - INFO - 文章 906007 回應狀態碼: 200
# 2025-02-02 17:08:04,492 - INFO - 文章 906008 回應狀態碼: 200
# 2025-02-02 17:08:04,492 - INFO - 文章 906007 不符合條件或解析失敗
# 2025-02-02 17:08:04,492 - INFO - 文章 906008 不符合條件或解析失敗
# 2025-02-02 17:08:05,172 - INFO - 正在抓取文章 906010
# 2025-02-02 17:08:05,175 - INFO - 正在抓取文章 906011
# 2025-02-02 17:08:05,178 - INFO - 正在抓取文章 906012
# 2025-02-02 17:08:05,179 - INFO - 正在抓取文章 906013
# 2025-02-02 17:08:05,179 - INFO - 文章 906010 回應狀態碼: 200
# 2025-02-02 17:08:05,179 - INFO - 文章 906010 不符合條件或解析失敗
# 2025-02-02 17:08:05,192 - INFO - 文章 906011 回應狀態碼: 200
# 2025-02-02 17:08:05,193 - INFO - 文章 906011 不符合條件或解析失敗
# 2025-02-02 17:08:05,194 - INFO - 文章 906013 回應狀態碼: 200
# 2025-02-02 17:08:05,195 - INFO - 文章 906013 不符合條件或解析失敗
# 2025-02-02 17:08:05,217 - INFO - 文章 906012 回應狀態碼: 200
# 2025-02-02 17:08:05,239 - INFO - 文章 906012 不符合條件或解析失敗
# 2025-02-02 17:08:05,993 - INFO - 正在抓取文章 906016
# 2025-02-02 17:08:05,993 - INFO - 正在抓取文章 906017
# 2025-02-02 17:08:05,993 - INFO - 正在抓取文章 906015
# 2025-02-02 17:08:05,999 - INFO - 正在抓取文章 906014
# 2025-02-02 17:08:06,011 - INFO - 文章 906016 回應狀態碼: 200
# 2025-02-02 17:08:06,017 - INFO - 文章 906017 回應狀態碼: 200
# 2025-02-02 17:08:06,018 - INFO - 文章 906016 不符合條件或解析失敗
# 2025-02-02 17:08:06,020 - INFO - 文章 906017 不符合條件或解析失敗
# 2025-02-02 17:08:06,022 - INFO - 文章 906015 回應狀態碼: 200
# 2025-02-02 17:08:06,027 - INFO - 文章 906014 回應狀態碼: 200
# 2025-02-02 17:08:06,027 - INFO - 文章 906015 不符合條件或解析失敗
# 2025-02-02 17:08:06,030 - INFO - 文章 906014 不符合條件或解析失敗
# 2025-02-02 17:08:06,679 - INFO - 正在抓取文章 906021
# 2025-02-02 17:08:06,679 - INFO - 正在抓取文章 906019
# 2025-02-02 17:08:06,679 - INFO - 正在抓取文章 906020
# 2025-02-02 17:08:06,679 - INFO - 正在抓取文章 906018
# 2025-02-02 17:08:06,700 - INFO - 文章 906021 回應狀態碼: 200
# 2025-02-02 17:08:06,701 - INFO - 文章 906018 回應狀態碼: 200
# 2025-02-02 17:08:06,701 - INFO - 文章 906020 回應狀態碼: 200
# 2025-02-02 17:08:06,702 - INFO - 文章 906019 回應狀態碼: 200
# 2025-02-02 17:08:06,703 - INFO - 文章 906021 不符合條件或解析失敗
# 2025-02-02 17:08:06,704 - INFO - 文章 906018 不符合條件或解析失敗
# 2025-02-02 17:08:06,705 - INFO - 文章 906020 不符合條件或解析失敗
# 2025-02-02 17:08:06,707 - INFO - 文章 906019 不符合條件或解析失敗
# 2025-02-02 17:08:07,523 - INFO - 正在抓取文章 906023
# 2025-02-02 17:08:07,523 - INFO - 正在抓取文章 906022
# 2025-02-02 17:08:07,523 - INFO - 正在抓取文章 906025
# 2025-02-02 17:08:07,523 - INFO - 正在抓取文章 906024
# 2025-02-02 17:08:07,535 - INFO - 文章 906023 回應狀態碼: 200
# 2025-02-02 17:08:07,536 - INFO - 文章 906023 不符合條件或解析失敗
# 2025-02-02 17:08:07,537 - INFO - 文章 906022 回應狀態碼: 200
# 2025-02-02 17:08:07,538 - INFO - 文章 906022 不符合條件或解析失敗
# 2025-02-02 17:08:07,542 - INFO - 文章 906024 回應狀態碼: 200
# 2025-02-02 17:08:07,544 - INFO - 文章 906024 不符合條件或解析失敗
# 2025-02-02 17:08:07,564 - INFO - 文章 906025 回應狀態碼: 200
# 2025-02-02 17:08:07,586 - INFO - 文章 906025 不符合條件或解析失敗
# 2025-02-02 17:08:08,211 - INFO - 正在抓取文章 906027
# 2025-02-02 17:08:08,211 - INFO - 正在抓取文章 906029
# 2025-02-02 17:08:08,211 - INFO - 正在抓取文章 906026
# 2025-02-02 17:08:08,211 - INFO - 正在抓取文章 906028
# 2025-02-02 17:08:08,212 - INFO - 文章 906027 回應狀態碼: 200
# 2025-02-02 17:08:08,212 - INFO - 文章 906029 回應狀態碼: 200
# 2025-02-02 17:08:08,212 - INFO - 文章 906027 不符合條件或解析失敗
# 2025-02-02 17:08:08,212 - INFO - 文章 906029 不符合條件或解析失敗
# 2025-02-02 17:08:08,228 - INFO - 文章 906026 回應狀態碼: 200
# 2025-02-02 17:08:08,228 - INFO - 文章 906028 回應狀態碼: 200
# 2025-02-02 17:08:08,228 - INFO - 文章 906026 不符合條件或解析失敗
# 2025-02-02 17:08:08,228 - INFO - 文章 906028 不符合條件或解析失敗
# 2025-02-02 17:08:09,045 - INFO - 正在抓取文章 906031
# 2025-02-02 17:08:09,053 - INFO - 正在抓取文章 906032
# 2025-02-02 17:08:09,054 - INFO - 正在抓取文章 906033
# 2025-02-02 17:08:09,056 - INFO - 文章 906031 回應狀態碼: 200
# 2025-02-02 17:08:09,057 - INFO - 文章 906031 不符合條件或解析失敗
# 2025-02-02 17:08:09,060 - INFO - 正在抓取文章 906030
# 2025-02-02 17:08:09,065 - INFO - 文章 906032 回應狀態碼: 200
# 2025-02-02 17:08:09,065 - INFO - 文章 906033 回應狀態碼: 200
# 2025-02-02 17:08:09,066 - INFO - 文章 906032 不符合條件或解析失敗
# 2025-02-02 17:08:09,067 - INFO - 文章 906033 不符合條件或解析失敗
# 2025-02-02 17:08:09,073 - INFO - 文章 906030 回應狀態碼: 200
# 2025-02-02 17:08:09,075 - INFO - 文章 906030 不符合條件或解析失敗
# 2025-02-02 17:08:09,712 - INFO - 正在抓取文章 906036
# 2025-02-02 17:08:09,713 - INFO - 正在抓取文章 906035
# 2025-02-02 17:08:09,714 - INFO - 正在抓取文章 906037
# 2025-02-02 17:08:09,714 - INFO - 文章 906036 回應狀態碼: 200
# 2025-02-02 17:08:09,714 - INFO - 文章 906036 不符合條件或解析失敗
# 2025-02-02 17:08:09,729 - INFO - 正在抓取文章 906034
# 2025-02-02 17:08:09,732 - INFO - 文章 906037 回應狀態碼: 200
# 2025-02-02 17:08:09,733 - INFO - 文章 906037 不符合條件或解析失敗
# 2025-02-02 17:08:09,733 - INFO - 文章 906035 回應狀態碼: 200
# 2025-02-02 17:08:09,735 - INFO - 文章 906035 不符合條件或解析失敗
# 2025-02-02 17:08:09,742 - INFO - 文章 906034 回應狀態碼: 200
# 2025-02-02 17:08:09,743 - INFO - 文章 906034 不符合條件或解析失敗
# 2025-02-02 17:08:10,558 - INFO - 正在抓取文章 906041
# 2025-02-02 17:08:10,558 - INFO - 正在抓取文章 906040
# 2025-02-02 17:08:10,558 - INFO - 正在抓取文章 906039
# 2025-02-02 17:08:10,582 - INFO - 文章 906039 回應狀態碼: 200
# 2025-02-02 17:08:10,583 - INFO - 文章 906039 不符合條件或解析失敗
# 2025-02-02 17:08:10,588 - INFO - 正在抓取文章 906038
# 2025-02-02 17:08:10,799 - INFO - 文章 906038 回應狀態碼: 200
# 2025-02-02 17:08:10,799 - INFO - 文章 906038 不符合條件或解析失敗
# 2025-02-02 17:08:10,815 - INFO - 文章 906040 回應狀態碼: 200
# 2025-02-02 17:08:10,816 - INFO - 文章 906041 回應狀態碼: 200
# 2025-02-02 17:08:10,839 - INFO - 文章 906040 不符合條件或解析失敗
# 2025-02-02 17:08:10,987 - INFO - 成功解析文章 906041
# 2025-02-02 17:08:11,215 - INFO - 正在抓取文章 906045
# 2025-02-02 17:08:11,215 - INFO - 正在抓取文章 906044
# 2025-02-02 17:08:11,218 - INFO - 正在抓取文章 906043
# 2025-02-02 17:08:11,230 - INFO - 文章 906045 回應狀態碼: 200
# 2025-02-02 17:08:11,231 - INFO - 文章 906043 回應狀態碼: 200
# 2025-02-02 17:08:11,232 - INFO - 文章 906044 回應狀態碼: 200
# 2025-02-02 17:08:11,233 - INFO - 文章 906045 不符合條件或解析失敗
# 2025-02-02 17:08:11,233 - INFO - 文章 906043 不符合條件或解析失敗
# 2025-02-02 17:08:11,235 - INFO - 文章 906044 不符合條件或解析失敗
# 2025-02-02 17:08:11,235 - INFO - 正在抓取文章 906042
# 2025-02-02 17:08:11,251 - INFO - 文章 906042 回應狀態碼: 200
# 2025-02-02 17:08:11,252 - INFO - 文章 906042 不符合條件或解析失敗
# 2025-02-02 17:08:12,084 - INFO - 正在抓取文章 906046
# 2025-02-02 17:08:12,084 - INFO - 正在抓取文章 906047
# 2025-02-02 17:08:12,085 - INFO - 正在抓取文章 906048
# 2025-02-02 17:08:12,085 - INFO - 正在抓取文章 906049
# 2025-02-02 17:08:12,098 - INFO - 文章 906046 回應狀態碼: 200
# 2025-02-02 17:08:12,100 - INFO - 文章 906046 不符合條件或解析失敗
# 2025-02-02 17:08:12,101 - INFO - 文章 906047 回應狀態碼: 200
# 2025-02-02 17:08:12,101 - INFO - 文章 906048 回應狀態碼: 200
# 2025-02-02 17:08:12,101 - INFO - 文章 906047 不符合條件或解析失敗
# 2025-02-02 17:08:12,101 - INFO - 文章 906049 回應狀態碼: 200
# 2025-02-02 17:08:12,101 - INFO - 文章 906048 不符合條件或解析失敗
# 2025-02-02 17:08:12,101 - INFO - 文章 906049 不符合條件或解析失敗
# 2025-02-02 17:08:12,754 - INFO - 正在抓取文章 906050
# 2025-02-02 17:08:12,760 - INFO - 正在抓取文章 906051
# 2025-02-02 17:08:12,762 - INFO - 正在抓取文章 906052
# 2025-02-02 17:08:12,762 - INFO - 正在抓取文章 906053
# 2025-02-02 17:08:12,768 - INFO - 文章 906050 回應狀態碼: 200
# 2025-02-02 17:08:12,772 - INFO - 文章 906050 不符合條件或解析失敗
# 2025-02-02 17:08:12,773 - INFO - 文章 906051 回應狀態碼: 200
# 2025-02-02 17:08:12,777 - INFO - 文章 906051 不符合條件或解析失敗
# 2025-02-02 17:08:12,779 - INFO - 文章 906052 回應狀態碼: 200
# 2025-02-02 17:08:12,781 - INFO - 文章 906052 不符合條件或解析失敗
# 2025-02-02 17:08:12,784 - INFO - 文章 906053 回應狀態碼: 200
# 2025-02-02 17:08:12,786 - INFO - 文章 906053 不符合條件或解析失敗
# 2025-02-02 17:08:13,601 - INFO - 正在抓取文章 906056
# 2025-02-02 17:08:13,601 - INFO - 正在抓取文章 906054
# 2025-02-02 17:08:13,601 - INFO - 正在抓取文章 906055
# 2025-02-02 17:08:13,603 - INFO - 正在抓取文章 906057
# 2025-02-02 17:08:13,630 - INFO - 文章 906056 回應狀態碼: 200
# 2025-02-02 17:08:13,632 - INFO - 文章 906054 回應狀態碼: 200
# 2025-02-02 17:08:13,633 - INFO - 文章 906055 回應狀態碼: 200
# 2025-02-02 17:08:13,635 - INFO - 文章 906057 回應狀態碼: 200
# 2025-02-02 17:08:13,635 - INFO - 文章 906056 不符合條件或解析失敗
# 2025-02-02 17:08:13,635 - INFO - 文章 906054 不符合條件或解析失敗
# 2025-02-02 17:08:13,645 - INFO - 文章 906055 不符合條件或解析失敗
# 2025-02-02 17:08:13,645 - INFO - 文章 906057 不符合條件或解析失敗
