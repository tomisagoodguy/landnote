# %%
import os
import time
import random
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib.parse
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
from pathlib import Path
import logging
from tqdm import tqdm
import hashlib
import re
import urllib3


class ArticleScraper:
    def __init__(self, scan_mode="all", data_file="articles.xlsx"):
        """初始化爬蟲設定"""
        # 基本設定
        self.base_url = "https://real-estate.get.com.tw/Columns/detail.aspx?no="
        self.target_authors = ["曾榮耀", "許文昌", "蘇偉強"]
        self.scan_mode = scan_mode
        self.data_file = Path(data_file)

        # 時間範圍設定
        self.end_date = datetime.now()
        self.start_date = self.end_date - timedelta(days=9*365)

        # 效能設定
        self.batch_size = 200
        self.max_workers = 16
        self.max_retries = 3
        self.retry_delay = 5

        # 文章編號範圍
        self.start_no = 900000
        self.max_no = 915000

        # 初始化
        self.setup_directories()
        self.setup_session()
        self.setup_logger()
        self.processed_articles = set()
        self.load_processed_articles()

    def setup_directories(self):
        """建立必要的目錄結構"""
        self.base_dir = Path("real_estate_articles")
        self.articles_dir = self.base_dir / "articles"
        self.images_dir = self.articles_dir / "images"
        self.logs_dir = self.base_dir / "logs"

        for directory in [self.base_dir, self.articles_dir, self.images_dir, self.logs_dir]:
            directory.mkdir(parents=True, exist_ok=True)

        # 創建預設的失敗圖片
        self.failed_image_path = self.images_dir / "image_download_failed.png"
        if not self.failed_image_path.exists():
            try:
                from PIL import Image, ImageDraw
                img = Image.new('RGB', (400, 100), color='white')
                d = ImageDraw.Draw(img)
                d.text((10, 40), "Image Download Failed", fill='black')
                img.save(self.failed_image_path)
            except Exception:
                self.failed_image_path.touch()

    def setup_session(self):
        """設定請求session"""
        urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
            'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
            'Accept-Encoding': 'gzip, deflate',
            'Connection': 'keep-alive',
            'Upgrade-Insecure-Requests': '1'
        })

    def setup_logger(self):
        """設定日誌系統"""
        self.logger = logging.getLogger('ArticleScraper')
        self.logger.setLevel(logging.INFO)

        log_file = self.logs_dir / \
            f"scraper_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
        handlers = [
            logging.FileHandler(log_file, encoding='utf-8'),
            logging.StreamHandler()
        ]

        formatter = logging.Formatter(
            '%(asctime)s - %(levelname)s - %(message)s')
        for handler in handlers:
            handler.setFormatter(formatter)
            self.logger.addHandler(handler)

    def load_processed_articles(self):
        """載入已處理的文章"""
        if self.data_file.exists():
            df = pd.read_excel(self.data_file)
            if '文章編號' in df.columns:
                self.processed_articles = set(df['文章編號'].astype(str))

    def download_image(self, img_url: str, article_no: int) -> str:
        """下載圖片並返回本地檔名"""
        for retry in range(self.max_retries):
            try:
                if not img_url.startswith('http'):
                    img_url = urllib.parse.urljoin(self.base_url, img_url)

                headers = {
                    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
                    'Accept': 'image/avif,image/webp,image/apng,image/svg+xml,image/*,*/*;q=0.8',
                    'Accept-Encoding': 'gzip, deflate',
                    'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
                    'Referer': self.base_url,
                    'Connection': 'keep-alive',
                    'Cache-Control': 'no-cache',
                    'Pragma': 'no-cache'
                }

                response = self.session.get(
                    img_url,
                    stream=True,
                    timeout=30,
                    headers=headers,
                    verify=False
                )
                response.raise_for_status()

                content_type = response.headers.get('content-type', '')
                if not content_type.startswith('image/'):
                    raise ValueError(f"非圖片內容類型: {content_type}")

                img_data = response.content
                img_hash = hashlib.md5(img_data).hexdigest()
                img_ext = os.path.splitext(urllib.parse.urlparse(img_url).path)[
                    1] or '.jpg'
                local_filename = f"{article_no}_{img_hash}{img_ext}"
                local_path = self.images_dir / local_filename

                if not local_path.exists():
                    with open(local_path, 'wb') as f:
                        f.write(img_data)

                return local_filename

            except Exception as e:
                self.logger.error(
                    f"下載圖片失敗 (嘗試 {retry + 1}/{self.max_retries}) {img_url}: {str(e)}")
                if retry < self.max_retries - 1:
                    time.sleep(self.retry_delay * (retry + 1))
                    continue

        return "image_download_failed.png"

    def fetch_article(self, article_no):
        """抓取單篇文章"""
        if str(article_no) in self.processed_articles:
            return None

        for retry in range(self.max_retries):
            try:
                url = f"{self.base_url}{article_no}"
                # 加入除錯訊息
                self.logger.info(f"正在抓取文章 {article_no}")
                
                response = self.session.get(url, timeout=30, verify=False)
                
                # 加入狀態碼檢查
                self.logger.info(f"文章 {article_no} 回應狀態碼: {response.status_code}")

                if response.status_code == 404:
                    self.logger.info(f"文章 {article_no} 不存在")
                    return None

                response.raise_for_status()
                response.encoding = 'utf-8'

                soup = BeautifulSoup(response.text, 'html.parser')
                article_data = self.parse_article(soup, article_no, url)

                if article_data and self.validate_article(article_data):
                    self.logger.info(f"成功解析文章 {article_no}")
                    return article_data
                else:
                    self.logger.info(f"文章 {article_no} 不符合條件或解析失敗")

            except requests.exceptions.RequestException as e:
                self.logger.error(f"抓取文章 {article_no} 失敗 (嘗試 {retry + 1}/{self.max_retries}): {str(e)}")
                # 加入回應內容檢查
                if hasattr(e.response, 'text'):
                    self.logger.error(f"錯誤回應內容: {e.response.text[:200]}")
                if retry < self.max_retries - 1:
                    time.sleep(self.retry_delay * (retry + 1))
                    continue
            except Exception as e:
                self.logger.error(f"處理文章 {article_no} 時發生未預期錯誤: {str(e)}")
                break

        return None


    def parse_article(self, soup, article_no, url):
        """解析文章內容"""
        try:
            # 先只解析作者欄位,如果不符合就直接返回
            author = None
            for row in soup.select('.columnsDetail_tableRow'):
                th = row.select_one('.columnsDetail_tableth')
                if th and th.text.strip() == '作者':
                    td = row.select_one('.columnsDetail_tabletd')
                    if td:
                        author = td.text.strip()
                        break
            
            # 如果不是目標作者就直接返回
            if not author or not any(target in author for target in self.target_authors):
                return None

            # 如果是目標作者,再解析完整內容
            article_info = {}
            for row in soup.select('.columnsDetail_tableRow'):
                th = row.select_one('.columnsDetail_tableth')
                td = row.select_one('.columnsDetail_tabletd')
                if th and td:
                    key = th.text.strip()
                    value = td.text.strip()
                    article_info[key] = value
                    
                    if key == '內文':
                        article_info['內文HTML'] = str(td)

            return {
                '文章編號': article_no,
                '標題': article_info.get('篇名', ''),
                '作者': author,
                '日期': article_info.get('日期', ''),
                '內文': article_info.get('內文', ''),
                'URL': url,
                '爬取時間': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            }

        except Exception as e:
            self.logger.error(f"解析文章 {article_no} 失敗: {str(e)}")
            return None


    def process_content(self, content_html, article_no):
        """處理文章內容"""
        if not content_html:
            return ""

        content = []
        try:
            for element in content_html.descendants:
                if isinstance(element, str):
                    text = element.strip()
                    if text:
                        content.append(text)
                elif element.name == 'img':
                    try:
                        img_src = element.get('src')
                        if img_src:
                            local_img = self.download_image(
                                img_src, article_no)
                            if local_img:
                                content.append(
                                    f"\n![圖片](./images/{local_img})\n")
                    except Exception as e:
                        self.logger.error(f"處理圖片元素失敗: {str(e)}")
                        continue

            return '\n'.join(filter(None, content))
        except Exception as e:
            self.logger.error(f"處理文章 {article_no} 內容失敗: {str(e)}")
            return ""

    def validate_article(self, article_data):
        """驗證文章資料完整性"""
        required_fields = ['標題', '作者', '日期', '內文']
        return all(field in article_data and article_data[field] for field in required_fields)

    def save_article(self, article_data):
        """儲存文章"""
        try:
            # 更新 Excel 資料
            new_df = pd.DataFrame([article_data])
            if self.data_file.exists():
                df = pd.read_excel(self.data_file)
                df = pd.concat([df, new_df]).drop_duplicates(subset=['文章編號'])
            else:
                df = new_df
            df.to_excel(self.data_file, index=False)

            # 建立 Markdown 文件
            article_no = article_data['文章編號']
            title = re.sub(r'[<>:"/\\|?*]', '', article_data['標題'])[:100]

            markdown_content = f"""# {article_data['標題']}

## 文章資訊
- 文章編號：{article_no}
- 作者：{article_data['作者']}
- 發布日期：{article_data['日期']}
- 爬取時間：{article_data['爬取時間']}
- 原文連結：[閱讀原文]({article_data['URL']})

## 內文
{article_data['內文']}

---
*注：本文圖片存放於 ./images/ 目錄下*
"""

            # 儲存 Markdown 文件
            file_path = self.articles_dir / f"{article_no}_{title}.md"
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(markdown_content)

            # 更新已處理集合
            self.processed_articles.add(str(article_no))

        except Exception as e:
            self.logger.error(f"儲存文章失敗: {str(e)}")

    def create_index(self):
        """建立索引頁面"""
        try:
            # 讀取文章資料
            if not self.data_file.exists():
                self.logger.error("找不到文章資料檔案")
                return

            df = pd.read_excel(self.data_file)

            # 將日期轉換為datetime格式並排序
            df['日期'] = pd.to_datetime(df['日期'])
            df = df.sort_values('日期', ascending=False)

            # 依年份分組
            years = df['日期'].dt.year.unique()

            # 建立索引內容
            content = ["# 地政專欄文章索引\n"]

            # 添加統計資訊
            content.append("## 文章統計\n")
            content.append(f"- 總文章數：{len(df)}篇")
            content.append(f"- 收錄年份：{min(years)}年 - {max(years)}年")
            content.append(
                f"- 最後更新：{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

            # 作者統計
            author_stats = df['作者'].value_counts()
            content.append("### 作者文章統計")
            for author, count in author_stats.items():
                content.append(f"- {author}: {count}篇")
            content.append("")

            content.append("## 目錄\n")

            # 建立年份快速連結
            content.append("### 年份快速導覽")
            for year in sorted(years, reverse=True):
                content.append(f"- [{year}年](#year-{year})")
            content.append("\n---\n")

            # 依年份建立文章列表
            for year in sorted(years, reverse=True):
                content.append(f"## {year}年 {{#year-{year}}}\n")
                year_df = df[df['日期'].dt.year == year]

                # 依月份分組
                for month in sorted(year_df['日期'].dt.month.unique(), reverse=True):
                    content.append(f"### {month}月\n")
                    month_df = year_df[year_df['日期'].dt.month == month]

                    # 列出當月文章
                    for _, article in month_df.iterrows():
                        title = re.sub(r'[<>:"/\\|?*]', '',
                                       article['標題'])[:100]
                        article_link = f"{article['文章編號']}_{title}.md"
                        date_str = article['日期'].strftime('%Y-%m-%d')
                        content.append(
                            f"- {date_str} [{article['標題']}](./{article_link}) - {article['作者']}")
                    content.append("")

            # 寫入索引文件
            index_path = self.articles_dir / "index.md"
            with open(index_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(content))

            self.logger.info("索引頁面建立完成")

        except Exception as e:
            self.logger.error(f"建立索引頁面時發生錯誤: {str(e)}")

    def run(self):
        """執行爬蟲"""
        self.logger.info(f"開始執行爬蟲 (模式: {self.scan_mode})")
        
        # 加入計數器
        success_count = 0
        fail_count = 0

        try:
            # 建議修改為
            if self.scan_mode == "new" and self.processed_articles:
                latest_no = int(max(self.processed_articles))
                self.logger.info(f"從最後處理的文章編號繼續: {latest_no}")
            else:
                latest_no = self.start_no
                self.logger.info(f"從預設起始編號開始: {latest_no}")
         
            with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                futures = []

                if self.scan_mode in ["all", "new"]:
                    # 掃描新文章
                    for article_no in range(latest_no + 1, self.max_no + 1, self.batch_size):
                        batch = range(article_no, min(article_no + self.batch_size, self.max_no + 1))
                        futures.extend([executor.submit(self.fetch_article, no) for no in batch])
                        self.logger.info(f"已提交批次: {article_no} 到 {min(article_no + self.batch_size, self.max_no)}")

                # 處理結果
                with tqdm(total=len(futures), desc="處理文章") as pbar:
                    for future in futures:
                        try:
                            result = future.result()
                            if result:
                                self.save_article(result)
                                success_count += 1
                            else:
                                fail_count += 1
                            pbar.update(1)
                        except Exception as e:
                            self.logger.error(f"處理文章結果失敗: {str(e)}")
                            fail_count += 1
                            pbar.update(1)

        finally:
            self.logger.info(f"成功處理文章數: {success_count}")
            self.logger.info(f"失敗處理文章數: {fail_count}")
            self.create_index()
            self.logger.info("程式結束執行")



if __name__ == "__main__":
    # 建立爬蟲實例並執行
    scraper = ArticleScraper(scan_mode="all")
    scraper.run()
# Out:
# 2025-02-02 15:32:13,354 - INFO - 開始執行爬蟲 (模式: all)
# 2025-02-02 15:32:13,354 - INFO - 從預設起始編號開始: 900000
# 2025-02-02 15:32:13,354 - INFO - 正在抓取文章 900001
# 2025-02-02 15:32:13,354 - INFO - 正在抓取文章 900002
# 2025-02-02 15:32:13,354 - INFO - 正在抓取文章 900003
# 2025-02-02 15:32:13,354 - INFO - 正在抓取文章 900004
# 2025-02-02 15:32:13,371 - INFO - 正在抓取文章 900005
# 2025-02-02 15:32:13,371 - INFO - 正在抓取文章 900006
# 2025-02-02 15:32:13,371 - INFO - 正在抓取文章 900007
# 2025-02-02 15:32:13,371 - INFO - 正在抓取文章 900008
# 2025-02-02 15:32:13,371 - INFO - 正在抓取文章 900009
# 2025-02-02 15:32:13,387 - INFO - 正在抓取文章 900010
# 2025-02-02 15:32:13,387 - INFO - 正在抓取文章 900011
# 2025-02-02 15:32:13,387 - INFO - 正在抓取文章 900012
# 2025-02-02 15:32:13,387 - INFO - 正在抓取文章 900013
# 2025-02-02 15:32:13,387 - INFO - 正在抓取文章 900014
# 2025-02-02 15:32:13,387 - INFO - 正在抓取文章 
# 2025-02-02 15:32:14,972 - INFO - 文章 900022 回應狀態碼: 200
# 2025-02-02 15:32:14,988 - INFO - 文章 900019 回應狀態碼: 200
# 2025-02-02 15:32:14,988 - INFO - 文章 900018 不符合條件或解析失敗
# 2025-02-02 15:32:14,999 - INFO - 已提交批次: 907401 到 907601
# 2025-02-02 15:32:15,001 - INFO - 文章 900007 回應狀態碼: 200
# 2025-02-02 15:32:15,003 - INFO - 文章 900012 不符合條件或解析失敗
# 2025-02-02 15:32:15,005 - INFO - 正在抓取文章 900011
# 2025-02-02 15:32:15,005 - INFO - 正在抓取文章 900002
# 2025-02-02 15:32:15,005 - INFO - 文章 900020 不符合條件或解析失敗
# 2025-02-02 15:32:15,005 - INFO - 正在抓取文章 900009
# 2025-02-02 15:32:15,009 - INFO - 文章 900021 不符合條件或解析失敗
# 2025-02-02 15:32:15,011 - INFO - 文章 900010 不符合條件或解析失敗
# 2025-02-02 15:32:15,013 - INFO - 文章 900022 不符合條件或解析失敗
# 2025-02-02 15:32:15,015 - INFO - 文章 900019 不符合條件或解析失敗
# 2025-02-02 15:32:15,015 - INFO - 正在抓取文章 900023
# 2025-02-02 15:32:15,019 - INFO - 已提交批次: 907601 到 907801
# 2025-02-02 15:32:15,021 - INFO - 文章 900007 不符合條件或解析失敗
# 2025-02-02 15:32:15,022 - INFO - 正在抓取文章 900012
# 2025-02-02 15:32:15,022 - INFO - 文章 900008 回應狀態碼: 200
# 2025-02-02 15:32:15,022 - INFO - 正在抓取文章 900020
# 2025-02-02 15:32:15,022 - INFO - 正在抓取文章 900021
# 2025-02-02 15:32:15,022 - INFO - 正在抓取文章 900010
# 2025-02-02 15:32:15,022 - INFO - 正在抓取文章 900022
# 2025-02-02 15:32:15,022 - INFO - 正在抓取文章 900024
# 2025-02-02 15:32:15,022 - INFO - 文章 900011 回應狀態碼: 200
# 2025-02-02 15:32:15,039 - INFO - 文章 900002 回應狀態碼: 200
# 2025-02-02 15:32:15,043 - INFO - 已提交批次: 907801 到 908001
# 2025-02-02 15:32:15,043 - INFO - 文章 900009 回應狀態碼: 200
# 2025-02-02 15:32:15,043 - INFO - 正在抓取文章 900007
# 2025-02-02 15:32:15,043 - INFO - 文章 900008 不符合條件或解析失敗
# 2025-02-02 15:32:15,043 - INFO - 文章 900023 回應狀態碼: 200
# 2025-02-02 15:32:15,060 - INFO - 文章 900012 回應狀態碼: 200
# 2025-02-02 15:32:15,060 - INFO - 文章 900011 不符合條件或解析失敗
# 2025-02-02 15:32:15,060 - INFO - 文章 900020 回應狀態碼: 200
# 2025-02-02 15:32:15,060 - INFO - 文章 900002 不符合條件或解析失敗
# 2025-02-02 15:32:15,060 - INFO - 文章 900021 回應狀態碼: 200
# 2025-02-02 15:32:15,072 - INFO - 已提交批次: 908001 到 908201
# 2025-02-02 15:32:15,072 - INFO - 文章 900010 回應狀態碼: 200
# 2025-02-02 15:32:15,072 - INFO - 文章 900009 不符合條件或解析失敗
# 2025-02-02 15:32:15,072 - INFO - 文章 900024 回應狀態碼: 200
# 2025-02-02 15:32:15,072 - INFO - 文章 900022 回應狀態碼: 200
# 2025-02-02 15:32:15,072 - INFO - 正在抓取文章 900008
# 2025-02-02 15:32:15,072 - INFO - 文章 900023 不符合條件或解析失敗
# 2025-02-02 15:32:15,072 - INFO - 文章 900012 不符合條件或解析失敗
# 2025-02-02 15:32:15,072 - INFO - 正在抓取文章 900011
# 2025-02-02 15:32:15,072 - INFO - 文章 900020 不符合條件或解析失敗
# 2025-02-02 15:32:15,072 - INFO - 正在抓取文章 900002
# 2025-02-02 15:32:15,072 - INFO - 文章 900021 不符合條件或解析失敗
# 2025-02-02 15:32:15,089 - INFO - 已提交批次: 908201 到 908401
# 2025-02-02 15:32:15,090 - INFO - 文章 900007 回應狀態碼: 200
# 2025-02-02 15:32:15,092 - INFO - 文章 900010 不符合條件或解析失敗
# 2025-02-02 15:32:15,093 - INFO - 正在抓取文章 900009
# 2025-02-02 15:32:15,093 - INFO - 文章 900024 不符合條件或解析失敗
# 2025-02-02 15:32:15,093 - INFO - 文章 900022 不符合條件或解析失敗
# 2025-02-02 15:32:15,093 - INFO - 正在抓取文章 900023
# 2025-02-02 15:32:15,093 - INFO - 正在抓取文章 900012
# 2025-02-02 15:32:15,093 - INFO - 正在抓取文章 900025
# 2025-02-02 15:32:15,105 - INFO - 正在抓取文章 900021
# 2025-02-02 15:32:15,105 - INFO - 文章 900008 回應狀態碼: 200
# 2025-02-02 15:32:15,105 - INFO - 已提交批次: 908401 到 908601
# 2025-02-02 15:32:15,105 - INFO - 文章 900011 回應狀態碼: 200
# 2025-02-02 15:32:15,105 - INFO - 文章 900007 不符合條件或解析失敗
# 2025-02-02 15:32:15,105 - INFO - 正在抓取文章 900010
# 2025-02-02 15:32:15,105 - INFO - 文章 900002 回應狀態碼: 200
# 2025-02-02 15:32:15,105 - INFO - 正在抓取文章 900024
# 2025-02-02 15:32:15,105 - INFO - 正在抓取文章 900022
# 2025-02-02 15:32:15,122 - INFO - 文章 900009 回應狀態碼: 200
# 2025-02-02 15:32:15,122 - INFO - 文章 900008 不符合條件或解析失敗
# 2025-02-02 15:32:15,122 - INFO - 已提交批次: 908601 到 908801
# 2025-02-02 15:32:15,122 - INFO - 文章 900023 回應狀態碼: 200
# 2025-02-02 15:32:15,122 - INFO - 文章 900012 回應狀態碼: 200
# 2025-02-02 15:32:15,122 - INFO - 文章 900011 不符合條件或解析失敗
# 2025-02-02 15:32:15,122 - INFO - 文章 900025 回應狀態碼: 200
# 2025-02-02 15:32:15,122 - INFO - 正在抓取文章 900007
# 2025-02-02 15:32:15,137 - INFO - 文章 900021 回應狀態碼: 200
# 2025-02-02 15:32:15,138 - INFO - 文章 900002 不符合條件或解析失敗
# 2025-02-02 15:32:15,138 - INFO - 文章 900009 不符合條件或解析失敗
# 2025-02-02 15:32:15,138 - INFO - 正在抓取文章 900026
# 2025-02-02 15:32:15,138 - INFO - 已提交批次: 908801 到 909001
# 2025-02-02 15:32:15,138 - INFO - 文章 900010 回應狀態碼: 200
# 2025-02-02 15:32:15,138 - INFO - 文章 900023 不符合條件或解析失敗
# 2025-02-02 15:32:15,155 - INFO - 文章 900012 不符合條件或解析失敗
# 2025-02-02 15:32:15,157 - INFO - 文章 900024 回應狀態碼: 200
# 2025-02-02 15:32:15,159 - INFO - 文章 900022 回應狀態碼: 200
# 2025-02-02 15:32:15,160 - INFO - 正在抓取文章 900027
# 2025-02-02 15:32:15,161 - INFO - 文章 900025 不符合條件或解析失敗
# 2025-02-02 15:32:15,163 - INFO - 文章 900021 不符合條件或解析失敗
# 2025-02-02 15:32:15,165 - INFO - 正在抓取文章 900028
# 2025-02-02 15:32:15,165 - INFO - 正在抓取文章 900029
# 2025-02-02 15:32:15,169 - INFO - 已提交批次: 909001 到 909201
# 2025-02-02 15:32:15,172 - INFO - 文章 900010 不符合條件或解析失敗
# 2025-02-02 15:32:15,174 - INFO - 正在抓取文章 900023
# 2025-02-02 15:32:15,174 - INFO - 正在抓取文章 900030
# 2025-02-02 15:32:15,174 - INFO - 文章 900007 回應狀態碼: 200
# 2025-02-02 15:32:15,176 - INFO - 文章 900024 不符合條件或解析失敗
# 2025-02-02 15:32:15,176 - INFO - 文章 900022 不符合條件或解析失敗
# 2025-02-02 15:32:15,176 - INFO - 正在抓取文章 900025
# 2025-02-02 15:32:15,176 - INFO - 正在抓取文章 900031
# 2025-02-02 15:32:15,188 - INFO - 已提交批次: 909201 到 909401
# 2025-02-02 15:32:15,188 - INFO - 文章 900026 回應狀態碼: 200
# 2025-02-02 15:32:15,188 - INFO - 文章 900015 回應狀態碼: 200
# 2025-02-02 15:32:15,188 - INFO - 文章 900027 回應狀態碼: 200
# 2025-02-02 15:32:15,188 - INFO - 正在抓取文章 900032
# 2025-02-02 15:32:15,188 - INFO - 文章 900029 回應狀態碼: 200
# 2025-02-02 15:32:15,188 - INFO - 文章 900007 不符合條件或解析失敗
# 2025-02-02 15:32:15,188 - INFO - 文章 900028 回應狀態碼: 200
# 2025-02-02 15:32:15,188 - INFO - 正在抓取文章 900024
# 2025-02-02 15:32:15,188 - INFO - 正在抓取文章 900033
# 2025-02-02 15:32:15,205 - INFO - 文章 900016 回應狀態碼: 200
# 2025-02-02 15:32:15,205 - INFO - 已提交批次: 909401 到 909601
# 2025-02-02 15:32:15,205 - INFO - 文章 900023 回應狀態碼: 200
# 2025-02-02 15:32:15,205 - INFO - 文章 900026 不符合條件或解析失敗
# 2025-02-02 15:32:15,205 - INFO - 文章 900030 回應狀態碼: 200
# 2025-02-02 15:32:15,205 - INFO - 文章 900014 回應狀態碼: 200
# 2025-02-02 15:32:15,205 - INFO - 文章 900025 回應狀態碼: 200
# 2025-02-02 15:32:15,205 - INFO - 文章 900015 不符合條件或解析失敗
# 2025-02-02 15:32:15,205 - INFO - 文章 900027 不符合條件或解析失敗
# 2025-02-02 15:32:15,205 - INFO - 文章 900031 回應狀態碼: 200
# 2025-02-02 15:32:15,222 - INFO - 文章 900029 不符合條件或解析失敗
# 2025-02-02 15:32:15,222 - INFO - 文章 900013 回應狀態碼: 200
# 2025-02-02 15:32:15,222 - INFO - 正在抓取文章 900034
# 2025-02-02 15:32:15,222 - INFO - 文章 900028 不符合條件或解析失敗
# 2025-02-02 15:32:15,222 - INFO - 文章 900016 不符合條件或解析失敗
# 2025-02-02 15:32:15,222 - INFO - 文章 900032 回應狀態碼: 200
# 2025-02-02 15:32:15,222 - INFO - 已提交批次: 909601 到 909801
# 2025-02-02 15:32:15,222 - INFO - 文章 900023 不符合條件或解析失敗
# 2025-02-02 15:32:15,222 - INFO - 正在抓取文章 900026
# 2025-02-02 15:32:15,222 - INFO - 文章 900030 不符合條件或解析失敗
# 2025-02-02 15:32:15,239 - INFO - 文章 900024 回應狀態碼: 200
# 2025-02-02 15:32:15,239 - INFO - 文章 900033 回應狀態碼: 200
# 2025-02-02 15:32:15,239 - INFO - 文章 900014 不符合條件或解析失敗
# 2025-02-02 15:32:15,241 - INFO - 文章 900025 不符合條件或解析失敗
# 2025-02-02 15:32:15,241 - INFO - 正在抓取文章 900015
# 2025-02-02 15:32:15,243 - INFO - 正在抓取文章 900027
# 2025-02-02 15:32:15,243 - INFO - 文章 900031 不符合條件或解析失敗
# 2025-02-02 15:32:15,245 - INFO - 正在抓取文章 900029
# 2025-02-02 15:32:15,245 - INFO - 文章 900013 不符合條件或解析失敗
# 2025-02-02 15:32:15,247 - INFO - 正在抓取文章 900028
# 2025-02-02 15:32:15,249 - INFO - 正在抓取文章 900016
# 2025-02-02 15:32:15,251 - INFO - 文章 900032 不符合條件或解析失敗
# 2025-02-02 15:32:15,254 - INFO - 已提交批次: 909801 到 910001
# 2025-02-02 15:32:15,255 - INFO - 正在抓取文章 900035
# 2025-02-02 15:32:15,255 - INFO - 正在抓取文章 900030
# 2025-02-02 15:32:15,255 - INFO - 文章 900024 不符合條件或解析失敗
# 2025-02-02 15:32:15,255 - INFO - 文章 900034 回應狀態碼: 200
# 2025-02-02 15:32:15,255 - INFO - 文章 900033 不符合條件或解析失敗
# 2025-02-02 15:32:15,255 - INFO - 正在抓取文章 900014
# 2025-02-02 15:32:15,255 - INFO - 正在抓取文章 900025
# 2025-02-02 15:32:15,255 - INFO - 正在抓取文章 900031
# 2025-02-02 15:32:15,255 - INFO - 文章 900026 回應狀態碼: 200
# 2025-02-02 15:32:15,255 - INFO - 正在抓取文章 900013
# 2025-02-02 15:32:15,273 - INFO - 正在抓取文章 900032
# 2025-02-02 15:32:15,276 - INFO - 已提交批次: 910001 到 910201
# 2025-02-02 15:32:15,276 - INFO - 文章 900029 回應狀態碼: 200
# 2025-02-02 15:32:15,276 - INFO - 文章 900015 回應狀態碼: 200
# 2025-02-02 15:32:15,276 - INFO - 文章 900027 回應狀態碼: 200
# 2025-02-02 15:32:15,276 - INFO - 文章 900028 回應狀態碼: 200
# 2025-02-02 15:32:15,276 - INFO - 正在抓取文章 900036
# 2025-02-02 15:32:15,276 - INFO - 文章 900016 回應狀態碼: 200
# 2025-02-02 15:32:15,276 - INFO - 文章 900034 不符合條件或解析失敗
# 2025-02-02 15:32:15,276 - INFO - 正在抓取文章 900033
# 2025-02-02 15:32:15,288 - INFO - 文章 900035 回應狀態碼: 200
# 2025-02-02 15:32:15,288 - INFO - 文章 900026 不符合條件或解析失敗
# 2025-02-02 15:32:15,288 - INFO - 文章 900030 回應狀態碼: 200
# 2025-02-02 15:32:15,298 - INFO - 文章 900014 回應狀態碼: 200
# 2025-02-02 15:32:15,304 - INFO - 已提交批次: 910201 到 910401
# 2025-02-02 15:32:15,305 - INFO - 文章 900029 不符合條件或解析失敗
# 2025-02-02 15:32:15,305 - INFO - 文章 900031 回應狀態碼: 200
# 2025-02-02 15:32:15,305 - INFO - 文章 900025 回應狀態碼: 200
# 2025-02-02 15:32:15,305 - INFO - 文章 900015 不符合條件或解析失敗
# 2025-02-02 15:32:15,305 - INFO - 文章 900027 不符合條件或解析失敗
# 2025-02-02 15:32:15,305 - INFO - 文章 900028 不符合條件或解析失敗
# 2025-02-02 15:32:15,305 - INFO - 文章 900016 不符合條件或解析失敗
# 2025-02-02 15:32:15,305 - INFO - 文章 900032 回應狀態碼: 200
# 2025-02-02 15:32:15,305 - INFO - 文章 900013 回應狀態碼: 200
# 2025-02-02 15:32:15,305 - INFO - 正在抓取文章 900034
# 2025-02-02 15:32:15,305 - INFO - 文章 900035 不符合條件或解析失敗
# 2025-02-02 15:32:15,305 - INFO - 正在抓取文章 900026
# 2025-02-02 15:32:15,323 - INFO - 文章 900030 不符合條件或解析失敗
# 2025-02-02 15:32:15,325 - INFO - 文章 900014 不符合條件或解析失敗
# 2025-02-02 15:32:15,326 - INFO - 已提交批次: 910401 到 910601
# 2025-02-02 15:32:15,326 - INFO - 文章 900033 回應狀態碼: 200
# 2025-02-02 15:32:15,326 - INFO - 文章 900036 回應狀態碼: 200
# 2025-02-02 15:32:15,326 - INFO - 正在抓取文章 900029
# 2025-02-02 15:32:15,326 - INFO - 文章 900031 不符合條件或解析失敗
# 2025-02-02 15:32:15,326 - INFO - 文章 900025 不符合條件或解析失敗
# 2025-02-02 15:32:15,326 - INFO - 正在抓取文章 900015
# 2025-02-02 15:32:15,326 - INFO - 正在抓取文章 900027
# 2025-02-02 15:32:15,326 - INFO - 正在抓取文章 900028
# 2025-02-02 15:32:15,326 - INFO - 正在抓取文章 900016
# 2025-02-02 15:32:15,339 - INFO - 文章 900032 不符合條件或解析失敗
# 2025-02-02 15:32:15,339 - INFO - 文章 900013 不符合條件或解析失敗
# 2025-02-02 15:32:15,339 - INFO - 正在抓取文章 900035
# 2025-02-02 15:32:15,339 - INFO - 正在抓取文章 900030
# 2025-02-02 15:32:15,339 - INFO - 正在抓取文章 900014
# 2025-02-02 15:32:15,339 - INFO - 已提交批次: 910601 到 910801
# 2025-02-02 15:32:15,339 - INFO - 文章 900033 不符合條件或解析失敗
# 2025-02-02 15:32:15,339 - INFO - 文章 900034 回應狀態碼: 200
# 2025-02-02 15:32:15,339 - INFO - 文章 900036 不符合條件或解析失敗
# 2025-02-02 15:32:15,355 - INFO - 正在抓取文章 900031
# 2025-02-02 15:32:15,355 - INFO - 文章 900026 回應狀態碼: 200
# 2025-02-02 15:32:15,355 - INFO - 正在抓取文章 900037
# 2025-02-02 15:32:15,355 - INFO - 正在抓取文章 900032
# 2025-02-02 15:32:15,355 - INFO - 正在抓取文章 900013
# 2025-02-02 15:32:15,355 - INFO - 文章 900029 回應狀態碼: 200
# 2025-02-02 15:32:15,373 - INFO - 文章 900027 回應狀態碼: 200
# 2025-02-02 15:32:15,374 - INFO - 文章 900015 回應狀態碼: 200
# 2025-02-02 15:32:15,376 - INFO - 已提交批次: 910801 到 911001
# 2025-02-02 15:32:15,376 - INFO - 文章 900028 回應狀態碼: 200
# 2025-02-02 15:32:15,376 - INFO - 文章 900016 回應狀態碼: 200
# 2025-02-02 15:32:15,376 - INFO - 文章 900035 回應狀態碼: 200
# 2025-02-02 15:32:15,376 - INFO - 正在抓取文章 900033
# 2025-02-02 15:32:15,376 - INFO - 文章 900034 不符合條件或解析失敗
# 2025-02-02 15:32:15,376 - INFO - 文章 900030 回應狀態碼: 200
# 2025-02-02 15:32:15,376 - INFO - 正在抓取文章 900036
# 2025-02-02 15:32:15,376 - INFO - 文章 900026 不符合條件或解析失敗
# 2025-02-02 15:32:15,389 - INFO - 文章 900014 回應狀態碼: 200
# 2025-02-02 15:32:15,389 - INFO - 文章 900029 不符合條件或解析失敗
# 2025-02-02 15:32:15,389 - INFO - 文章 900031 回應狀態碼: 200
# 2025-02-02 15:32:15,389 - INFO - 文章 900027 不符合條件或解析失敗
# 2025-02-02 15:32:15,389 - INFO - 文章 900015 不符合條件或解析失敗
# 2025-02-02 15:32:15,389 - INFO - 文章 900037 回應狀態碼: 200
# 2025-02-02 15:32:15,404 - INFO - 已提交批次: 911001 到 911201
# 2025-02-02 15:32:15,405 - INFO - 文章 900032 回應狀態碼: 200
# 2025-02-02 15:32:15,405 - INFO - 文章 900013 回應狀態碼: 200
# 2025-02-02 15:32:15,407 - INFO - 文章 900028 不符合條件或解析失敗
# 2025-02-02 15:32:15,407 - INFO - 文章 900016 不符合條件或解析失敗
# 2025-02-02 15:32:15,409 - INFO - 文章 900035 不符合條件或解析失敗
# 2025-02-02 15:32:15,409 - INFO - 正在抓取文章 900034
# 2025-02-02 15:32:15,409 - INFO - 文章 900030 不符合條件或解析失敗
# 2025-02-02 15:32:15,409 - INFO - 正在抓取文章 900038
# 2025-02-02 15:32:15,409 - INFO - 文章 900014 不符合條件或解析失敗
# 2025-02-02 15:32:15,409 - INFO - 正在抓取文章 900039
# 2025-02-02 15:32:15,409 - INFO - 文章 900031 不符合條件或解析失敗
# 2025-02-02 15:32:15,421 - INFO - 正在抓取文章 900040
# 2025-02-02 15:32:15,422 - INFO - 正在抓取文章 900041
# 2025-02-02 15:32:15,422 - INFO - 文章 900033 回應狀態碼: 200
# 2025-02-02 15:32:15,422 - INFO - 文章 900037 不符合條件或解析失敗
# 2025-02-02 15:32:15,422 - INFO - 已提交批次: 911201 到 911401
# 2025-02-02 15:32:15,422 - INFO - 文章 900036 回應狀態碼: 200
# 2025-02-02 15:32:15,422 - INFO - 文章 900032 不符合條件或解析失敗
# 2025-02-02 15:32:15,422 - INFO - 文章 900013 不符合條件或解析失敗
# 2025-02-02 15:32:15,422 - INFO - 正在抓取文章 900042
# 2025-02-02 15:32:15,422 - INFO - 正在抓取文章 900043
# 2025-02-02 15:32:15,422 - INFO - 正在抓取文章 900035
# 2025-02-02 15:32:15,422 - INFO - 正在抓取文章 900044
# 2025-02-02 15:32:15,438 - INFO - 正在抓取文章 900045
# 2025-02-02 15:32:15,438 - INFO - 正在抓取文章 900046
# 2025-02-02 15:32:15,438 - INFO - 文章 900034 回應狀態碼: 200
# 2025-02-02 15:32:15,438 - INFO - 文章 900033 不符合條件或解析失敗
# 2025-02-02 15:32:15,438 - INFO - 正在抓取文章 900037
# 2025-02-02 15:32:15,438 - INFO - 文章 900038 回應狀態碼: 200
# 2025-02-02 15:32:15,438 - INFO - 已提交批次: 911401 到 911601
# 2025-02-02 15:32:15,438 - INFO - 文章 900039 回應狀態碼: 200
# 2025-02-02 15:32:15,438 - INFO - 文章 900040 回應狀態碼: 200
# 2025-02-02 15:32:15,455 - INFO - 文章 900036 不符合條件或解析失敗
# 2025-02-02 15:32:15,455 - INFO - 文章 900041 回應狀態碼: 200
# 2025-02-02 15:32:15,455 - INFO - 正在抓取文章 900047
# 2025-02-02 15:32:15,455 - INFO - 正在抓取文章 900048
# 2025-02-02 15:32:15,473 - INFO - 文章 900042 回應狀態碼: 200
# 2025-02-02 15:32:15,474 - INFO - 文章 900043 回應狀態碼: 200
# 2025-02-02 15:32:15,477 - INFO - 文章 900035 回應狀態碼: 200
# 2025-02-02 15:32:15,478 - INFO - 文章 900034 不符合條件或解析失敗
# 2025-02-02 15:32:15,480 - INFO - 正在抓取文章 900049
# 2025-02-02 15:32:15,481 - INFO - 文章 900044 回應狀態碼: 200
# 2025-02-02 15:32:15,483 - INFO - 文章 900045 回應狀態碼: 200
# 2025-02-02 15:32:15,483 - INFO - 文章 900038 不符合條件或解析失敗
# 2025-02-02 15:32:15,490 - INFO - 文章 900046 回應狀態碼: 200
# 2025-02-02 15:32:15,494 - INFO - 已提交批次: 911601 到 911801
# 2025-02-02 15:32:15,496 - INFO - 文章 900037 回應狀態碼: 200
# 2025-02-02 15:32:15,497 - INFO - 文章 900039 不符合條件或解析失敗
# 2025-02-02 15:32:15,499 - INFO - 文章 900040 不符合條件或解析失敗
# 2025-02-02 15:32:15,500 - INFO - 正在抓取文章 900036
# 2025-02-02 15:32:15,502 - INFO - 文章 900041 不符合條件或解析失敗
# 2025-02-02 15:32:15,508 - INFO - 文章 900042 不符合條件或解析失敗
# 2025-02-02 15:32:15,508 - INFO - 文章 900043 不符合條件或解析失敗
# 2025-02-02 15:32:15,508 - INFO - 文章 900035 不符合條件或解析失敗
# 2025-02-02 15:32:15,508 - INFO - 正在抓取文章 900050
# 2025-02-02 15:32:15,508 - INFO - 文章 900047 回應狀態碼: 200
# 2025-02-02 15:32:15,508 - INFO - 文章 900044 不符合條件或解析失敗
# 2025-02-02 15:32:15,523 - INFO - 文章 900045 不符合條件或解析失敗
# 2025-02-02 15:32:15,524 - INFO - 文章 900048 回應狀態碼: 200
# 2025-02-02 15:32:15,525 - INFO - 正在抓取文章 900038
# 2025-02-02 15:32:15,528 - INFO - 文章 900046 不符合條件或解析失敗
# 2025-02-02 15:32:15,534 - INFO - 已提交批次: 911801 到 912001
# 2025-02-02 15:32:15,535 - INFO - 文章 900049 回應狀態碼: 200
# 2025-02-02 15:32:15,536 - INFO - 文章 900037 不符合條件或解析失敗
# 2025-02-02 15:32:15,537 - INFO - 正在抓取文章 900039
# 2025-02-02 15:32:15,538 - INFO - 正在抓取文章 900040
# 2025-02-02 15:32:15,541 - INFO - 正在抓取文章 900041
# 2025-02-02 15:32:15,542 - INFO - 正在抓取文章 900042
# 2025-02-02 15:32:15,543 - INFO - 正在抓取文章 900043
# 2025-02-02 15:32:15,544 - INFO - 正在抓取文章 900051
# 2025-02-02 15:32:15,548 - INFO - 文章 900047 不符合條件或解析失敗
# 2025-02-02 15:32:15,549 - INFO - 正在抓取文章 900044
# 2025-02-02 15:32:15,550 - INFO - 正在抓取文章 900045
# 2025-02-02 15:32:15,551 - INFO - 文章 900048 不符合條件或解析失敗
# 2025-02-02 15:32:15,552 - INFO - 文章 900036 回應狀態碼: 200
# 2025-02-02 15:32:15,554 - INFO - 正在抓取文章 900046
# 2025-02-02 15:32:15,561 - INFO - 已提交批次: 912001 到 912201
# 2025-02-02 15:32:15,563 - INFO - 文章 900050 回應狀態碼: 200
# 2025-02-02 15:32:15,564 - INFO - 文章 900038 回應狀態碼: 200
# 2025-02-02 15:32:15,565 - INFO - 文章 900049 不符合條件或解析失敗
# 2025-02-02 15:32:15,566 - INFO - 正在抓取文章 900037
# 2025-02-02 15:32:15,662 - INFO - 文章 900039 回應狀態碼: 200
# 2025-02-02 15:32:15,663 - INFO - 正在抓取文章 900047
# 2025-02-02 15:32:15,664 - INFO - 文章 900040 回應狀態碼: 200
# 2025-02-02 15:32:15,666 - INFO - 文章 900042 回應狀態碼: 200
# 2025-02-02 15:32:15,667 - INFO - 文章 900041 回應狀態碼: 200
# 2025-02-02 15:32:15,669 - INFO - 正在抓取文章 900048
# 2025-02-02 15:32:15,670 - INFO - 文章 900043 回應狀態碼: 200
# 2025-02-02 15:32:15,671 - INFO - 文章 900036 不符合條件或解析失敗
# 2025-02-02 15:32:15,672 - INFO - 文章 900051 回應狀態碼: 200
# 2025-02-02 15:32:15,674 - INFO - 已提交批次: 912201 到 912401
# 2025-02-02 15:32:15,674 - INFO - 文章 900045 回應狀態碼: 200
# 2025-02-02 15:32:15,674 - INFO - 文章 900044 回應狀態碼: 200
# 2025-02-02 15:32:15,682 - INFO - 文章 900050 不符合條件或解析失敗
# 2025-02-02 15:32:15,687 - INFO - 文章 900038 不符合條件或解析失敗
# 2025-02-02 15:32:15,691 - INFO - 文章 900046 回應狀態碼: 200
# 2025-02-02 15:32:15,692 - INFO - 正在抓取文章 900049
# 2025-02-02 15:32:15,697 - INFO - 文章 900039 不符合條件或解析失敗
# 2025-02-02 15:32:15,702 - INFO - 文章 900040 不符合條件或解析失敗
# 2025-02-02 15:32:15,704 - INFO - 文章 900042 不符合條件或解析失敗
# 2025-02-02 15:32:15,706 - INFO - 文章 900041 不符合條件或解析失敗
# 2025-02-02 15:32:15,707 - INFO - 文章 900037 回應狀態碼: 200
# 2025-02-02 15:32:15,711 - INFO - 文章 900047 回應狀態碼: 200
# 2025-02-02 15:32:15,714 - INFO - 文章 900043 不符合條件或解析失敗
# 2025-02-02 15:32:15,715 - INFO - 正在抓取文章 900052
# 2025-02-02 15:32:15,716 - INFO - 文章 900051 不符合條件或解析失敗
# 2025-02-02 15:32:15,720 - INFO - 已提交批次: 912401 到 912601
# 2025-02-02 15:32:15,721 - INFO - 文章 900045 不符合條件或解析失敗
# 2025-02-02 15:32:15,722 - INFO - 文章 900044 不符合條件或解析失敗
# 2025-02-02 15:32:15,723 - INFO - 文章 900048 回應狀態碼: 200
# 2025-02-02 15:32:15,724 - INFO - 正在抓取文章 900050
# 2025-02-02 15:32:15,724 - INFO - 正在抓取文章 900038
# 2025-02-02 15:32:15,726 - INFO - 文章 900046 不符合條件或解析失敗
# 2025-02-02 15:32:15,728 - INFO - 正在抓取文章 900039
# 2025-02-02 15:32:15,730 - INFO - 正在抓取文章 900040
# 2025-02-02 15:32:15,730 - INFO - 正在抓取文章 900042
# 2025-02-02 15:32:15,731 - INFO - 正在抓取文章 900041
# 2025-02-02 15:32:15,732 - INFO - 文章 900037 不符合條件或解析失敗
# 2025-02-02 15:32:15,733 - INFO - 文章 900047 不符合條件或解析失敗
# 2025-02-02 15:32:15,735 - INFO - 正在抓取文章 900043
# 2025-02-02 15:32:15,736 - INFO - 正在抓取文章 900051
# 2025-02-02 15:32:15,739 - INFO - 文章 900049 回應狀態碼: 200
# 2025-02-02 15:32:15,743 - INFO - 已提交批次: 912601 到 912801
# 2025-02-02 15:32:15,745 - INFO - 正在抓取文章 900045
# 2025-02-02 15:32:15,746 - INFO - 正在抓取文章 900044
# 2025-02-02 15:32:15,749 - INFO - 文章 900052 回應狀態碼: 200
# 2025-02-02 15:32:15,750 - INFO - 文章 900048 不符合條件或解析失敗
# 2025-02-02 15:32:15,756 - INFO - 正在抓取文章 900046
# 2025-02-02 15:32:15,764 - INFO - 正在抓取文章 900053
# 2025-02-02 15:32:15,765 - INFO - 文章 900050 回應狀態碼: 200
# 2025-02-02 15:32:15,766 - INFO - 文章 900038 回應狀態碼: 200
# 2025-02-02 15:32:15,766 - INFO - 正在抓取文章 900047
# 2025-02-02 15:32:15,769 - INFO - 文章 900039 回應狀態碼: 200
# 2025-02-02 15:32:15,770 - INFO - 文章 900040 回應狀態碼: 200
# 2025-02-02 15:32:15,771 - INFO - 文章 900049 不符合條件或解析失敗
# 2025-02-02 15:32:15,773 - INFO - 文章 900042 回應狀態碼: 200
# 2025-02-02 15:32:15,774 - INFO - 文章 900041 回應狀態碼: 200
# 2025-02-02 15:32:18,024 - INFO - 文章 900083 回應狀態碼: 200
# 2025-02-02 15:32:18,024 - INFO - 文章 900084 回應狀態碼: 200
# 2025-02-02 15:32:18,024 - INFO - 文章 900080 回應狀態碼: 200
# 2025-02-02 15:32:18,024 - INFO - 文章 900072 不符合條件或解析失敗
# 2025-02-02 15:32:18,024 - INFO - 正在抓取文章 900092
# 2025-02-02 15:32:18,024 - INFO - 正在抓取文章 900093
# 2025-02-02 15:32:18,024 - INFO - 正在抓取文章 900094
# 2025-02-02 15:32:18,024 - INFO - 文章 900079 回應狀態碼: 200
# 2025-02-02 15:32:18,024 - INFO - 正在抓取文章 900095
# 2025-02-02 15:32:18,024 - INFO - 文章 900085 回應狀態碼: 200
# 2025-02-02 15:32:18,041 - INFO - 文章 900083 不符合條件或解析失敗
# 2025-02-02 15:32:18,041 - INFO - 文章 900086 回應狀態碼: 200
# 2025-02-02 15:32:18,041 - INFO - 文章 900084 不符合條件或解析失敗
# 2025-02-02 15:32:18,041 - INFO - 文章 900088 回應狀態碼: 200
# 2025-02-02 15:32:18,041 - INFO - 文章 900080 不符合條件或解析失敗
# 2025-02-02 15:32:18,041 - INFO - 正在抓取文章 900096
# 2025-02-02 15:32:18,041 - INFO - 文章 900087 回應狀態碼: 200
# 2025-02-02 15:32:18,041 - INFO - 文章 900090 回應狀態碼: 200
# 2025-02-02 15:32:18,041 - INFO - 文章 900089 回應狀態碼: 200
# 2025-02-02 15:32:18,041 - INFO - 文章 900079 不符合條件或解析失敗
# 2025-02-02 15:32:18,057 - INFO - 文章 900091 回應狀態碼: 200
# 2025-02-02 15:32:18,061 - INFO - 文章 900092 回應狀態碼: 200
# 2025-02-02 15:32:18,062 - INFO - 文章 900093 回應狀態碼: 200
# 2025-02-02 15:32:18,062 - INFO - 文章 900085 不符合條件或解析失敗
# 2025-02-02 15:32:18,062 - INFO - 文章 900094 回應狀態碼: 200
# 2025-02-02 15:32:18,062 - INFO - 正在抓取文章 900083
# 2025-02-02 15:32:18,062 - INFO - 文章 900086 不符合條件或解析失敗
# 2025-02-02 15:32:18,062 - INFO - 正在抓取文章 900084
# 2025-02-02 15:32:18,062 - INFO - 文章 900088 不符合條件或解析失敗
# 2025-02-02 15:32:18,062 - INFO - 正在抓取文章 900097
# 2025-02-02 15:32:18,062 - INFO - 文章 900087 不符合條件或解析失敗
# 2025-02-02 15:32:18,062 - INFO - 文章 900090 不符合條件或解析失敗
# 2025-02-02 15:32:18,062 - INFO - 文章 900089 不符合條件或解析失敗
# 2025-02-02 15:32:18,062 - INFO - 正在抓取文章 900098
# 2025-02-02 15:32:18,074 - INFO - 文章 900091 不符合條件或解析失敗
# 2025-02-02 15:32:18,074 - INFO - 文章 900092 不符合條件或解析失敗
# 2025-02-02 15:32:18,074 - INFO - 文章 900093 不符合條件或解析失敗
# 2025-02-02 15:32:18,074 - INFO - 正在抓取文章 900085
# 2025-02-02 15:32:18,074 - INFO - 文章 900094 不符合條件或解析失敗
# 2025-02-02 15:32:18,074 - INFO - 正在抓取文章 900086
# 2025-02-02 15:32:18,074 - INFO - 正在抓取文章 900088
# 2025-02-02 15:32:18,074 - INFO - 正在抓取文章 900087
# 2025-02-02 15:32:18,088 - INFO - 正在抓取文章 900090
# 2025-02-02 15:32:18,088 - INFO - 正在抓取文章 900089
# 2025-02-02 15:32:18,088 - INFO - 文章 900095 回應狀態碼: 200
# 2025-02-02 15:32:18,091 - INFO - 正在抓取文章 900091
# 2025-02-02 15:32:18,091 - INFO - 正在抓取文章 900092
# 2025-02-02 15:32:18,091 - INFO - 正在抓取文章 900093
# 2025-02-02 15:32:18,091 - INFO - 正在抓取文章 900094
# 2025-02-02 15:32:18,091 - INFO - 文章 900083 回應狀態碼: 200
# 2025-02-02 15:32:18,091 - INFO - 文章 900096 回應狀態碼: 200
# 2025-02-02 15:32:18,091 - INFO - 文章 900084 回應狀態碼: 200
# 2025-02-02 15:32:18,091 - INFO - 文章 900097 回應狀態碼: 200
# 2025-02-02 15:32:18,091 - INFO - 文章 900098 回應狀態碼: 200
# 2025-02-02 15:32:18,108 - INFO - 文章 900085 回應狀態碼: 200
# 2025-02-02 15:32:18,125 - INFO - 文章 900086 回應狀態碼: 200
# 2025-02-02 15:32:18,125 - INFO - 文章 900095 不符合條件或解析失敗
# 2025-02-02 15:32:18,125 - INFO - 文章 900088 回應狀態碼: 200
# 2025-02-02 15:32:18,125 - INFO - 文章 900089 回應狀態碼: 200
# 2025-02-02 15:32:18,125 - INFO - 文章 900090 回應狀態碼: 200
# 2025-02-02 15:32:18,125 - INFO - 文章 900087 回應狀態碼: 200
# 2025-02-02 15:32:18,141 - INFO - 文章 900083 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 文章 900094 回應狀態碼: 200
# 2025-02-02 15:32:18,158 - INFO - 文章 900092 回應狀態碼: 200
# 2025-02-02 15:32:18,158 - INFO - 文章 900096 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 文章 900093 回應狀態碼: 200
# 2025-02-02 15:32:18,158 - INFO - 文章 900091 回應狀態碼: 200
# 2025-02-02 15:32:18,158 - INFO - 文章 900084 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 文章 900097 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 文章 900098 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 文章 900085 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 文章 900086 不符合條件或解析失敗
# 2025-02-02 15:32:18,158 - INFO - 正在抓取文章 900095
# 2025-02-02 15:32:18,158 - INFO - 文章 900088 不符合條件或解析失敗
# 2025-02-02 15:32:18,174 - INFO - 文章 900089 不符合條件或解析失敗
# 2025-02-02 15:32:18,176 - INFO - 文章 900090 不符合條件或解析失敗
# 2025-02-02 15:32:18,178 - INFO - 文章 900087 不符合條件或解析失敗
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900099
# 2025-02-02 15:32:18,178 - INFO - 文章 900094 不符合條件或解析失敗
# 2025-02-02 15:32:18,178 - INFO - 文章 900092 不符合條件或解析失敗
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900096
# 2025-02-02 15:32:18,178 - INFO - 文章 900093 不符合條件或解析失敗
# 2025-02-02 15:32:18,178 - INFO - 文章 900091 不符合條件或解析失敗
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900100
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900097
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900098
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900101
# 2025-02-02 15:32:18,178 - INFO - 正在抓取文章 900102
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900103
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900104
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900090
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900105
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900094
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900092
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900093
# 2025-02-02 15:32:18,191 - INFO - 正在抓取文章 900091
# 2025-02-02 15:32:18,208 - INFO - 文章 900099 回應狀態碼: 200
# 2025-02-02 15:32:18,208 - INFO - 文章 900100 回應狀態碼: 200
# 2025-02-02 15:32:18,208 - INFO - 文章 900097 回應狀態碼: 200
# 2025-02-02 15:32:18,208 - INFO - 文章 900095 回應狀態碼: 200
# 2025-02-02 15:32:18,224 - INFO - 文章 900099 不符合條件或解析失敗
# 2025-02-02 15:32:18,224 - INFO - 文章 900100 不符合條件或解析失敗
# 2025-02-02 15:32:18,224 - INFO - 文章 900096 回應狀態碼: 200
# 2025-02-02 15:32:18,224 - INFO - 文章 900098 回應狀態碼: 200
# 2025-02-02 15:32:18,224 - INFO - 文章 900104 回應狀態碼: 200
# 2025-02-02 15:32:18,224 - INFO - 文章 900097 不符合條件或解析失敗
# ...
# 2025-02-02 15:33:05,336 - INFO - 文章 901012 回應狀態碼: 200
# 2025-02-02 15:33:05,337 - INFO - 文章 901017 不符合條件或解析失敗
# 2025-02-02 15:33:05,342 - INFO - 正在抓取文章 901020
# 2025-02-02 15:33:05,344 - INFO - 文章 901018 不符合條件或解析失敗
# 2025-02-02 15:33:05,345 - INFO - 正在抓取文章 901014
# 2025-02-02 15:33:05,347 - INFO - 正在抓取文章 901022
# 2025-02-02 15:33:05,348 - INFO - 正在抓取文章 901015
# 2025-02-02 15:33:05,352 - INFO - 文章 901013 回應狀態碼: 200
# 2025-02-02 15:33:05,352 - INFO - 正在抓取文章 901021
# 2025-02-02 15:33:05,354 - INFO - 正在抓取文章 901026
# 2025-02-02 15:33:05,356 - INFO - 文章 901019 不符合條件或解析失敗
# 2025-02-02 15:33:05,332 - INFO - 正在抓取文章 901016
# 2025-02-02 15:33:05,363 - INFO - 文章 901024 回應狀態碼: 200
# 2025-02-02 15:33:05,367 - INFO - 正在抓取文章 901023
# 2025-02-02 15:33:05,369 - INFO - 文章 901012 不符合條件或解析失敗
# 2025-02-02 15:33:05,370 - INFO - 文章 901025 回應狀態碼: 200
# 2025-02-02 15:33:05,371 - INFO - 正在抓取文章 901017
# 2025-02-02 15:33:05,375 - INFO - 正在抓取文章 901018
# 2025-02-02 15:33:05,377 - INFO - 文章 901027 回應狀態碼: 200
# 2025-02-02 15:33:05,385 - INFO - 文章 901020 回應狀態碼: 200
# 2025-02-02 15:33:05,387 - INFO - 文章 901013 不符合條件或解析失敗
# 2025-02-02 15:33:05,388 - INFO - 文章 901014 回應狀態碼: 200
# 2025-02-02 15:33:05,394 - INFO - 文章 901015 回應狀態碼: 200
# 2025-02-02 15:33:05,396 - INFO - 文章 901022 回應狀態碼: 200
# 2025-02-02 15:33:05,397 - INFO - 正在抓取文章 901019
# 2025-02-02 15:33:05,403 - INFO - 文章 901024 不符合條件或解析失敗
# 2025-02-02 15:33:05,403 - INFO - 文章 901021 回應狀態碼: 200
# 2025-02-02 15:33:05,406 - INFO - 文章 901026 回應狀態碼: 200
# 2025-02-02 15:33:05,409 - INFO - 正在抓取文章 901028
# 2025-02-02 15:33:05,411 - INFO - 文章 901025 不符合條件或解析失敗
# 處理文章:   5%|▍         | 706/15000 [00:48<29:29,  8.08it/s]2025-02-02 15:33:05,413 - INFO - 文章 901016 回應狀態碼: 200
# 2025-02-02 15:33:05,418 - INFO - 文章 901023 回應狀態碼: 200
# 2025-02-02 15:33:05,421 - INFO - 文章 901027 不符合條件或解析失敗
# 2025-02-02 15:33:05,424 - INFO - 文章 901020 不符合條件或解析失敗
# 2025-02-02 15:33:05,425 - INFO - 正在抓取文章 901029
# 2025-02-02 15:33:05,427 - INFO - 文章 901014 不符合條件或解析失敗
# 2025-02-02 15:33:05,432 - INFO - 文章 901017 回應狀態碼: 200
# 2025-02-02 15:33:05,434 - INFO - 文章 901018 回應狀態碼: 200
# 2025-02-02 15:33:05,439 - INFO - 文章 901015 不符合條件或解析失敗
# 2025-02-02 15:33:05,442 - INFO - 文章 901022 不符合條件或解析失敗
# 2025-02-02 15:33:05,447 - INFO - 正在抓取文章 901024
# 2025-02-02 15:33:05,448 - INFO - 文章 901021 不符合條件或解析失敗
# 2025-02-02 15:33:05,451 - INFO - 文章 901026 不符合條件或解析失敗
# 2025-02-02 15:33:05,457 - INFO - 正在抓取文章 901025
# 2025-02-02 15:33:05,458 - INFO - 文章 901019 回應狀態碼: 200
# 2025-02-02 15:33:05,459 - INFO - 文章 901016 不符合條件或解析失敗
# 2025-02-02 15:33:05,462 - INFO - 文章 901023 不符合條件或解析失敗
# 2025-02-02 15:33:05,464 - INFO - 正在抓取文章 901027
# 2025-02-02 15:33:05,466 - INFO - 正在抓取文章 901020
# 2025-02-02 15:33:05,467 - INFO - 文章 901028 回應狀態碼: 200
# 2025-02-02 15:33:05,471 - INFO - 正在抓取文章 901030
# 2025-02-02 15:33:05,473 - INFO - 文章 901017 不符合條件或解析失敗
# 2025-02-02 15:33:05,474 - INFO - 文章 901018 不符合條件或解析失敗
# 2025-02-02 15:33:05,476 - INFO - 正在抓取文章 901031
# 2025-02-02 15:33:05,477 - INFO - 正在抓取文章 901022
# 2025-02-02 15:33:05,480 - INFO - 正在抓取文章 901021
# 2025-02-02 15:33:05,482 - INFO - 正在抓取文章 901026
# 2025-02-02 15:33:05,486 - INFO - 文章 901019 不符合條件或解析失敗
# 2025-02-02 15:33:05,488 - INFO - 正在抓取文章 901032
# 2025-02-02 15:33:05,490 - INFO - 正在抓取文章 901023
# 2025-02-02 15:33:05,501 - INFO - 文章 901024 回應狀態碼: 200
# 2025-02-02 15:33:05,507 - INFO - 文章 901028 不符合條件或解析失敗
# 2025-02-02 15:33:05,508 - INFO - 文章 901025 回應狀態碼: 200
# 2025-02-02 15:33:05,509 - INFO - 文章 901029 回應狀態碼: 200
# 2025-02-02 15:33:05,512 - INFO - 文章 901027 回應狀態碼: 200
# 2025-02-02 15:33:05,516 - INFO - 文章 901020 回應狀態碼: 200
# 2025-02-02 15:33:05,520 - INFO - 正在抓取文章 901033
# 2025-02-02 15:33:05,523 - INFO - 正在抓取文章 901034
# 2025-02-02 15:33:05,549 - INFO - 正在抓取文章 901035
# 2025-02-02 15:33:05,549 - INFO - 文章 901030 回應狀態碼: 200
# 2025-02-02 15:33:05,550 - INFO - 文章 901031 回應狀態碼: 200
# 2025-02-02 15:33:05,550 - INFO - 文章 901022 回應狀態碼: 200
# 2025-02-02 15:33:05,556 - INFO - 文章 901021 回應狀態碼: 200
# 2025-02-02 15:33:05,557 - INFO - 文章 901026 回應狀態碼: 200
# 2025-02-02 15:33:05,571 - INFO - 文章 901032 回應狀態碼: 200
# 2025-02-02 15:33:05,572 - INFO - 文章 901024 不符合條件或解析失敗
# 2025-02-02 15:33:05,577 - INFO - 文章 901023 回應狀態碼: 200
# 2025-02-02 15:33:05,578 - INFO - 正在抓取文章 901028
# 2025-02-02 15:33:05,581 - INFO - 文章 901025 不符合條件或解析失敗
# 2025-02-02 15:33:05,623 - INFO - 成功解析文章 901029
# 2025-02-02 15:33:05,626 - INFO - 文章 901027 不符合條件或解析失敗
# 2025-02-02 15:33:05,633 - INFO - 文章 901020 不符合條件或解析失敗
# 2025-02-02 15:33:05,652 - INFO - 文章 901033 回應狀態碼: 200
# 2025-02-02 15:33:05,658 - INFO - 文章 901034 回應狀態碼: 200
# 2025-02-02 15:33:05,683 - INFO - 成功解析文章 901030
# 2025-02-02 15:33:05,683 - INFO - 文章 901035 回應狀態碼: 200
# 2025-02-02 15:33:05,683 - INFO - 文章 901031 不符合條件或解析失敗
# 2025-02-02 15:33:05,698 - INFO - 文章 901022 不符合條件或解析失敗
# 2025-02-02 15:33:05,701 - INFO - 文章 901021 不符合條件或解析失敗
# 2025-02-02 15:33:05,702 - INFO - 文章 901026 不符合條件或解析失敗
# 2025-02-02 15:33:05,703 - INFO - 文章 901032 不符合條件或解析失敗
# 2025-02-02 15:33:05,703 - INFO - 正在抓取文章 901024
# 2025-02-02 15:33:05,703 - INFO - 文章 901023 不符合條件或解析失敗
# 2025-02-02 15:33:05,729 - INFO - 正在抓取文章 901025
# 2025-02-02 15:33:05,732 - INFO - 正在抓取文章 901036
# 2025-02-02 15:33:05,737 - INFO - 文章 901028 回應狀態碼: 200
# 2025-02-02 15:33:05,738 - INFO - 正在抓取文章 901027
# 2025-02-02 15:33:05,743 - INFO - 正在抓取文章 901037
# 2025-02-02 15:33:05,747 - INFO - 文章 901033 不符合條件或解析失敗
# 2025-02-02 15:33:05,753 - INFO - 文章 901034 不符合條件或解析失敗
# 2025-02-02 15:33:05,754 - INFO - 正在抓取文章 901038
# 2025-02-02 15:33:05,757 - INFO - 文章 901035 不符合條件或解析失敗
# 2025-02-02 15:33:05,762 - INFO - 正在抓取文章 901031
# 2025-02-02 15:33:05,768 - INFO - 正在抓取文章 901039
# 2025-02-02 15:33:05,772 - INFO - 正在抓取文章 901040
# 2025-02-02 15:33:05,778 - INFO - 正在抓取文章 901026
# 2025-02-02 15:33:05,780 - INFO - 正在抓取文章 901032
# 2025-02-02 15:33:05,789 - INFO - 正在抓取文章 901041
# 2025-02-02 15:33:05,800 - INFO - 文章 901024 回應狀態碼: 200
# 2025-02-02 15:33:05,809 - INFO - 文章 901028 不符合條件或解析失敗
# 2025-02-02 15:33:05,811 - INFO - 文章 901025 回應狀態碼: 200
# 2025-02-02 15:33:05,818 - INFO - 文章 901036 回應狀態碼: 200
# 2025-02-02 15:33:05,821 - INFO - 正在抓取文章 901033
# 2025-02-02 15:33:05,825 - INFO - 文章 901027 回應狀態碼: 200
# 2025-02-02 15:33:05,826 - INFO - 正在抓取文章 901034
# 2025-02-02 15:33:05,833 - INFO - 文章 901037 回應狀態碼: 200
# 2025-02-02 15:33:05,839 - INFO - 正在抓取文章 901035
# 2025-02-02 15:33:05,851 - INFO - 文章 901038 回應狀態碼: 200
# 2025-02-02 15:33:05,854 - INFO - 文章 901031 回應狀態碼: 200
# 2025-02-02 15:33:05,864 - INFO - 文章 901024 不符合條件或解析失敗
# 2025-02-02 15:33:05,865 - INFO - 文章 901039 回應狀態碼: 200
# 2025-02-02 15:33:05,887 - INFO - 文章 901040 回應狀態碼: 200
# 2025-02-02 15:33:05,888 - INFO - 文章 901032 回應狀態碼: 200
# 2025-02-02 15:33:05,895 - INFO - 文章 901026 回應狀態碼: 200
# 2025-02-02 15:33:05,896 - INFO - 文章 901041 回應狀態碼: 200
# 2025-02-02 15:33:05,903 - INFO - 正在抓取文章 901028
# 2025-02-02 15:33:05,904 - INFO - 文章 901025 不符合條件或解析失敗
# 2025-02-02 15:33:05,905 - INFO - 文章 901036 不符合條件或解析失敗
# 2025-02-02 15:33:05,907 - INFO - 文章 901027 不符合條件或解析失敗
# 2025-02-02 15:33:05,950 - INFO - 文章 901033 回應狀態碼: 200
# 2025-02-02 15:33:06,025 - INFO - 文章 901037 不符合條件或解析失敗
# 2025-02-02 15:33:06,026 - INFO - 文章 901034 回應狀態碼: 200
# 2025-02-02 15:33:06,033 - INFO - 文章 901038 不符合條件或解析失敗
# 2025-02-02 15:33:06,035 - INFO - 文章 901031 不符合條件或解析失敗
# 2025-02-02 15:33:06,036 - INFO - 正在抓取文章 901042
# 2025-02-02 15:33:06,036 - INFO - 文章 901039 不符合條件或解析失敗
# 2025-02-02 15:33:06,038 - INFO - 文章 901040 不符合條件或解析失敗
# 2025-02-02 15:33:06,039 - INFO - 文章 901032 不符合條件或解析失敗
# 2025-02-02 15:33:06,041 - INFO - 文章 901026 不符合條件或解析失敗
# 2025-02-02 15:33:06,041 - INFO - 文章 901035 回應狀態碼: 200
# 2025-02-02 15:33:06,043 - INFO - 文章 901041 不符合條件或解析失敗
# 2025-02-02 15:33:06,045 - INFO - 正在抓取文章 901043
# 2025-02-02 15:33:06,046 - INFO - 正在抓取文章 901036
# 2025-02-02 15:33:06,048 - INFO - 正在抓取文章 901044
# 2025-02-02 15:33:06,049 - INFO - 文章 901033 不符合條件或解析失敗
# 2025-02-02 15:33:06,050 - INFO - 正在抓取文章 901037
# 2025-02-02 15:33:06,051 - INFO - 文章 901034 不符合條件或解析失敗
# 2025-02-02 15:33:06,052 - INFO - 正在抓取文章 901038
# 2025-02-02 15:33:06,053 - INFO - 正在抓取文章 901031
# 2025-02-02 15:33:06,054 - INFO - 文章 901028 回應狀態碼: 200
# 2025-02-02 15:33:06,056 - INFO - 正在抓取文章 901039
# 2025-02-02 15:33:06,056 - INFO - 正在抓取文章 901040
# 2025-02-02 15:33:06,057 - INFO - 正在抓取文章 901032
# 2025-02-02 15:33:06,058 - INFO - 正在抓取文章 901045
# 2025-02-02 15:33:06,059 - INFO - 文章 901035 不符合條件或解析失敗
# 2025-02-02 15:33:06,060 - INFO - 正在抓取文章 901041
# 2025-02-02 15:33:06,067 - INFO - 文章 901042 回應狀態碼: 200
# 2025-02-02 15:33:06,068 - INFO - 正在抓取文章 901033
# 2025-02-02 15:33:06,070 - INFO - 正在抓取文章 901034
# 2025-02-02 15:33:06,073 - INFO - 文章 901028 不符合條件或解析失敗
# 2025-02-02 15:33:06,075 - INFO - 文章 901036 回應狀態碼: 200
# 2025-02-02 15:33:06,076 - INFO - 文章 901043 回應狀態碼: 200
# 2025-02-02 15:33:06,077 - INFO - 文章 901044 回應狀態碼: 200
# 2025-02-02 15:33:06,081 - INFO - 文章 901037 回應狀態碼: 200
# 2025-02-02 15:33:06,083 - INFO - 文章 901031 回應狀態碼: 200
# 2025-02-02 15:33:06,084 - INFO - 文章 901038 回應狀態碼: 200
# 2025-02-02 15:33:06,085 - INFO - 正在抓取文章 901035
# 2025-02-02 15:33:06,089 - INFO - 文章 901039 回應狀態碼: 200
# 2025-02-02 15:33:06,089 - INFO - 文章 901040 回應狀態碼: 200
# 2025-02-02 15:33:06,090 - INFO - 文章 901042 不符合條件或解析失敗
# 2025-02-02 15:33:06,094 - INFO - 正在抓取文章 901046
# 2025-02-02 15:33:06,094 - INFO - 文章 901032 回應狀態碼: 200
# 2025-02-02 15:33:06,095 - INFO - 文章 901045 回應狀態碼: 200
# 2025-02-02 15:33:06,098 - INFO - 文章 901036 不符合條件或解析失敗
# 2025-02-02 15:33:06,099 - INFO - 文章 901041 回應狀態碼: 200
# 2025-02-02 15:33:06,100 - INFO - 文章 901043 不符合條件或解析失敗
# 2025-02-02 15:33:06,101 - INFO - 文章 901044 不符合條件或解析失敗
# 2025-02-02 15:33:06,102 - INFO - 文章 901037 不符合條件或解析失敗
# 2025-02-02 15:33:06,104 - INFO - 文章 901033 回應狀態碼: 200
# 2025-02-02 15:33:06,104 - INFO - 文章 901031 不符合條件或解析失敗
# 2025-02-02 15:33:06,105 - INFO - 文章 901034 回應狀態碼: 200
# 2025-02-02 15:33:06,106 - INFO - 文章 901038 不符合條件或解析失敗
# 2025-02-02 15:33:06,109 - INFO - 文章 901039 不符合條件或解析失敗
# 2025-02-02 15:33:06,110 - INFO - 文章 901040 不符合條件或解析失敗
# 2025-02-02 15:33:06,113 - INFO - 正在抓取文章 901042
# 2025-02-02 15:33:06,113 - INFO - 文章 901032 不符合條件或解析失敗
# 2025-02-02 15:33:06,116 - INFO - 文章 901045 不符合條件或解析失敗
# 2025-02-02 15:33:06,118 - INFO - 正在抓取文章 901036
# 2025-02-02 15:33:06,119 - INFO - 文章 901035 回應狀態碼: 200
# 2025-02-02 15:33:06,120 - INFO - 文章 901041 不符合條件或解析失敗
# 2025-02-02 15:33:06,121 - INFO - 正在抓取文章 901043
# 2025-02-02 15:33:06,121 - INFO - 正在抓取文章 901044
# 2025-02-02 15:33:06,123 - INFO - 正在抓取文章 901037
# 2025-02-02 15:33:06,124 - INFO - 文章 901033 不符合條件或解析失敗
# 2025-02-02 15:33:06,124 - INFO - 正在抓取文章 901047
# 2025-02-02 15:33:06,125 - INFO - 文章 901034 不符合條件或解析失敗
# 2025-02-02 15:33:06,127 - INFO - 文章 901046 回應狀態碼: 200
# 2025-02-02 15:33:06,127 - INFO - 正在抓取文章 901038
# 2025-02-02 15:33:06,128 - INFO - 正在抓取文章 901039
# 2025-02-02 15:33:06,129 - INFO - 正在抓取文章 901040
# 2025-02-02 15:33:06,132 - INFO - 正在抓取文章 901048
# 2025-02-02 15:33:06,133 - INFO - 正在抓取文章 901045
# 2025-02-02 15:33:06,136 - INFO - 文章 901035 不符合條件或解析失敗
# 2025-02-02 15:33:06,138 - INFO - 正在抓取文章 901041
# 2025-02-02 15:33:06,141 - INFO - 文章 901042 回應狀態碼: 200
# 2025-02-02 15:33:06,145 - INFO - 正在抓取文章 901049
# 2025-02-02 15:33:06,147 - INFO - 文章 901036 回應狀態碼: 200
# 2025-02-02 15:33:06,148 - INFO - 正在抓取文章 901050
# 2025-02-02 15:33:06,150 - INFO - 文章 901046 不符合條件或解析失敗
# 2025-02-02 15:33:06,151 - INFO - 文章 901043 回應狀態碼: 200
# 2025-02-02 15:33:06,152 - INFO - 文章 901044 回應狀態碼: 200
# 2025-02-02 15:33:06,154 - INFO - 文章 901037 回應狀態碼: 200
# 2025-02-02 15:33:06,156 - INFO - 文章 901047 回應狀態碼: 200
# 2025-02-02 15:33:06,162 - INFO - 文章 901038 回應狀態碼: 200
# 2025-02-02 15:33:06,162 - INFO - 正在抓取文章 901051
# 2025-02-02 15:33:06,165 - INFO - 文章 901042 不符合條件或解析失敗
# 2025-02-02 15:33:06,166 - INFO - 文章 901039 回應狀態碼: 200
# 2025-02-02 15:33:06,166 - INFO - 文章 901040 回應狀態碼: 200
# 2025-02-02 15:33:06,170 - INFO - 文章 901036 不符合條件或解析失敗
# 2025-02-02 15:33:06,171 - INFO - 文章 901048 回應狀態碼: 200
# 2025-02-02 15:33:06,172 - INFO - 文章 901045 回應狀態碼: 200
# 2025-02-02 15:33:06,174 - INFO - 正在抓取文章 901046
# 2025-02-02 15:33:06,176 - INFO - 文章 901041 回應狀態碼: 200
# 2025-02-02 15:33:06,176 - INFO - 文章 901043 不符合條件或解析失敗
# 2025-02-02 15:33:06,178 - INFO - 文章 901044 不符合條件或解析失敗
# 2025-02-02 15:33:06,179 - INFO - 文章 901037 不符合條件或解析失敗
# 2025-02-02 15:33:06,180 - INFO - 文章 901047 不符合條件或解析失敗
# 2025-02-02 15:33:06,181 - INFO - 文章 901038 不符合條件或解析失敗
# 2025-02-02 15:33:06,182 - INFO - 文章 901049 回應狀態碼: 200
# 2025-02-02 15:33:06,183 - INFO - 文章 901050 回應狀態碼: 200
# 2025-02-02 15:33:06,186 - INFO - 正在抓取文章 901042
# 2025-02-02 15:33:06,188 - INFO - 文章 901039 不符合條件或解析失敗
# 2025-02-02 15:33:06,189 - INFO - 文章 901040 不符合條件或解析失敗
# 2025-02-02 15:33:06,190 - INFO - 正在抓取文章 901052
# 2025-02-02 15:33:06,192 - INFO - 文章 901048 不符合條件或解析失敗
# 2025-02-02 15:33:06,193 - INFO - 文章 901045 不符合條件或解析失敗
# 2025-02-02 15:33:06,196 - INFO - 文章 901051 回應狀態碼: 200
# 2025-02-02 15:33:06,197 - INFO - 文章 901041 不符合條件或解析失敗
# 2025-02-02 15:33:06,198 - INFO - 正在抓取文章 901043
# 2025-02-02 15:33:06,200 - INFO - 正在抓取文章 901044
# 2025-02-02 15:33:06,200 - INFO - 正在抓取文章 901053
# 2025-02-02 15:33:06,203 - INFO - 正在抓取文章 901047
# 2025-02-02 15:33:06,204 - INFO - 正在抓取文章 901054
# 2025-02-02 15:33:06,205 - INFO - 文章 901049 不符合條件或解析失敗
# 2025-02-02 15:33:06,207 - INFO - 文章 901050 不符合條件或解析失敗
# 2025-02-02 15:33:06,210 - INFO - 正在抓取文章 901055
# 2025-02-02 15:33:06,211 - INFO - 正在抓取文章 901056
# 2025-02-02 15:33:06,214 - INFO - 正在抓取文章 901048
# 2025-02-02 15:33:06,215 - INFO - 正在抓取文章 901045
# 2025-02-02 15:33:06,216 - INFO - 文章 901051 不符合條件或解析失敗
# 2025-02-02 15:33:06,217 - INFO - 文章 901046 回應狀態碼: 200
# 2025-02-02 15:33:06,218 - INFO - 正在抓取文章 901057
# 2025-02-02 15:33:06,219 - INFO - 文章 901042 回應狀態碼: 200
# 2025-02-02 15:33:06,225 - INFO - 文章 901052 回應狀態碼: 200
# 2025-02-02 15:33:06,230 - INFO - 正在抓取文章 901049
# 2025-02-02 15:33:06,231 - INFO - 正在抓取文章 901050
# 2025-02-02 15:33:06,233 - INFO - 文章 901043 回應狀態碼: 200
# 2025-02-02 15:33:06,234 - INFO - 文章 901044 回應狀態碼: 200
# 2025-02-02 15:33:06,236 - INFO - 文章 901053 回應狀態碼: 200
# 2025-02-02 15:33:06,237 - INFO - 文章 901047 回應狀態碼: 200
# 2025-02-02 15:33:06,239 - INFO - 文章 901054 回應狀態碼: 200
# 2025-02-02 15:33:06,245 - INFO - 正在抓取文章 901051
# 2025-02-02 15:33:06,246 - INFO - 文章 901055 回應狀態碼: 200
# 2025-02-02 15:33:06,247 - INFO - 文章 901046 不符合條件或解析失敗
# 2025-02-02 15:33:06,250 - INFO - 文章 901042 不符合條件或解析失敗
# 2025-02-02 15:33:06,251 - INFO - 文章 901056 回應狀態碼: 200
# 2025-02-02 15:33:06,252 - INFO - 文章 901048 回應狀態碼: 200
# 2025-02-02 15:33:06,253 - INFO - 文章 901052 不符合條件或解析失敗
# 2025-02-02 15:33:06,254 - INFO - 文章 901045 回應狀態碼: 200
# 2025-02-02 15:33:06,259 - INFO - 文章 901043 不符合條件或解析失敗
# 2025-02-02 15:33:06,260 - INFO - 文章 901057 回應狀態碼: 200
# 2025-02-02 15:33:06,261 - INFO - 文章 901044 不符合條件或解析失敗
# 2025-02-02 15:33:06,262 - INFO - 文章 901053 不符合條件或解析失敗
# 2025-02-02 15:33:06,264 - INFO - 文章 901047 不符合條件或解析失敗
# 2025-02-02 15:33:06,265 - INFO - 文章 901054 不符合條件或解析失敗
# 2025-02-02 15:33:06,268 - INFO - 文章 901049 回應狀態碼: 200
# 2025-02-02 15:33:06,269 - INFO - 文章 901050 回應狀態碼: 200
# 2025-02-02 15:33:06,270 - INFO - 文章 901055 不符合條件或解析失敗
# 2025-02-02 15:33:06,271 - INFO - 正在抓取文章 901046
# 2025-02-02 15:33:06,272 - INFO - 正在抓取文章 901058
# 2025-02-02 15:33:06,273 - INFO - 文章 901056 不符合條件或解析失敗
# 2025-02-02 15:33:06,275 - INFO - 文章 901048 不符合條件或解析失敗
# 2025-02-02 15:33:06,276 - INFO - 正在抓取文章 901052
# 2025-02-02 15:33:06,277 - INFO - 文章 901051 回應狀態碼: 200
# 2025-02-02 15:33:06,278 - INFO - 文章 901045 不符合條件或解析失敗
# 2025-02-02 15:33:06,279 - INFO - 正在抓取文章 901059
# 2025-02-02 15:33:06,280 - INFO - 文章 901057 不符合條件或解析失敗
# 2025-02-02 15:33:06,282 - INFO - 正在抓取文章 901060
# 2025-02-02 15:33:06,283 - INFO - 正在抓取文章 901053
# 2025-02-02 15:33:06,283 - INFO - 正在抓取文章 901047
# 2025-02-02 15:33:06,283 - INFO - 正在抓取文章 901054
# 2025-02-02 15:33:06,283 - INFO - 文章 901049 不符合條件或解析失敗
# 2025-02-02 15:33:06,283 - INFO - 文章 901050 不符合條件或解析失敗
# 2025-02-02 15:33:06,325 - INFO - 正在抓取文章 901050
# 2025-02-02 15:33:06,283 - INFO - 正在抓取文章 901056
# 2025-02-02 15:33:06,283 - INFO - 正在抓取文章 901048
# 2025-02-02 15:33:06,301 - INFO - 文章 901051 不符合條件或解析失敗
# 2025-02-02 15:33:06,346 - INFO - 正在抓取文章 901051
# 2025-02-02 15:33:06,303 - INFO - 文章 901058 回應狀態碼: 200
# 2025-02-02 15:33:06,304 - INFO - 正在抓取文章 901061
# 2025-02-02 15:33:06,305 - INFO - 正在抓取文章 901057
# 2025-02-02 15:33:06,311 - INFO - 文章 901052 回應狀態碼: 200
# 2025-02-02 15:33:06,319 - INFO - 文章 901059 回應狀態碼: 200
# 2025-02-02 15:33:06,322 - INFO - 正在抓取文章 901049
# 2025-02-02 15:33:06,283 - INFO - 正在抓取文章 901055
# 2025-02-02 15:33:06,326 - INFO - 文章 901053 回應狀態碼: 200
# 2025-02-02 15:33:06,328 - INFO - 文章 901047 回應狀態碼: 200
# 2025-02-02 15:33:06,331 - INFO - 文章 901054 回應狀態碼: 200
# 2025-02-02 15:33:06,342 - INFO - 文章 901060 回應狀態碼: 200
