# %% [markdown]
# # 可以抓取舊文章和新文章

# %%
import os
import time
import random
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib.parse
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
from pathlib import Path
import logging
from tqdm import tqdm
import hashlib
import re
import urllib3
from typing import Optional, Dict, Any, List

class ArticleScraper:
    def __init__(self, scan_mode="all", data_file="articles.xlsx"):
        """初始化爬蟲設定"""
        # 常量設定
        self.SETTINGS = {
            'BASE_URL': "https://real-estate.get.com.tw/Columns/",
            'TARGET_AUTHORS': ["曾榮耀", "許文昌", "蘇偉強"],
            'JOURNAL_PARAMS': {
                "no": "1282",
                "pno": "51121"
            },
            'PERFORMANCE': {
                'BATCH_SIZE': 50,
                'MAX_WORKERS': 4,
                'MAX_RETRIES': 5,
                'RETRY_DELAY': 3,
                'REQUEST_INTERVAL': 1.5
            },
            'ARTICLE_RANGES': [
                {
                    "start": 900000,
                    "end": 915000,
                    "description": "新年份範圍"
                },
                {
                    "start": 409187,
                    "end": 421516,
                    "description": "早期年份範圍"
                }
            ]
        }

        # 基本設定
        self.base_url = self.SETTINGS['BASE_URL']
        self.detail_url = f"{self.base_url}detail.aspx"
        self.journal_url = f"{self.base_url}journal.aspx"
        self.target_authors = self.SETTINGS['TARGET_AUTHORS']
        self.scan_mode = scan_mode
        self.data_file = Path(data_file)

        # 期刊參數設定
        self.journal_params = self.SETTINGS['JOURNAL_PARAMS']

        # 時間範圍設定
        self.end_date = datetime.now()
        self.start_date = self.end_date - timedelta(days=9*365)

        # 效能設定
        self.batch_size = self.SETTINGS['PERFORMANCE']['BATCH_SIZE']
        self.max_workers = self.SETTINGS['PERFORMANCE']['MAX_WORKERS']
        self.max_retries = self.SETTINGS['PERFORMANCE']['MAX_RETRIES']
        self.retry_delay = self.SETTINGS['PERFORMANCE']['RETRY_DELAY']
        self.request_interval = self.SETTINGS['PERFORMANCE']['REQUEST_INTERVAL']

        # 文章編號範圍設定
        self.article_ranges = self.SETTINGS['ARTICLE_RANGES']

        # 初始化其他組件
        self.setup_directories()
        self.setup_session()
        self.setup_logger()
        self.processed_articles = set()
        self.load_processed_articles()
        self.last_request_time = 0

        # 記錄範圍資訊到日誌
        for range_info in self.article_ranges:
            self.logger.info(
                f"設定文章範圍: {range_info['description']} - "
                f"從 {range_info['start']} 到 {range_info['end']}"
            )



    def setup_directories(self):
        """建立必要的目錄結構"""
        self.base_dir = Path("real_estate_articles")
        self.articles_dir = self.base_dir / "articles"
        self.images_dir = self.articles_dir / "images"
        self.logs_dir = self.base_dir / "logs"

        for directory in [self.base_dir, self.articles_dir, self.images_dir, self.logs_dir]:
            directory.mkdir(parents=True, exist_ok=True)

        # 創建預設的失敗圖片
        self.failed_image_path = self.images_dir / "image_download_failed.png"
        if not self.failed_image_path.exists():
            try:
                from PIL import Image, ImageDraw
                img = Image.new('RGB', (400, 100), color='white')
                d = ImageDraw.Draw(img)
                d.text((10, 40), "Image Download Failed", fill='black')
                img.save(self.failed_image_path)
            except Exception:
                self.failed_image_path.touch()

    def setup_session(self):
        """設定請求session"""
        urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
            'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
            'Accept-Encoding': 'gzip, deflate',
            'Connection': 'keep-alive',
            'Upgrade-Insecure-Requests': '1'
        })

    def setup_logger(self):
        """設定日誌系統"""
        self.logger = logging.getLogger('ArticleScraper')
        self.logger.setLevel(logging.INFO)

        log_file = self.logs_dir / f"scraper_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
        handlers = [
            logging.FileHandler(log_file, encoding='utf-8'),
            logging.StreamHandler()
        ]

        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        for handler in handlers:
            handler.setFormatter(formatter)
            self.logger.addHandler(handler)

    def load_processed_articles(self):
        """載入已處理的文章"""
        if self.data_file.exists():
            df = pd.read_excel(self.data_file)
            if '文章編號' in df.columns:
                self.processed_articles = set(df['文章編號'].astype(str))

    def wait_between_requests(self):
        """控制請求間隔"""
        current_time = time.time()
        elapsed = current_time - self.last_request_time
        if elapsed < self.request_interval:
            time.sleep(self.request_interval - elapsed)
        self.last_request_time = current_time

    def get_max_page_number(self) -> int:
        """獲取期刊最大頁數"""
        try:
            self.wait_between_requests()
            response = self.session.get(
                self.journal_url,
                params=self.journal_params,
                timeout=30,
                verify=False
            )
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 找到分頁元素
            pagination = soup.select('.pagination a')
            if pagination:
                page_numbers = []
                for a in pagination:
                    try:
                        page_numbers.append(int(a.text.strip()))
                    except ValueError:
                        continue
                return max(page_numbers) if page_numbers else 1
            return 1
            
        except Exception as e:
            self.logger.error(f"獲取最大頁數失敗: {str(e)}")
            return 30  # 預設較大的頁數以確保不遺漏

    def get_article_urls_from_journal(self, page_no: int) -> List[int]:
        """從期刊頁面獲取文章編號列表"""
        try:
            params = self.journal_params.copy()
            params['page_no'] = page_no
            
            self.wait_between_requests()
            response = self.session.get(
                self.journal_url,
                params=params,
                timeout=30,
                verify=False
            )
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            articles = []
            for link in soup.select('a[href*="detail.aspx?no="]'):
                href = link.get('href', '')
                if 'no=' in href:
                    article_no = href.split('no=')[-1]
                    try:
                        article_no = int(article_no)
                        if str(article_no) not in self.processed_articles:
                            articles.append(article_no)
                    except ValueError:
                        continue
                        
            return articles
            
        except Exception as e:
            self.logger.error(f"獲取第 {page_no} 頁文章列表失敗: {str(e)}")
            return []

    def fetch_article(self, article_no: int) -> Optional[Dict]:
        """抓取單篇文章"""
        if str(article_no) in self.processed_articles:
            return None

        for retry in range(self.max_retries):
            try:
                params = {'no': article_no}
                self.wait_between_requests()

                self.logger.info(f"正在抓取文章 {article_no}")
                response = self.session.get(
                    self.detail_url,
                    params=params,
                    timeout=30,
                    verify=False
                )

                self.logger.info(f"文章 {article_no} 回應狀態碼: {
                                 response.status_code}")

                if response.status_code == 404:
                    self.logger.info(f"文章 {article_no} 不存在")
                    return None

                response.raise_for_status()
                response.encoding = 'utf-8'

                soup = BeautifulSoup(response.text, 'html.parser')
                article_data = self.parse_article(soup, article_no)

                if article_data and self.validate_article(article_data):
                    self.logger.info(f"成功解析文章 {article_no}")
                    return article_data
                else:
                    self.logger.info(f"文章 {article_no} 不符合條件或解析失敗")
                    return None

            except requests.exceptions.RequestException as e:
                self.logger.error(f"抓取文章 {article_no} 失敗 (嘗試 {
                                  retry + 1}/{self.max_retries}): {str(e)}")
                if hasattr(e, 'response') and hasattr(e.response, 'text'):
                    self.logger.error(f"錯誤回應內容: {e.response.text[:200]}")
                if retry < self.max_retries - 1:
                    time.sleep(self.retry_delay * (retry + 1))
                    continue
            except Exception as e:
                self.logger.error(f"處理文章 {article_no} 時發生未預期錯誤: {str(e)}")
                break

        return None

    def parse_article(self, soup: BeautifulSoup, article_no: int) -> Optional[Dict]:
        """解析文章內容"""
        try:
            # 先只解析作者欄位,如果不符合就直接返回
            author = None
            article_info = {}

            for row in soup.select('.columnsDetail_tableRow'):
                th = row.select_one('.columnsDetail_tableth')
                td = row.select_one('.columnsDetail_tabletd')
                if th and td:
                    key = th.text.strip()
                    value = td.text.strip()
                    article_info[key] = value

                    if key == '內文':
                        article_info['內文HTML'] = str(td)
                    elif key == '作者':
                        author = value

            # 如果不是目標作者就直接返回
            if not author or not any(target in author for target in self.target_authors):
                return None

            # 處理文章內容和圖片
            content = self.process_content(
                article_info.get('內文HTML', ''), article_no)

            return {
                '文章編號': article_no,
                '標題': article_info.get('篇名', ''),
                '作者': author,
                '日期': article_info.get('日期', ''),
                '內文': content,
                'URL': f"{self.detail_url}?no={article_no}",
                '爬取時間': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            }

        except Exception as e:
            self.logger.error(f"解析文章 {article_no} 失敗: {str(e)}")
            return None
        
    def download_image(self, img_url: str, article_no: int) -> Optional[str]:
        """下載圖片並返回本地檔名"""
        try:
            if not img_url.startswith(('http://', 'https://')):
                img_url = urllib.parse.urljoin(self.base_url, img_url)
            
            # 生成唯一的檔名
            url_hash = hashlib.md5(img_url.encode()).hexdigest()[:8]
            file_ext = os.path.splitext(img_url)[1] or '.jpg'
            local_filename = f"{article_no}_{url_hash}{file_ext}"
            local_path = self.images_dir / local_filename
            
            # 如果圖片已存在就直接返回
            if local_path.exists():
                return local_filename
                
            # 下載圖片
            self.wait_between_requests()
            response = self.session.get(img_url, timeout=30, verify=False)
            response.raise_for_status()
            
            # 保存圖片
            with open(local_path, 'wb') as f:
                f.write(response.content)
                
            return local_filename
            
        except Exception as e:
            self.logger.error(f"下載圖片失敗 ({img_url}): {str(e)}")
            return None

    def process_content(self, html_content: str, article_no: int) -> str:
        """處理文章內容，包括下載圖片和清理HTML"""
        if not html_content:
            return ""

        soup = BeautifulSoup(html_content, 'html.parser')
        image_references = []  # 用於存儲圖片引用

        # 處理圖片
        for index, img in enumerate(soup.find_all('img'), 1):
            img_url = img.get('src', '')
            if img_url:
                local_filename = self.download_image(img_url, article_no)
                if local_filename:
                    # 保存圖片引用
                    image_references.append(f"\n![圖片{index}](./images/{local_filename})\n")
                    # 在原文中插入圖片標記
                    img.replace_with(f"[圖片{index}]")
                else:
                    img.replace_with("[圖片下載失敗]")

        # 清理HTML並格式化
        content = self._format_content(soup)
        
        # 在文章末尾添加所有圖片
        if image_references:
            content += "\n\n## 文章圖片\n"
            content += "".join(image_references)

        return content

    def _format_content(self, soup: BeautifulSoup) -> str:
        """格式化文章內容，處理換行和縮排"""
        # 允許的HTML標籤
        allowed_tags = {'p', 'br', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'ul', 'ol', 'li'}

        # 移除不允許的標籤但保留其文本
        for tag in soup.find_all():
            if tag.name not in allowed_tags:
                tag.unwrap()

        # 確保段落之間有適當的換行
        for p in soup.find_all('p'):
            text = p.get_text().strip()
            if text:  # 只處理非空段落
                p.string = ' '.join(text.split())
                p.append('\n\n')

        # 處理標題
        for h in soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6']):
            level = int(h.name[1])  # 獲取標題級別
            prefix = '#' * level + ' '  # 根據級別添加 # 符號
            h.string = f'\n{prefix}{h.get_text().strip()}\n'

        # 處理列表
        for li in soup.find_all('li'):
            indent = '  '
            if li.parent.name == 'ol':
                # 為有序列表添加數字
                index = len(li.find_previous_siblings('li')) + 1
                li.insert(0, f'{indent}{index}. ')
            else:
                # 為無序列表添加圓點
                li.insert(0, f'{indent}• ')
            li.append('\n')

        # 獲取處理後的文本
        content = soup.get_text()

        # 清理最終文本
        content = re.sub(r'\n{3,}', '\n\n', content)  # 移除過多的空行
        content = re.sub(r'[ \t]+', ' ', content)     # 標準化空格
        content = re.sub(r' *\n *', '\n', content)    # 清理行首尾空格

        # 分段處理並保持段落間的空行
        paragraphs = [p.strip() for p in content.split('\n') if p.strip()]
        formatted_content = '\n\n'.join(paragraphs)

        return formatted_content.strip()



    def validate_article(self, article_data: Dict) -> bool:
        """驗證文章資料完整性"""
        required_fields = ['標題', '作者', '日期', '內文']
        return all(field in article_data and article_data[field] for field in required_fields)

    def save_article(self, article_data: Dict) -> None:
        """儲存文章"""
        try:
            # 更新 Excel 資料
            new_df = pd.DataFrame([article_data])
            if self.data_file.exists():
                df = pd.read_excel(self.data_file)
                df = pd.concat([df, new_df]).drop_duplicates(subset=['文章編號'])
            else:
                df = new_df
            df.to_excel(self.data_file, index=False)

            # 建立 Markdown 文件
            article_no = article_data['文章編號']
            title = re.sub(r'[<>:"/\\|?*]', '', article_data['標題'])[:100]

            markdown_content = f"""# {article_data['標題']}

## 文章資訊
- 文章編號：{article_no}
- 作者：{article_data['作者']}
- 發布日期：{article_data['日期']}
- 爬取時間：{article_data['爬取時間']}
- 原文連結：[閱讀原文]({article_data['URL']})

## 內文
{article_data['內文']}

---
*注：本文圖片存放於 ./images/ 目錄下*
"""

            # 儲存 Markdown 文件
            file_path = self.articles_dir / f"{article_no}_{title}.md"
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(markdown_content)

            # 更新已處理集合
            self.processed_articles.add(str(article_no))

        except Exception as e:
            self.logger.error(f"儲存文章失敗: {str(e)}")
            
            
    def create_index(self):
        """創建文章索引，整合原有目錄內容"""
        try:
            # 讀取 Excel 檔案獲取所有文章資訊
            if not self.data_file.exists():
                return
                
            df = pd.read_excel(self.data_file)
            
            # 讀取現有的目錄文件（如果存在）
            index_path = self.base_dir / "README.md"
            existing_content = []
            existing_articles = set()
            
            if index_path.exists():
                with open(index_path, 'r', encoding='utf-8') as f:
                    existing_content = f.read().splitlines()
                    # 提取現有目錄中的文章編號
                    for line in existing_content:
                        if match := re.search(r'/(\d+)_[^/]+\.md', line):
                            existing_articles.add(match.group(1))
            
            # 只處理新文章
            df['文章編號'] = df['文章編號'].astype(str)
            new_articles = df[~df['文章編號'].isin(existing_articles)]
            
            if new_articles.empty and existing_content:
                self.logger.info("沒有新文章需要添加到目錄")
                return
                
            # 如果有現有內容，保留開頭的通用部分（如標題）
            index_content = []
            for line in existing_content:
                if line.startswith('## '):
                    break
                index_content.append(line)
            
            if not index_content:  # 如果是全新的目錄
                index_content = ["# 文章目錄", ""]
            
            # 合併現有文章和新文章
            all_articles = pd.concat([
                df[df['文章編號'].isin(existing_articles)],
                new_articles
            ]).drop_duplicates(subset=['文章編號'])
            
            # 按作者和日期排序
            all_articles['日期'] = pd.to_datetime(all_articles['日期'])
            all_articles = all_articles.sort_values(['作者', '日期'], ascending=[True, False])
            
            # 按作者分組
            for author in sorted(all_articles['作者'].unique()):
                index_content.append(f"## {author}")
                author_articles = all_articles[all_articles['作者'] == author]
                
                # 按年份分組
                for year in sorted(author_articles['日期'].dt.year.unique(), reverse=True):
                    index_content.append(f"\n### {year}年")
                    year_articles = author_articles[author_articles['日期'].dt.year == year]
                    
                    # 生成文章列表
                    for _, article in year_articles.iterrows():
                        title = re.sub(r'[<>:"/\\|?*]', '', article['標題'])[:100]
                        file_name = f"{article['文章編號']}_{title}.md"
                        date_str = article['日期'].strftime('%Y-%m-%d')
                        index_content.append(
                            f"- {date_str} [{article['標題']}](./articles/{file_name})"
                        )
                
                index_content.append("")  # 作者之間加入空行
            
            # 保存更新後的目錄文件
            with open(index_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(index_content))
                
            self.logger.info(f"已成功更新文章目錄，新增 {len(new_articles)} 篇文章")
            
        except Exception as e:
            self.logger.error(f"更新目錄失敗: {str(e)}")


    def run(self):
        """執行爬蟲"""
        self.logger.info(f"開始執行爬蟲 (模式: {self.scan_mode})")

        success_count = 0
        fail_count = 0

        try:
            with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                futures = []

                # 從期刊頁面獲取文章
                max_page = self.get_max_page_number()
                self.logger.info(f"檢測到期刊總頁數: {max_page}")

                article_numbers = set()

                # 收集所有文章編號
                for page_no in range(1, max_page + 1):
                    self.logger.info(f"正在獲取第 {page_no} 頁的文章列表")
                    page_articles = self.get_article_urls_from_journal(page_no)
                    article_numbers.update(page_articles)

                    if not page_articles:
                        self.logger.warning(f"第 {page_no} 頁沒有找到新文章，可能已到達最後一頁")
                        break

                self.logger.info(f"從期刊頁面共找到 {len(article_numbers)} 篇新文章")

                # 處理找到的文章
                for article_no in article_numbers:
                    if str(article_no) not in self.processed_articles:
                        futures.append(executor.submit(self.fetch_article, article_no))

                # 如果是全量模式，掃描所有編號範圍
                if self.scan_mode == "all":
                    for range_info in self.article_ranges:
                        self.logger.info(f"開始處理範圍 {range_info['start']} 到 {range_info['end']}")
                        for article_no in range(range_info['start'], range_info['end'] + 1, self.batch_size):
                            batch = range(article_no, min(
                                article_no + self.batch_size, range_info['end'] + 1))
                            futures.extend([
                                executor.submit(self.fetch_article, no)
                                for no in batch
                                if str(no) not in self.processed_articles
                            ])

                # 處理結果
                with tqdm(total=len(futures), desc="處理文章") as pbar:
                    for future in futures:
                        try:
                            result = future.result()
                            if result:
                                self.save_article(result)
                                success_count += 1
                            else:
                                fail_count += 1
                            pbar.update(1)
                        except Exception as e:
                            self.logger.error(f"處理文章結果失敗: {str(e)}")
                            fail_count += 1
                            pbar.update(1)

        finally:
            self.logger.info(f"成功處理文章數: {success_count}")
            self.logger.info(f"失敗處理文章數: {fail_count}")
            self.create_index()
            self.logger.info("程式結束執行")



if __name__ == "__main__":
    # 建立爬蟲實例並執行
    scraper = ArticleScraper(scan_mode="all")
    scraper.run()
# Out:
# 2025-02-05 19:34:10,306 - INFO - 設定文章範圍: 新年份範圍 - 從 900000 到 915000
# 2025-02-05 19:34:10,306 - INFO - 設定文章範圍: 早期年份範圍 - 從 409187 到 421516
# 2025-02-05 19:34:10,306 - INFO - 開始執行爬蟲 (模式: all)
# 2025-02-05 19:34:10,883 - INFO - 檢測到期刊總頁數: 1
# 2025-02-05 19:34:10,883 - INFO - 正在獲取第 1 頁的文章列表
# 2025-02-05 19:34:11,850 - WARNING - 第 1 頁沒有找到新文章，可能已到達最後一頁
# 2025-02-05 19:34:11,850 - INFO - 從期刊頁面共找到 0 篇新文章
# 2025-02-05 19:34:11,850 - INFO - 開始處理範圍 900000 到 915000
# 2025-02-05 19:34:12,199 - INFO - 開始處理範圍 409187 到 421516
# 2025-02-05 19:34:12,467 - INFO - 正在抓取文章 900002
# 2025-02-05 19:34:12,467 - INFO - 正在抓取文章 900001
# 2025-02-05 19:34:12,467 - INFO - 正在抓取文章 900003
# 2025-02-05 19:34:12,483 - INFO - 正在抓取文章 900000
# 2025-02-05 19:34:12,501 - INFO - 文章 900002 回應狀態碼: 200
# 2025-02-05 19:34:12,502 - INFO - 文章 900002 不符合條件或解析失敗
# 處理文章:   0%|          | 0/26520 [00:00<?, ?it/s]2025-02-05 19:34:13,015 - INFO - 文章 900001 回應狀態碼: 200
# 2025-02-05 19:34:13,015 - INFO - 文章 900001 不符合條件或解析失敗
# 2025-02-05 19:34:13,051 - INFO - 文章 900000 回應狀態碼: 200
# 2025-02-05 19:34:13,051 - INFO - 文章 900000 不符合條件或解析失敗
# 處理文章:   0%|          | 1/26520 [00:00<3:28:19,  2.12it/s]2025-02-05 19:34:13,069 - INFO - 文章 900003 回應狀態碼: 200
# 2025-02-05 19:34:13,069 - INFO - 文章 900003 不符合條件或解析失敗
# 2025-02-05 19:34:13,367 - INFO - 正在抓取文章 900004
# 2025-02-05 19:34:13,371 - INFO - 正在抓取文章 900006
# 2025-02-05 19:34:13,376 - INFO - 正在抓取文章 900007
# 2025-02-05 19:34:13,376 - INFO - 正在抓取文章 900005
# 2025-02-05 19:34:13,380 - INFO - 文章 900004 回應狀態碼: 200
# 2025-02-05 19:34:13,382 - INFO - 文章 900006 回應狀態碼: 200
# 2025-02-05 19:34:13,383 - INFO - 文章 900004 不符合條件或解析失敗
# 處理文章:   0%|          | 5/26520 [00:00<1:02:23,  7.08it/s]2025-02-05 19:34:13,384 - INFO - 文章 900006 不符合條件或解析失敗
# 2025-02-05 19:34:13,400 - INFO - 文章 900007 回應狀態碼: 200
# 2025-02-05 19:34:13,401 - INFO - 文章 900007 不符合條件或解析失敗
# 2025-02-05 19:34:13,401 - INFO - 文章 900005 回應狀態碼: 200
# 2025-02-05 19:34:13,404 - INFO - 文章 900005 不符合條件或解析失敗
# 2025-02-05 19:34:14,516 - INFO - 正在抓取文章 900009
# 2025-02-05 19:34:14,517 - INFO - 正在抓取文章 900011
# 2025-02-05 19:34:14,517 - INFO - 正在抓取文章 900008
# 2025-02-05 19:34:14,518 - INFO - 正在抓取文章 900010
# 2025-02-05 19:34:14,521 - INFO - 文章 900009 回應狀態碼: 200
# 2025-02-05 19:34:14,521 - INFO - 文章 900009 不符合條件或解析失敗
# 2025-02-05 19:34:14,532 - INFO - 文章 900011 回應狀態碼: 200
# 2025-02-05 19:34:14,533 - INFO - 文章 900011 不符合條件或解析失敗
# 2025-02-05 19:34:14,534 - INFO - 文章 900010 回應狀態碼: 200
# 2025-02-05 19:34:14,535 - INFO - 文章 900008 回應狀態碼: 200
# 2025-02-05 19:34:14,536 - INFO - 文章 900010 不符合條件或解析失敗
# 2025-02-05 19:34:14,538 - INFO - 文章 900008 不符合條件或解析失敗
# 處理文章:   0%|          | 9/26520 [00:01<1:38:07,  4.50it/s]2025-02-05 19:34:14,901 - INFO - 正在抓取文章 900013
# 2025-02-05 19:34:14,902 - INFO - 正在抓取文章 900015
# 2025-02-05 19:34:14,902 - INFO - 正在抓取文章 900014
# 2025-02-05 19:34:14,911 - INFO - 正在抓取文章 900012
# 2025-02-05 19:34:14,915 - INFO - 文章 900013 回應狀態碼: 200
# 2025-02-05 19:34:14,916 - INFO - 文章 900013 不符合條件或解析失敗
# 2025-02-05 19:34:14,918 - INFO - 文章 900014 回應狀態碼: 200
# 2025-02-05 19:34:14,919 - INFO - 文章 900014 不符合條件或解析失敗
# 2025-02-05 19:34:14,922 - INFO - 文章 900012 回應狀態碼: 200
# 2025-02-05 19:34:14,922 - INFO - 文章 900012 不符合條件或解析失敗
# 處理文章:   0%|          | 13/26520 [00:02<1:13:35,  6.00it/s]2025-02-05 19:34:14,922 - INFO - 文章 900015 回應狀態碼: 200
# 2025-02-05 19:34:14,922 - INFO - 文章 900015 不符合條件或解析失敗
# 2025-02-05 19:34:16,021 - INFO - 正在抓取文章 900019
# 2025-02-05 19:34:16,021 - INFO - 正在抓取文章 900016
# 2025-02-05 19:34:16,022 - INFO - 正在抓取文章 900017
# 2025-02-05 19:34:16,024 - INFO - 正在抓取文章 900018
# 2025-02-05 19:34:16,024 - INFO - 文章 900019 回應狀態碼: 200
# 2025-02-05 19:34:16,034 - INFO - 文章 900019 不符合條件或解析失敗
# 2025-02-05 19:34:16,034 - INFO - 文章 900016 回應狀態碼: 200
# 2025-02-05 19:34:16,034 - INFO - 文章 900016 不符合條件或解析失敗
# 處理文章:   0%|          | 17/26520 [00:03<1:32:33,  4.77it/s]2025-02-05 19:34:16,040 - INFO - 文章 900017 回應狀態碼: 200
# 2025-02-05 19:34:16,041 - INFO - 文章 900017 不符合條件或解析失敗
# 2025-02-05 19:34:16,041 - INFO - 文章 900018 回應狀態碼: 200
# 2025-02-05 19:34:16,041 - INFO - 文章 900018 不符合條件或解析失敗
# 2025-02-05 19:34:16,424 - INFO - 正在抓取文章 900020
# 2025-02-05 19:34:16,424 - INFO - 正在抓取文章 900022
# 2025-02-05 19:34:16,426 - INFO - 正在抓取文章 900021
# 2025-02-05 19:34:16,427 - INFO - 正在抓取文章 900023
# 2025-02-05 19:34:16,437 - INFO - 文章 900020 回應狀態碼: 200
# 2025-02-05 19:34:16,437 - INFO - 文章 900020 不符合條件或解析失敗
# 處理文章:   0%|          | 21/26520 [00:03<1:15:33,  5.85it/s]2025-02-05 19:34:16,441 - INFO - 文章 900022 回應狀態碼: 200
# 2025-02-05 19:34:16,442 - INFO - 文章 900023 回應狀態碼: 200
# 2025-02-05 19:34:16,442 - INFO - 文章 900021 回應狀態碼: 200
# 2025-02-05 19:34:16,442 - INFO - 文章 900022 不符合條件或解析失敗
# 2025-02-05 19:34:16,442 - INFO - 文章 900023 不符合條件或解析失敗
# 2025-02-05 19:34:16,442 - INFO - 文章 900021 不符合條件或解析失敗
# 2025-02-05 19:34:17,541 - INFO - 正在抓取文章 900024
# 2025-02-05 19:34:17,547 - INFO - 正在抓取文章 900025
# 2025-02-05 19:34:17,548 - INFO - 正在抓取文章 900026
# 2025-02-05 19:34:17,549 - INFO - 正在抓取文章 900027
# 2025-02-05 19:34:17,571 - INFO - 文章 900025 回應狀態碼: 200
# 2025-02-05 19:34:17,571 - INFO - 文章 900027 回應狀態碼: 200
# 2025-02-05 19:34:17,571 - INFO - 文章 900025 不符合條件或解析失敗
# 2025-02-05 19:34:17,571 - INFO - 文章 900024 回應狀態碼: 200
# 2025-02-05 19:34:17,571 - INFO - 文章 900027 不符合條件或解析失敗
# 2025-02-05 19:34:17,571 - INFO - 文章 900026 回應狀態碼: 200
# 2025-02-05 19:34:17,571 - INFO - 文章 900024 不符合條件或解析失敗
# 處理文章:   0%|          | 25/26520 [00:05<1:32:41,  4.76it/s]2025-02-05 19:34:17,584 - INFO - 文章 900026 不符合條件或解析失敗
# 2025-02-05 19:34:17,942 - INFO - 正在抓取文章 900030
# 2025-02-05 19:34:17,943 - INFO - 正在抓取文章 900031
# 2025-02-05 19:34:17,952 - INFO - 正在抓取文章 900028
# 2025-02-05 19:34:17,954 - INFO - 正在抓取文章 900029
# 2025-02-05 19:34:17,958 - INFO - 文章 900031 回應狀態碼: 200
# 2025-02-05 19:34:17,959 - INFO - 文章 900031 不符合條件或解析失敗
# 2025-02-05 19:34:17,960 - INFO - 文章 900028 回應狀態碼: 200
# 2025-02-05 19:34:17,960 - INFO - 文章 900028 不符合條件或解析失敗
# 處理文章:   0%|          | 29/26520 [00:05<1:16:01,  5.81it/s]2025-02-05 19:34:17,967 - INFO - 文章 900029 回應狀態碼: 200
# 2025-02-05 19:34:17,969 - INFO - 文章 900029 不符合條件或解析失敗
# 2025-02-05 19:34:18,087 - INFO - 文章 900030 回應狀態碼: 200
# 2025-02-05 19:34:18,087 - INFO - 文章 900030 不符合條件或解析失敗
# 處理文章:   0%|          | 31/26520 [00:05<1:06:59,  6.59it/s]2025-02-05 19:34:19,072 - INFO - 正在抓取文章 900034
# 2025-02-05 19:34:19,072 - INFO - 正在抓取文章 900032
# 2025-02-05 19:34:19,077 - INFO - 正在抓取文章 900035
# 2025-02-05 19:34:19,077 - INFO - 正在抓取文章 900033
# 2025-02-05 19:34:19,083 - INFO - 文章 900034 回應狀態碼: 200
# 2025-02-05 19:34:19,084 - INFO - 文章 900034 不符合條件或解析失敗
# 2025-02-05 19:34:19,085 - INFO - 文章 900032 回應狀態碼: 200
# 2025-02-05 19:34:19,087 - INFO - 文章 900032 不符合條件或解析失敗
# 處理文章:   0%|          | 33/26520 [00:06<1:39:37,  4.43it/s]2025-02-05 19:34:19,089 - INFO - 文章 900035 回應狀態碼: 200
# 2025-02-05 19:34:19,090 - INFO - 文章 900035 不符合條件或解析失敗
# 2025-02-05 19:34:19,095 - INFO - 文章 900033 回應狀態碼: 200
# 2025-02-05 19:34:19,096 - INFO - 文章 900033 不符合條件或解析失敗
# 2025-02-05 19:34:19,460 - INFO - 正在抓取文章 900037
# 2025-02-05 19:34:19,461 - INFO - 正在抓取文章 900036
# 2025-02-05 19:34:19,461 - INFO - 正在抓取文章 900038
# 2025-02-05 19:34:19,461 - INFO - 正在抓取文章 900039
# 2025-02-05 19:34:19,474 - INFO - 文章 900037 回應狀態碼: 200
# 2025-02-05 19:34:19,474 - INFO - 文章 900037 不符合條件或解析失敗
# 2025-02-05 19:34:19,474 - INFO - 文章 900036 回應狀態碼: 200
# 2025-02-05 19:34:19,477 - INFO - 文章 900038 回應狀態碼: 200
# 2025-02-05 19:34:19,478 - INFO - 文章 900039 回應狀態碼: 200
# 2025-02-05 19:34:19,479 - INFO - 文章 900036 不符合條件或解析失敗
# 2025-02-05 19:34:19,480 - INFO - 文章 900038 不符合條件或解析失敗
# 處理文章:   0%|          | 37/26520 [00:06<1:18:20,  5.63it/s]2025-02-05 19:34:19,480 - INFO - 文章 900039 不符合條件或解析失敗
# 2025-02-05 19:34:20,598 - INFO - 正在抓取文章 900043
# 2025-02-05 19:34:20,598 - INFO - 正在抓取文章 900040
# 2025-02-05 19:34:20,601 - INFO - 正在抓取文章 900041
# 2025-02-05 19:34:20,602 - INFO - 正在抓取文章 900042
# 2025-02-05 19:34:20,607 - INFO - 文章 900043 回應狀態碼: 200
# 2025-02-05 19:34:20,607 - INFO - 文章 900043 不符合條件或解析失敗
# 2025-02-05 19:34:20,607 - INFO - 文章 900040 回應狀態碼: 200
# 2025-02-05 19:34:20,607 - INFO - 文章 900040 不符合條件或解析失敗
# 2025-02-05 19:34:20,616 - INFO - 文章 900041 回應狀態碼: 200
# 處理文章:   0%|          | 41/26520 [00:08<1:34:51,  4.65it/s]2025-02-05 19:34:20,616 - INFO - 文章 900042 回應狀態碼: 200
# 2025-02-05 19:34:20,619 - INFO - 文章 900041 不符合條件或解析失敗
# 2025-02-05 19:34:20,621 - INFO - 文章 900042 不符合條件或解析失敗
# 2025-02-05 19:34:20,981 - INFO - 正在抓取文章 900047
# 2025-02-05 19:34:20,981 - INFO - 正在抓取文章 900046
# 2025-02-05 19:34:20,981 - INFO - 正在抓取文章 900045
# 2025-02-05 19:34:20,988 - INFO - 正在抓取文章 900044
# 2025-02-05 19:34:20,991 - INFO - 文章 900047 回應狀態碼: 200
# 2025-02-05 19:34:20,991 - INFO - 文章 900046 回應狀態碼: 200
# 2025-02-05 19:34:20,991 - INFO - 文章 900045 回應狀態碼: 200
# 2025-02-05 19:34:20,991 - INFO - 文章 900047 不符合條件或解析失敗
# 2025-02-05 19:34:20,991 - INFO - 文章 900046 不符合條件或解析失敗
# 2025-02-05 19:34:20,999 - INFO - 文章 900044 回應狀態碼: 200
# 2025-02-05 19:34:20,999 - INFO - 文章 900045 不符合條件或解析失敗
# 2025-02-05 19:34:21,003 - INFO - 文章 900044 不符合條件或解析失敗
# 處理文章:   0%|          | 45/26520 [00:08<1:17:29,  5.69it/s]2025-02-05 19:34:22,107 - INFO - 正在抓取文章 900051
# 2025-02-05 19:34:22,108 - INFO - 正在抓取文章 900050
# 2025-02-05 19:34:22,110 - INFO - 正在抓取文章 900048
# 2025-02-05 19:34:22,112 - INFO - 正在抓取文章 900049
# 2025-02-05 19:34:22,124 - INFO - 文章 900051 回應狀態碼: 200
# 2025-02-05 19:34:22,124 - INFO - 文章 900050 回應狀態碼: 200
# 2025-02-05 19:34:22,125 - INFO - 文章 900051 不符合條件或解析失敗
# 2025-02-05 19:34:22,127 - INFO - 文章 900050 不符合條件或解析失敗
# 2025-02-05 19:34:22,128 - INFO - 文章 900048 回應狀態碼: 200
# 2025-02-05 19:34:22,128 - INFO - 文章 900048 不符合條件或解析失敗
# 處理文章:   0%|          | 49/26520 [00:09<1:32:25,  4.77it/s]2025-02-05 19:34:22,128 - INFO - 文章 900049 回應狀態碼: 200
# 2025-02-05 19:34:22,128 - INFO - 文章 900049 不符合條件或解析失敗
# 2025-02-05 19:34:22,500 - INFO - 正在抓取文章 900053
# 2025-02-05 19:34:22,500 - INFO - 正在抓取文章 900052
# 2025-02-05 19:34:22,503 - INFO - 正在抓取文章 900054
# 2025-02-05 19:34:22,506 - INFO - 正在抓取文章 900056
# 2025-02-05 19:34:22,513 - INFO - 文章 900053 回應狀態碼: 200
# 2025-02-05 19:34:22,514 - INFO - 文章 900052 回應狀態碼: 200
# 2025-02-05 19:34:22,515 - INFO - 文章 900053 不符合條件或解析失敗
# 2025-02-05 19:34:22,516 - INFO - 文章 900052 不符合條件或解析失敗
# 處理文章:   0%|          | 53/26520 [00:09<1:16:48,  5.74it/s]2025-02-05 19:34:22,517 - INFO - 文章 900054 回應狀態碼: 200
# 2025-02-05 19:34:22,520 - INFO - 文章 900054 不符合條件或解析失敗
# 2025-02-05 19:34:22,535 - INFO - 文章 900056 回應狀態碼: 200
# 2025-02-05 19:34:22,561 - INFO - 文章 900056 不符合條件或解析失敗
# 2025-02-05 19:34:23,629 - INFO - 正在抓取文章 900057
# 2025-02-05 19:34:23,630 - INFO - 正在抓取文章 900059
# 2025-02-05 19:34:23,630 - INFO - 正在抓取文章 900060
# 2025-02-05 19:34:23,630 - INFO - 正在抓取文章 900061
# 2025-02-05 19:34:23,660 - INFO - 文章 900057 回應狀態碼: 200
# 2025-02-05 19:34:23,693 - INFO - 文章 900059 回應狀態碼: 200
# 2025-02-05 19:34:23,697 - INFO - 文章 900057 不符合條件或解析失敗
# 2025-02-05 19:34:23,698 - INFO - 文章 900061 回應狀態碼: 200
# 處理文章:   0%|          | 57/26520 [00:11<1:34:22,  4.67it/s]2025-02-05 19:34:23,698 - INFO - 文章 900060 回應狀態碼: 200
# 2025-02-05 19:34:23,727 - INFO - 文章 900059 不符合條件或解析失敗
# 2025-02-05 19:34:23,744 - INFO - 文章 900061 不符合條件或解析失敗
# 2025-02-05 19:34:23,775 - INFO - 文章 900060 不符合條件或解析失敗
# 2025-02-05 19:34:24,062 - INFO - 正在抓取文章 900063
# 2025-02-05 19:34:24,062 - INFO - 正在抓取文章 900064
# 2025-02-05 19:34:24,062 - INFO - 正在抓取文章 900065
# 2025-02-05 19:34:24,063 - INFO - 正在抓取文章 900062
# 2025-02-05 19:34:24,104 - INFO - 文章 900064 回應狀態碼: 200
# 2025-02-05 19:34:24,124 - INFO - 文章 900065 回應狀態碼: 200
# 2025-02-05 19:34:24,127 - INFO - 文章 900064 不符合條件或解析失敗
# 2025-02-05 19:34:24,128 - INFO - 文章 900062 回應狀態碼: 200
# 2025-02-05 19:34:24,146 - INFO - 文章 900065 不符合條件或解析失敗
# 2025-02-05 19:34:24,174 - INFO - 文章 900062 不符合條件或解析失敗
# 2025-02-05 19:34:24,175 - INFO - 文章 900063 回應狀態碼: 200
# 處理文章:   0%|          | 61/26520 [00:11<1:20:35,  5.47it/s]2025-02-05 19:34:24,200 - INFO - 文章 900063 不符合條件或解析失敗
# 2025-02-05 19:34:25,228 - INFO - 正在抓取文章 900069
# 2025-02-05 19:34:25,228 - INFO - 正在抓取文章 900068
# 2025-02-05 19:34:25,228 - INFO - 正在抓取文章 900067
# 2025-02-05 19:34:25,232 - INFO - 正在抓取文章 900066
# 2025-02-05 19:34:25,240 - INFO - 文章 900069 回應狀態碼: 200
# 2025-02-05 19:34:25,240 - INFO - 文章 900069 不符合條件或解析失敗
# 2025-02-05 19:34:25,304 - INFO - 文章 900067 回應狀態碼: 200
# 2025-02-05 19:34:25,325 - INFO - 文章 900067 不符合條件或解析失敗
# 2025-02-05 19:34:25,364 - INFO - 文章 900066 回應狀態碼: 200
# 2025-02-05 19:34:25,374 - INFO - 文章 900066 不符合條件或解析失敗
# 處理文章:   0%|          | 65/26520 [00:12<1:36:15,  4.58it/s]2025-02-05 19:34:25,394 - INFO - 文章 900068 回應狀態碼: 200
# 2025-02-05 19:34:25,416 - INFO - 文章 900068 不符合條件或解析失敗
# 2025-02-05 19:34:25,647 - INFO - 正在抓取文章 900071
# 2025-02-05 19:34:25,651 - INFO - 正在抓取文章 900073
# 2025-02-05 19:34:25,652 - INFO - 正在抓取文章 900070
# 2025-02-05 19:34:25,660 - INFO - 正在抓取文章 900072
# 2025-02-05 19:34:25,662 - INFO - 文章 900071 回應狀態碼: 200
# 2025-02-05 19:34:25,663 - INFO - 文章 900071 不符合條件或解析失敗
# 2025-02-05 19:34:25,663 - INFO - 文章 900073 回應狀態碼: 200
# 2025-02-05 19:34:25,664 - INFO - 文章 900070 回應狀態碼: 200
# 2025-02-05 19:34:25,665 - INFO - 文章 900073 不符合條件或解析失敗
# 2025-02-05 19:34:25,667 - INFO - 文章 900070 不符合條件或解析失敗
# 處理文章:   0%|          | 69/26520 [00:13<1:16:51,  5.74it/s]2025-02-05 19:34:25,672 - INFO - 文章 900072 回應狀態碼: 200
# 2025-02-05 19:34:25,673 - INFO - 文章 900072 不符合條件或解析失敗
# 2025-02-05 19:34:26,875 - INFO - 正在抓取文章 900076
# 2025-02-05 19:34:26,875 - INFO - 正在抓取文章 900074
# 2025-02-05 19:34:26,876 - INFO - 正在抓取文章 900077
# 2025-02-05 19:34:26,876 - INFO - 正在抓取文章 900075
# 2025-02-05 19:34:26,917 - INFO - 文章 900076 回應狀態碼: 200
# 2025-02-05 19:34:26,917 - INFO - 文章 900076 不符合條件或解析失敗
# 2025-02-05 19:34:26,919 - INFO - 文章 900074 回應狀態碼: 200
# 2025-02-05 19:34:26,920 - INFO - 文章 900077 回應狀態碼: 200
# 2025-02-05 19:34:26,921 - INFO - 文章 900075 回應狀態碼: 200
# 2025-02-05 19:34:26,922 - INFO - 文章 900074 不符合條件或解析失敗
# 處理文章:   0%|          | 73/26520 [00:14<1:35:32,  4.61it/s]2025-02-05 19:34:26,923 - INFO - 文章 900077 不符合條件或解析失敗
# 2025-02-05 19:34:26,925 - INFO - 文章 900075 不符合條件或解析失敗
# 2025-02-05 19:34:27,168 - INFO - 正在抓取文章 900080
# 2025-02-05 19:34:27,168 - INFO - 正在抓取文章 900079
# 2025-02-05 19:34:27,168 - INFO - 正在抓取文章 900083
# 2025-02-05 19:34:27,168 - INFO - 正在抓取文章 900078
# 2025-02-05 19:34:27,192 - INFO - 文章 900080 回應狀態碼: 200
# 2025-02-05 19:34:27,193 - INFO - 文章 900079 回應狀態碼: 200
# 2025-02-05 19:34:27,193 - INFO - 文章 900080 不符合條件或解析失敗
# 2025-02-05 19:34:27,193 - INFO - 文章 900083 回應狀態碼: 200
# 2025-02-05 19:34:27,193 - INFO - 文章 900079 不符合條件或解析失敗
# 2025-02-05 19:34:27,193 - INFO - 文章 900078 回應狀態碼: 200
# 2025-02-05 19:34:27,193 - INFO - 文章 900083 不符合條件或解析失敗
# 2025-02-05 19:34:27,193 - INFO - 文章 900078 不符合條件或解析失敗
# 處理文章:   0%|          | 77/26520 [00:14<1:15:34,  5.83it/s]2025-02-05 19:34:28,422 - INFO - 正在抓取文章 900084
# 2025-02-05 19:34:28,426 - INFO - 正在抓取文章 900085
# 2025-02-05 19:34:28,428 - INFO - 正在抓取文章 900086
# 2025-02-05 19:34:28,429 - INFO - 正在抓取文章 900087
# 2025-02-05 19:34:28,431 - INFO - 文章 900084 回應狀態碼: 200
# 2025-02-05 19:34:28,431 - INFO - 文章 900084 不符合條件或解析失敗
# 處理文章:   0%|          | 81/26520 [00:15<1:33:52,  4.69it/s]2025-02-05 19:34:28,431 - INFO - 文章 900085 回應狀態碼: 200
# 2025-02-05 19:34:28,439 - INFO - 文章 900085 不符合條件或解析失敗
# 2025-02-05 19:34:28,485 - INFO - 文章 900086 回應狀態碼: 200
# 2025-02-05 19:34:28,486 - INFO - 文章 900087 回應狀態碼: 200
# 2025-02-05 19:34:28,487 - INFO - 文章 900086 不符合條件或解析失敗
# 2025-02-05 19:34:28,488 - INFO - 文章 900087 不符合條件或解析失敗
# 2025-02-05 19:34:28,693 - INFO - 正在抓取文章 900091
# 2025-02-05 19:34:28,693 - INFO - 正在抓取文章 900090
# 2025-02-05 19:34:28,693 - INFO - 正在抓取文章 900089
# 2025-02-05 19:34:28,699 - INFO - 正在抓取文章 900088
# 2025-02-05 19:34:28,699 - INFO - 文章 900091 回應狀態碼: 200
# 2025-02-05 19:34:28,699 - INFO - 文章 900091 不符合條件或解析失敗
# 2025-02-05 19:34:28,699 - INFO - 文章 900090 回應狀態碼: 200
# 2025-02-05 19:34:28,699 - INFO - 文章 900090 不符合條件或解析失敗
# 2025-02-05 19:34:28,711 - INFO - 文章 900089 回應狀態碼: 200
# 2025-02-05 19:34:28,712 - INFO - 文章 900088 回應狀態碼: 200
# 2025-02-05 19:34:28,712 - INFO - 文章 900089 不符合條件或解析失敗
# 2025-02-05 19:34:28,713 - INFO - 文章 900088 不符合條件或解析失敗
# 處理文章:   0%|          | 85/26520 [00:16<1:15:03,  5.87it/s]2025-02-05 19:34:29,932 - INFO - 正在抓取文章 900094
# 2025-02-05 19:34:29,932 - INFO - 正在抓取文章 900095
# 2025-02-05 19:34:29,932 - INFO - 正在抓取文章 900093
# 2025-02-05 19:34:29,939 - INFO - 正在抓取文章 900092
# 2025-02-05 19:34:29,945 - INFO - 文章 900094 回應狀態碼: 200
# 2025-02-05 19:34:29,946 - INFO - 文章 900094 不符合條件或解析失敗
# 2025-02-05 19:34:29,988 - INFO - 文章 900093 回應狀態碼: 200
# 2025-02-05 19:34:29,989 - INFO - 文章 900093 不符合條件或解析失敗
# 2025-02-05 19:34:29,993 - INFO - 文章 900092 回應狀態碼: 200
# 2025-02-05 19:34:29,995 - INFO - 文章 900095 回應狀態碼: 200
# 2025-02-05 19:34:29,995 - INFO - 文章 900092 不符合條件或解析失敗
# 2025-02-05 19:34:30,020 - INFO - 文章 900095 不符合條件或解析失敗
# 處理文章:   0%|          | 89/26520 [00:17<1:35:39,  4.60it/s]2025-02-05 19:34:30,200 - INFO - 正在抓取文章 900096
# 2025-02-05 19:34:30,200 - INFO - 正在抓取文章 900097
# 2025-02-05 19:34:30,201 - INFO - 正在抓取文章 900098
# 2025-02-05 19:34:30,203 - INFO - 正在抓取文章 900099
# 2025-02-05 19:34:30,215 - INFO - 文章 900097 回應狀態碼: 200
# 2025-02-05 19:34:30,216 - INFO - 文章 900098 回應狀態碼: 200
# 2025-02-05 19:34:30,216 - INFO - 文章 900097 不符合條件或解析失敗
# 2025-02-05 19:34:30,218 - INFO - 文章 900098 不符合條件或解析失敗
# 2025-02-05 19:34:30,240 - INFO - 文章 900096 回應狀態碼: 200
# 2025-02-05 19:34:30,241 - INFO - 文章 900099 回應狀態碼: 200
# 2025-02-05 19:34:30,266 - INFO - 文章 900096 不符合條件或解析失敗
# 2025-02-05 19:34:30,266 - INFO - 文章 900099 不符合條件或解析失敗
# 處理文章:   0%|          | 93/26520 [00:17<1:15:03,  5.87it/s]2025-02-05 19:34:31,521 - INFO - 正在抓取文章 900101
# 2025-02-05 19:34:31,521 - INFO - 正在抓取文章 900100
# 2025-02-05 19:34:31,523 - INFO - 正在抓取文章 900102
# 2025-02-05 19:34:31,525 - INFO - 正在抓取文章 900103
# 2025-02-05 19:34:31,534 - INFO - 文章 900101 回應狀態碼: 200
# 2025-02-05 19:34:31,535 - INFO - 文章 900101 不符合條件或解析失敗
# 2025-02-05 19:34:31,538 - INFO - 文章 900100 回應狀態碼: 200
# 2025-02-05 19:34:31,538 - INFO - 文章 900102 回應狀態碼: 200
# 2025-02-05 19:34:31,541 - INFO - 文章 900100 不符合條件或解析失敗
# 2025-02-05 19:34:31,542 - INFO - 文章 900102 不符合條件或解析失敗
# 處理文章:   0%|          | 97/26520 [00:18<1:34:45,  4.65it/s]2025-02-05 19:34:31,551 - INFO - 文章 900103 回應狀態碼: 200
# 2025-02-05 19:34:31,583 - INFO - 文章 900103 不符合條件或解析失敗
# 2025-02-05 19:34:31,767 - INFO - 正在抓取文章 900104
# 2025-02-05 19:34:31,767 - INFO - 正在抓取文章 900105
# 2025-02-05 19:34:31,767 - INFO - 正在抓取文章 900106
# 2025-02-05 19:34:31,774 - INFO - 正在抓取文章 900107
# 2025-02-05 19:34:31,779 - INFO - 文章 900104 回應狀態碼: 200
# 2025-02-05 19:34:31,780 - INFO - 文章 900104 不符合條件或解析失敗
# 處理文章:   0%|          | 101/26520 [00:19<1:14:06,  5.94it/s]2025-02-05 19:34:31,782 - INFO - 文章 900105 回應狀態碼: 200
# 2025-02-05 19:34:31,783 - INFO - 文章 900106 回應狀態碼: 200
# 2025-02-05 19:34:31,784 - INFO - 文章 900105 不符合條件或解析失敗
# 2025-02-05 19:34:31,785 - INFO - 文章 900107 回應狀態碼: 200
# 2025-02-05 19:34:31,786 - INFO - 文章 900106 不符合條件或解析失敗
# 2025-02-05 19:34:31,786 - INFO - 文章 900107 不符合條件或解析失敗
# 2025-02-05 19:34:33,085 - INFO - 正在抓取文章 900108
# 2025-02-05 19:34:33,085 - INFO - 正在抓取文章 900109
# 2025-02-05 19:34:33,088 - INFO - 正在抓取文章 900111
# 2025-02-05 19:34:33,088 - INFO - 正在抓取文章 900110
# 2025-02-05 19:34:33,103 - INFO - 文章 900109 回應狀態碼: 200
# 2025-02-05 19:34:33,105 - INFO - 文章 900109 不符合條件或解析失敗
# 2025-02-05 19:34:33,105 - INFO - 文章 900108 回應狀態碼: 200
# 2025-02-05 19:34:33,105 - INFO - 文章 900111 回應狀態碼: 200
# 2025-02-05 19:34:33,105 - INFO - 文章 900110 回應狀態碼: 200
# 2025-02-05 19:34:33,105 - INFO - 文章 900108 不符合條件或解析失敗
# 2025-02-05 19:34:33,105 - INFO - 文章 900111 不符合條件或解析失敗
# 處理文章:   0%|          | 105/26520 [00:20<1:35:57,  4.59it/s]2025-02-05 19:34:33,105 - INFO - 文章 900110 不符合條件或解析失敗
# 2025-02-05 19:34:33,287 - INFO - 正在抓取文章 900115
# 2025-02-05 19:34:33,287 - INFO - 正在抓取文章 900114
# 2025-02-05 19:34:33,287 - INFO - 正在抓取文章 900113
# 2025-02-05 19:34:33,291 - INFO - 正在抓取文章 900112
# 2025-02-05 19:34:33,298 - INFO - 文章 900115 回應狀態碼: 200
# 2025-02-05 19:34:33,298 - INFO - 文章 900115 不符合條件或解析失敗
# 2025-02-05 19:34:33,298 - INFO - 文章 900114 回應狀態碼: 200
# 2025-02-05 19:34:33,298 - INFO - 文章 900114 不符合條件或解析失敗
# 2025-02-05 19:34:33,304 - INFO - 文章 900113 回應狀態碼: 200
# 2025-02-05 19:34:33,305 - INFO - 文章 900112 回應狀態碼: 200
# 2025-02-05 19:34:33,306 - INFO - 文章 900113 不符合條件或解析失敗
# 2025-02-05 19:34:33,308 - INFO - 文章 900112 不符合條件或解析失敗
# 處理文章:   0%|          | 109/26520 [00:20<1:13:30,  5.99it/s]2025-02-05 19:34:34,605 - INFO - 正在抓取文章 900117
# 2025-02-05 19:34:34,606 - INFO - 正在抓取文章 900118
# 2025-02-05 19:34:34,607 - INFO - 正在抓取文章 900119
# 2025-02-05 19:34:34,609 - INFO - 正在抓取文章 900116
# 2025-02-05 19:34:34,616 - INFO - 文章 900117 回應狀態碼: 200
# 2025-02-05 19:34:34,616 - INFO - 文章 900117 不符合條件或解析失敗
# 2025-02-05 19:34:34,616 - INFO - 文章 900118 回應狀態碼: 200
# 2025-02-05 19:34:34,616 - INFO - 文章 900119 回應狀態碼: 200
# 2025-02-05 19:34:34,616 - INFO - 文章 900116 回應狀態碼: 200
# 2025-02-05 19:34:34,616 - INFO - 文章 900118 不符合條件或解析失敗
# 2025-02-05 19:34:34,626 - INFO - 文章 900119 不符合條件或解析失敗
# 2025-02-05 19:34:34,628 - INFO - 文章 900116 不符合條件或解析失敗
# 處理文章:   0%|          | 113/26520 [00:22<1:35:16,  4.62it/s]2025-02-05 19:34:34,799 - INFO - 正在抓取文章 900123
# 2025-02-05 19:34:34,799 - INFO - 正在抓取文章 900122
# 2025-02-05 19:34:34,799 - INFO - 正在抓取文章 900121
# 2025-02-05 19:34:34,806 - INFO - 正在抓取文章 900120
# 2025-02-05 19:34:34,806 - INFO - 文章 900123 回應狀態碼: 200
# 2025-02-05 19:34:34,806 - INFO - 文章 900123 不符合條件或解析失敗
# 2025-02-05 19:34:34,806 - INFO - 文章 900122 回應狀態碼: 200
# 2025-02-05 19:34:34,806 - INFO - 文章 900121 回應狀態碼: 200
# 2025-02-05 19:34:34,815 - INFO - 文章 900122 不符合條件或解析失敗
# 2025-02-05 19:34:34,816 - INFO - 文章 900121 不符合條件或解析失敗
# 2025-02-05 19:34:34,817 - INFO - 文章 900120 回應狀態碼: 200
# 2025-02-05 19:34:34,821 - INFO - 文章 900120 不符合條件或解析失敗
# 處理文章:   0%|          | 117/26520 [00:22<1:12:51,  6.04it/s]2025-02-05 19:34:36,116 - INFO - 正在抓取文章 900127
# 2025-02-05 19:34:36,117 - INFO - 正在抓取文章 900125
# 2025-02-05 19:34:36,117 - INFO - 正在抓取文章 900126
# 2025-02-05 19:34:36,124 - INFO - 正在抓取文章 900124
# 2025-02-05 19:34:36,124 - INFO - 文章 900125 回應狀態碼: 200
# 2025-02-05 19:34:36,124 - INFO - 文章 900127 回應狀態碼: 200
# 2025-02-05 19:34:36,124 - INFO - 文章 900125 不符合條件或解析失敗
# 2025-02-05 19:34:36,124 - INFO - 文章 900126 回應狀態碼: 200
# 2025-02-05 19:34:36,133 - INFO - 文章 900127 不符合條件或解析失敗
# 2025-02-05 19:34:36,135 - INFO - 文章 900126 不符合條件或解析失敗
# 2025-02-05 19:34:36,136 - INFO - 文章 900124 回應狀態碼: 200
# 2025-02-05 19:34:36,140 - INFO - 文章 900124 不符合條件或解析失敗
# 處理文章:   0%|          | 121/26520 [00:23<1:34:28,  4.66it/s]2025-02-05 19:34:36,306 - INFO - 正在抓取文章 900129
# 2025-02-05 19:34:36,306 - INFO - 正在抓取文章 900130
# 2025-02-05 19:34:36,307 - INFO - 正在抓取文章 900128
# 2025-02-05 19:34:36,307 - INFO - 正在抓取文章 900131
# 2025-02-05 19:34:36,307 - INFO - 文章 900129 回應狀態碼: 200
# 2025-02-05 19:34:36,319 - INFO - 文章 900129 不符合條件或解析失敗
# 2025-02-05 19:34:36,319 - INFO - 文章 900130 回應狀態碼: 200
# 2025-02-05 19:34:36,322 - INFO - 文章 900130 不符合條件或解析失敗
# 2025-02-05 19:34:36,323 - INFO - 文章 900131 回應狀態碼: 200
# 2025-02-05 19:34:36,324 - INFO - 文章 900128 回應狀態碼: 200
# 2025-02-05 19:34:36,325 - INFO - 文章 900131 不符合條件或解析失敗
# 2025-02-05 19:34:36,326 - INFO - 文章 900128 不符合條件或解析失敗
# 處理文章:   0%|          | 125/26520 [00:23<1:12:16,  6.09it/s]2025-02-05 19:34:37,640 - INFO - 正在抓取文章 900133
# 2025-02-05 19:34:37,642 - INFO - 正在抓取文章 900132
# 2025-02-05 19:34:37,643 - INFO - 正在抓取文章 900134
# 2025-02-05 19:34:37,643 - INFO - 正在抓取文章 900135
# 2025-02-05 19:34:37,651 - INFO - 文章 900133 回應狀態碼: 200
# 2025-02-05 19:34:37,651 - INFO - 文章 900133 不符合條件或解析失敗
# 2025-02-05 19:34:37,651 - INFO - 文章 900132 回應狀態碼: 200
# 2025-02-05 19:34:37,651 - INFO - 文章 900132 不符合條件或解析失敗
# 處理文章:   0%|          | 129/26520 [00:25<1:34:17,  4.66it/s]2025-02-05 19:34:37,651 - INFO - 文章 900134 回應狀態碼: 200
# 2025-02-05 19:34:37,651 - INFO - 文章 900135 回應狀態碼: 200
# 2025-02-05 19:34:37,651 - INFO - 文章 900134 不符合條件或解析失敗
# 2025-02-05 19:34:37,651 - INFO - 文章 900135 不符合條件或解析失敗
# 2025-02-05 19:34:37,831 - INFO - 正在抓取文章 900136
# 2025-02-05 19:34:37,833 - INFO - 正在抓取文章 900137
# 2025-02-05 19:34:37,839 - INFO - 正在抓取文章 900138
# 2025-02-05 19:34:37,840 - INFO - 正在抓取文章 900139
# 2025-02-05 19:34:37,840 - INFO - 文章 900136 回應狀態碼: 200
# 2025-02-05 19:34:37,840 - INFO - 文章 900136 不符合條件或解析失敗
# 2025-02-05 19:34:37,846 - INFO - 文章 900137 回應狀態碼: 200
# 處理文章:   1%|          | 133/26520 [00:25<1:12:24,  6.07it/s]2025-02-05 19:34:37,847 - INFO - 文章 900137 不符合條件或解析失敗
# 2025-02-05 19:34:37,850 - INFO - 文章 900138 回應狀態碼: 200
# 2025-02-05 19:34:37,852 - INFO - 文章 900138 不符合條件或解析失敗
# 2025-02-05 19:34:37,853 - INFO - 文章 900139 回應狀態碼: 200
# 2025-02-05 19:34:37,855 - INFO - 文章 900139 不符合條件或解析失敗
# 2025-02-05 19:34:39,152 - INFO - 正在抓取文章 900145
# 2025-02-05 19:34:39,152 - INFO - 正在抓取文章 900141
# 2025-02-05 19:34:39,152 - INFO - 正在抓取文章 900143
# 2025-02-05 19:34:39,158 - INFO - 正在抓取文章 900140
# 2025-02-05 19:34:39,159 - INFO - 文章 900143 回應狀態碼: 200
# 2025-02-05 19:34:39,159 - INFO - 文章 900143 不符合條件或解析失敗
# 2025-02-05 19:34:39,181 - INFO - 文章 900145 回應狀態碼: 200
# 2025-02-05 19:34:39,206 - INFO - 文章 900145 不符合條件或解析失敗
# 2025-02-05 19:34:39,207 - INFO - 文章 900141 回應狀態碼: 200
# 2025-02-05 19:34:39,207 - INFO - 文章 900140 回應狀態碼: 200
# 2025-02-05 19:34:39,229 - INFO - 文章 900141 不符合條件或解析失敗
# 2025-02-05 19:34:39,260 - INFO - 文章 900140 不符合條件或解析失敗
# 處理文章:   1%|          | 136/26520 [00:26<1:26:16,  5.10it/s]
# 2025-02-05 19:34:39,340 - INFO - 正在抓取文章 900149
# 2025-02-05 19:34:39,340 - INFO - 正在抓取文章 900146
# 2025-02-05 19:34:39,340 - INFO - 正在抓取文章 900148
# 2025-02-05 19:34:39,342 - INFO - 正在抓取文章 900147
# 2025-02-05 19:34:39,386 - INFO - 文章 900149 回應狀態碼: 200
# 2025-02-05 19:34:39,406 - INFO - 文章 900149 不符合條件或解析失敗
# 2025-02-05 19:34:39,406 - INFO - 文章 900146 回應狀態碼: 200
# 2025-02-05 19:34:39,406 - INFO - 文章 900148 回應狀態碼: 200
# 2025-02-05 19:34:39,418 - INFO - 文章 900147 回應狀態碼: 200
# 2025-02-05 19:34:39,462 - INFO - 文章 900148 不符合條件或解析失敗
# 2025-02-05 19:34:39,481 - INFO - 文章 900146 不符合條件或解析失敗
# 2025-02-05 19:34:39,508 - INFO - 文章 900147 不符合條件或解析失敗
# 2025-02-05 19:34:40,707 - INFO - 正在抓取文章 900151
# 2025-02-05 19:34:40,707 - INFO - 正在抓取文章 900153
# 2025-02-05 19:34:40,708 - INFO - 正在抓取文章 900152
# 2025-02-05 19:34:40,716 - INFO - 正在抓取文章 900150
# 2025-02-05 19:34:40,716 - INFO - 文章 900151 回應狀態碼: 200
# 2025-02-05 19:34:40,716 - INFO - 文章 900153 回應狀態碼: 200
# 2025-02-05 19:34:40,716 - INFO - 文章 900151 不符合條件或解析失敗
# 2025-02-05 19:34:40,724 - INFO - 文章 900152 回應狀態碼: 200
# 2025-02-05 19:34:40,724 - INFO - 文章 900153 不符合條件或解析失敗
# 2025-02-05 19:34:40,724 - INFO - 文章 900152 不符合條件或解析失敗
# 2025-02-05 19:34:40,728 - INFO - 文章 900150 回應狀態碼: 200
# 2025-02-05 19:34:40,731 - INFO - 文章 900150 不符合條件或解析失敗
# 2025-02-05 19:34:40,906 - INFO - 正在抓取文章 900156
# 2025-02-05 19:34:40,907 - INFO - 正在抓取文章 900155
# 2025-02-05 19:34:40,908 - INFO - 正在抓取文章 900157
# 2025-02-05 19:34:40,908 - INFO - 正在抓取文章 900154
# 2025-02-05 19:34:40,908 - INFO - 文章 900155 回應狀態碼: 200
# 2025-02-05 19:34:40,908 - INFO - 文章 900155 不符合條件或解析失敗
# 2025-02-05 19:34:40,908 - INFO - 文章 900156 回應狀態碼: 200
# 2025-02-05 19:34:40,908 - INFO - 文章 900157 回應狀態碼: 200
# 2025-02-05 19:34:40,908 - INFO - 文章 900156 不符合條件或解析失敗
# 2025-02-05 19:34:40,924 - INFO - 文章 900154 回應狀態碼: 200
# 2025-02-05 19:34:40,924 - INFO - 文章 900157 不符合條件或解析失敗
# 2025-02-05 19:34:40,926 - INFO - 文章 900154 不符合條件或解析失敗
# 2025-02-05 19:34:42,225 - INFO - 正在抓取文章 900160
# 2025-02-05 19:34:42,225 - INFO - 正在抓取文章 900161
# 2025-02-05 19:34:42,225 - INFO - 正在抓取文章 900159
# 2025-02-05 19:34:42,237 - INFO - 正在抓取文章 900158
# 2025-02-05 19:34:42,272 - INFO - 文章 900161 回應狀態碼: 200
# 2025-02-05 19:34:42,272 - INFO - 文章 900161 不符合條件或解析失敗
# 2025-02-05 19:34:42,272 - INFO - 文章 900160 回應狀態碼: 200
# 2025-02-05 19:34:42,287 - INFO - 文章 900158 回應狀態碼: 200
# 2025-02-05 19:34:42,289 - INFO - 文章 900159 回應狀態碼: 200
# 2025-02-05 19:34:42,289 - INFO - 文章 900160 不符合條件或解析失敗
# 2025-02-05 19:34:42,289 - INFO - 文章 900158 不符合條件或解析失敗
# 2025-02-05 19:34:42,289 - INFO - 文章 900159 不符合條件或解析失敗
# 2025-02-05 19:34:42,413 - INFO - 正在抓取文章 900163
# 2025-02-05 19:34:42,414 - INFO - 正在抓取文章 900164
# 2025-02-05 19:34:42,415 - INFO - 正在抓取文章 900165
# 2025-02-05 19:34:42,422 - INFO - 正在抓取文章 900162
# 2025-02-05 19:34:42,426 - INFO - 文章 900163 回應狀態碼: 200
# 2025-02-05 19:34:42,428 - INFO - 文章 900163 不符合條件或解析失敗
# 2025-02-05 19:34:42,428 - INFO - 文章 900164 回應狀態碼: 200
# 2025-02-05 19:34:42,428 - INFO - 文章 900165 回應狀態碼: 200
# 2025-02-05 19:34:42,431 - INFO - 文章 900164 不符合條件或解析失敗
# 2025-02-05 19:34:42,433 - INFO - 文章 900165 不符合條件或解析失敗
# 2025-02-05 19:34:42,434 - INFO - 文章 900162 回應狀態碼: 200
# 2025-02-05 19:34:42,437 - INFO - 文章 900162 不符合條件或解析失敗
# 2025-02-05 19:34:43,773 - INFO - 正在抓取文章 900169
# 2025-02-05 19:34:43,773 - INFO - 正在抓取文章 900167
# 2025-02-05 19:34:43,773 - INFO - 正在抓取文章 900168
# 2025-02-05 19:34:43,774 - INFO - 正在抓取文章 900166
# 2025-02-05 19:34:43,786 - INFO - 文章 900169 回應狀態碼: 200
# 2025-02-05 19:34:43,786 - INFO - 文章 900167 回應狀態碼: 200
# 2025-02-05 19:34:43,786 - INFO - 文章 900169 不符合條件或解析失敗
# 2025-02-05 19:34:43,786 - INFO - 文章 900168 回應狀態碼: 200
# 2025-02-05 19:34:43,786 - INFO - 文章 900167 不符合條件或解析失敗
# 2025-02-05 19:34:43,786 - INFO - 文章 900166 回應狀態碼: 200
# 2025-02-05 19:34:43,794 - INFO - 文章 900168 不符合條件或解析失敗
# 2025-02-05 19:34:43,796 - INFO - 文章 900166 不符合條件或解析失敗
# 2025-02-05 19:34:43,928 - INFO - 正在抓取文章 900173
# 2025-02-05 19:34:43,928 - INFO - 正在抓取文章 900172
# 2025-02-05 19:34:43,929 - INFO - 正在抓取文章 900171
# 2025-02-05 19:34:43,935 - INFO - 正在抓取文章 900170
# 2025-02-05 19:34:43,938 - INFO - 文章 900173 回應狀態碼: 200
# 2025-02-05 19:34:43,941 - INFO - 文章 900172 回應狀態碼: 200
# 2025-02-05 19:34:43,941 - INFO - 文章 900171 回應狀態碼: 200
# 2025-02-05 19:34:43,941 - INFO - 文章 900173 不符合條件或解析失敗
# 2025-02-05 19:34:43,941 - INFO - 文章 900172 不符合條件或解析失敗
# 2025-02-05 19:34:43,941 - INFO - 文章 900171 不符合條件或解析失敗
# 2025-02-05 19:34:43,941 - INFO - 文章 900170 回應狀態碼: 200
# 2025-02-05 19:34:43,950 - INFO - 文章 900170 不符合條件或解析失敗
# 2025-02-05 19:34:45,287 - INFO - 正在抓取文章 900177
# 2025-02-05 19:34:45,292 - INFO - 正在抓取文章 900174
# 2025-02-05 19:34:45,294 - INFO - 正在抓取文章 900175
# 2025-02-05 19:34:45,295 - INFO - 正在抓取文章 900176
# 2025-02-05 19:34:45,295 - INFO - 文章 900174 回應狀態碼: 200
# 2025-02-05 19:34:45,295 - INFO - 文章 900174 不符合條件或解析失敗
# 2025-02-05 19:34:45,309 - INFO - 文章 900175 回應狀態碼: 200
# 2025-02-05 19:34:45,310 - INFO - 文章 900176 回應狀態碼: 200
# 2025-02-05 19:34:45,311 - INFO - 文章 900175 不符合條件或解析失敗
# 2025-02-05 19:34:45,312 - INFO - 文章 900176 不符合條件或解析失敗
# 2025-02-05 19:34:45,325 - INFO - 文章 900177 回應狀態碼: 200
# 2025-02-05 19:34:45,348 - INFO - 文章 900177 不符合條件或解析失敗
# 2025-02-05 19:34:45,441 - INFO - 正在抓取文章 900180
# 2025-02-05 19:34:45,442 - INFO - 正在抓取文章 900179
# 2025-02-05 19:34:45,442 - INFO - 正在抓取文章 900181
# 2025-02-05 19:34:45,452 - INFO - 正在抓取文章 900178
# 2025-02-05 19:34:45,452 - INFO - 文章 900180 回應狀態碼: 200
# 2025-02-05 19:34:45,452 - INFO - 文章 900180 不符合條件或解析失敗
# 2025-02-05 19:34:45,456 - INFO - 文章 900179 回應狀態碼: 200
# 2025-02-05 19:34:45,457 - INFO - 文章 900181 回應狀態碼: 200
# 2025-02-05 19:34:45,458 - INFO - 文章 900179 不符合條件或解析失敗
# 2025-02-05 19:34:45,460 - INFO - 文章 900181 不符合條件或解析失敗
# 2025-02-05 19:34:45,465 - INFO - 文章 900178 回應狀態碼: 200
# 2025-02-05 19:34:45,466 - INFO - 文章 900178 不符合條件或解析失敗
# 2025-02-05 19:34:46,796 - INFO - 正在抓取文章 900183
# 2025-02-05 19:34:46,796 - INFO - 正在抓取文章 900182
# 2025-02-05 19:34:46,797 - INFO - 正在抓取文章 900184
# 2025-02-05 19:34:46,797 - INFO - 正在抓取文章 900185
# 2025-02-05 19:34:46,797 - INFO - 文章 900183 回應狀態碼: 200
# 2025-02-05 19:34:46,810 - INFO - 文章 900182 回應狀態碼: 200
# 2025-02-05 19:34:46,811 - INFO - 文章 900184 回應狀態碼: 200
# 2025-02-05 19:34:46,812 - INFO - 文章 900183 不符合條件或解析失敗
# 2025-02-05 19:34:46,813 - INFO - 文章 900182 不符合條件或解析失敗
# 2025-02-05 19:34:46,814 - INFO - 文章 900184 不符合條件或解析失敗
# 2025-02-05 19:34:46,814 - INFO - 文章 900185 回應狀態碼: 200
# 2025-02-05 19:34:46,819 - INFO - 文章 900185 不符合條件或解析失敗
# 2025-02-05 19:34:46,967 - INFO - 正在抓取文章 900189
# 2025-02-05 19:34:46,967 - INFO - 正在抓取文章 900188
# 2025-02-05 19:34:46,969 - INFO - 正在抓取文章 900186
# 2025-02-05 19:34:46,970 - INFO - 正在抓取文章 900187
# 2025-02-05 19:34:46,981 - INFO - 文章 900189 回應狀態碼: 200
# 2025-02-05 19:34:46,982 - INFO - 文章 900188 回應狀態碼: 200
# 2025-02-05 19:34:46,982 - INFO - 文章 900189 不符合條件或解析失敗
# 2025-02-05 19:34:46,982 - INFO - 文章 900186 回應狀態碼: 200
# 2025-02-05 19:34:46,986 - INFO - 文章 900188 不符合條件或解析失敗
# 2025-02-05 19:34:46,989 - INFO - 文章 900186 不符合條件或解析失敗
# 2025-02-05 19:34:46,991 - INFO - 文章 900187 回應狀態碼: 200
# 2025-02-05 19:34:46,994 - INFO - 文章 900187 不符合條件或解析失敗
# 2025-02-05 19:34:48,314 - INFO - 正在抓取文章 900193
# 2025-02-05 19:34:48,314 - INFO - 正在抓取文章 900191
# 2025-02-05 19:34:48,315 - INFO - 正在抓取文章 900190
# 2025-02-05 19:34:48,316 - INFO - 正在抓取文章 900192
# 2025-02-05 19:34:48,327 - INFO - 文章 900193 回應狀態碼: 200
# 2025-02-05 19:34:48,328 - INFO - 文章 900191 回應狀態碼: 200
# 2025-02-05 19:34:48,329 - INFO - 文章 900193 不符合條件或解析失敗
# 2025-02-05 19:34:48,330 - INFO - 文章 900190 回應狀態碼: 200
# 2025-02-05 19:34:48,331 - INFO - 文章 900192 回應狀態碼: 200
# 2025-02-05 19:34:48,331 - INFO - 文章 900191 不符合條件或解析失敗
# 2025-02-05 19:34:48,334 - INFO - 文章 900190 不符合條件或解析失敗
# 2025-02-05 19:34:48,334 - INFO - 文章 900192 不符合條件或解析失敗
# 2025-02-05 19:34:48,492 - INFO - 正在抓取文章 900194
# 2025-02-05 19:34:48,494 - INFO - 正在抓取文章 900195
# 2025-02-05 19:34:48,495 - INFO - 正在抓取文章 900196
# 2025-02-05 19:34:48,496 - INFO - 正在抓取文章 900197
# 2025-02-05 19:34:48,505 - INFO - 文章 900194 回應狀態碼: 200
# 2025-02-05 19:34:48,506 - INFO - 文章 900194 不符合條件或解析失敗
# 2025-02-05 19:34:48,509 - INFO - 文章 900196 回應狀態碼: 200
# 2025-02-05 19:34:48,509 - INFO - 文章 900195 回應狀態碼: 200
# 2025-02-05 19:34:48,510 - INFO - 文章 900196 不符合條件或解析失敗
# 2025-02-05 19:34:48,511 - INFO - 文章 900197 回應狀態碼: 200
# 2025-02-05 19:34:48,512 - INFO - 文章 900195 不符合條件或解析失敗
# 2025-02-05 19:34:48,516 - INFO - 文章 900197 不符合條件或解析失敗
# 2025-02-05 19:34:49,835 - INFO - 正在抓取文章 900201
# 2025-02-05 19:34:49,835 - INFO - 正在抓取文章 900200
# 2025-02-05 19:34:49,835 - INFO - 正在抓取文章 900199
# 2025-02-05 19:34:49,835 - INFO - 正在抓取文章 900198
# 2025-02-05 19:34:49,847 - INFO - 文章 900201 回應狀態碼: 200
# 2025-02-05 19:34:49,848 - INFO - 文章 900201 不符合條件或解析失敗
# 2025-02-05 19:34:49,849 - INFO - 文章 900200 回應狀態碼: 200
# 2025-02-05 19:34:49,850 - INFO - 文章 900199 回應狀態碼: 200
# 2025-02-05 19:34:49,851 - INFO - 文章 900200 不符合條件或解析失敗
# 2025-02-05 19:34:49,853 - INFO - 文章 900199 不符合條件或解析失敗
# 2025-02-05 19:34:49,853 - INFO - 文章 900198 回應狀態碼: 200
# 2025-02-05 19:34:49,857 - INFO - 文章 900198 不符合條件或解析失敗
# 2025-02-05 19:34:50,006 - INFO - 正在抓取文章 900203
# 2025-02-05 19:34:50,006 - INFO - 正在抓取文章 900202
# 2025-02-05 19:34:50,007 - INFO - 正在抓取文章 900205
# 2025-02-05 19:34:50,007 - INFO - 正在抓取文章 900204
# 2025-02-05 19:34:50,034 - INFO - 文章 900203 回應狀態碼: 200
# 2025-02-05 19:34:50,035 - INFO - 文章 900203 不符合條件或解析失敗
# 2025-02-05 19:34:50,041 - INFO - 文章 900205 回應狀態碼: 200
# 2025-02-05 19:34:50,042 - INFO - 文章 900202 回應狀態碼: 200
# 2025-02-05 19:34:50,043 - INFO - 文章 900204 回應狀態碼: 200
# 2025-02-05 19:34:50,085 - INFO - 文章 900205 不符合條件或解析失敗
# 2025-02-05 19:34:50,085 - INFO - 文章 900202 不符合條件或解析失敗
# 2025-02-05 19:34:50,085 - INFO - 文章 900204 不符合條件或解析失敗
